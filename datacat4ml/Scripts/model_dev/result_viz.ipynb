# %%
import os
import pandas as pd

# %%
# slurm_0: lsa_morganc+rdkc
slurm_0 = pd.read_parquet(os.path.join('mlruns', '800787657032729645', 'cac51ded99a2446cb788a390d70b785e', 'artifacts', 'metrics.parquet'))
# slurm_1: clip_morganc+rdkc
slurm_1 = pd.read_parquet(os.path.join('mlruns', '800787657032729645', '69e76f2f89a243b09423a04eee22a8fc', 'artifacts', 'metrics.parquet'))
# slurm_2: lsa_sprsFP
slurm_2 = pd.read_parquet(os.path.join('mlruns', '800787657032729645', '3405bdcefbfa41ee91fd96ce3a9e9c9f', 'artifacts', 'metrics.parquet'))
# slurm_3: clip_sprsFP
slurm_3 = pd.read_parquet(os.path.join('mlruns', '800787657032729645', 'c28e88f5734146659abdd5af599ddb5a', 'artifacts', 'metrics.parquet'))

# %%
print(f'columns: \n {slurm_0.columns}')
print(f"slurm_0['target_chembl_id'].unique(): \n {slurm_0['target_chembl_id'].unique()}")
slurm_0.describe()
# Out:
# columns:
#  Index(['assay_idx', 'assay_id', 'assay_chembl_id', 'assay_description',
#        'assay_type', 'assay_type_description', 'assay_category',
#        'assay_organism', 'assay_tax_id', 'assay_strain', 'assay_tissue',
#        'assay_cell_type', 'assay_subcellular_fraction', 'bao_format',
#        'bao_label', 'variant_id', 'assay_test_type', 'cell_id', 'tissue_id',
#        'relationship_type', 'relationship_type_description', 'aidx',
#        'confidence_score', 'confidence_score_description', 'tid',
#        'target_chembl_id', 'effect', 'effect_description', 'assay',
#        'assay_keywords_description', 'auroc', 'avgp', 'neg_avgp', 'argmax_j',
#        'bedroc', 'davgp', 'dneg_avgp'],
#       dtype='object')
# slurm_0['target_chembl_id'].unique():
#  ['CHEMBL233' 'CHEMBL237' 'CHEMBL236' 'CHEMBL2014']
#           assay_idx      assay_id  assay_tax_id  assay_strain  variant_id  \
# count    389.000000  3.890000e+02    290.000000           0.0         0.0
# ...

# %%
slurm_0
# Out:
#        assay_idx  assay_id assay_chembl_id  \
# 16113      16113    148100    CHEMBL751582
# 16118      16118    148222    CHEMBL754712
# 16127      16127    146569    CHEMBL755058
# 16129      16129    149322    CHEMBL756357
# 16143      16143    149323    CHEMBL756358
# ...          ...       ...             ...
# 18261      18261    331364    CHEMBL867089
# 18262      18262    379862    CHEMBL864850
# 18270      18270    540960   CHEMBL1030680
# 18279      18279    740153   CHEMBL1763213
# 18286      18286   1992302   CHEMBL4626037
#
#                                        assay_description assay_type  \
# 16113  Binding affinity at human opioid receptor mu 1...          B
# 16118  In vitro binding affinity to human Opioid rece...          B
# 16127  Binding affinity towards opioid receptor mu wa...          B
# 16129  Binding affinity towards mu opioid receptor wa...          B
# 16143            Binding affinity for mu opioid receptor          B
# ...
