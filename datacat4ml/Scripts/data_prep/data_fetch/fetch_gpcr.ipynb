# %%
# conda env: datacat(Python 3.8.20)
import sys
from datacat4ml.const import DATA_DIR, FIG_DIR, FETCH_DATA_DIR , FETCH_FIG_DIR
from datacat4ml.const import OR_chemblids, OR_uniprot_ids
from datacat4ml.utils import mkdirs

import os
from typing import List
import string

import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from sklearn.metrics import r2_score,cohen_kappa_score,balanced_accuracy_score,\
    median_absolute_error,matthews_corrcoef
import hashlib
from collections import Counter, defaultdict

from rdkit import Chem
from rdkit.Chem import AllChem

# %% [markdown]
# # Connect to the database

# %%
# load ipython-sql, a Jupyter Notebook magic extension. 
# %load_ext sql 
# %sql sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db

import sqlite3
conn = sqlite3.connect('/storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db')

# %% [markdown]
# # Fetch GPCR data

# %% [markdown]
# ## Read Uniprot IDs for GPCR human

# %%
# All GPCR proteins in human
GPCR_human = pd.read_csv(os.path.join(DATA_DIR, 'GPCR_human.tsv'),sep='\t')
gpcr_uniprot_ids_list = GPCR_human['Entry'].tolist()
print(f'The number of proteins in GPCR_human is {len(gpcr_uniprot_ids_list)}')
print(f'The first 5 proteins in GPCR_human are {gpcr_uniprot_ids_list[:5]}')
# Out:
# The number of proteins in GPCR_human is 898
# The first 5 proteins in GPCR_human are ['Q16570', 'O00590', 'P25106', 'Q9NPB9', 'P18509']

# %% [markdown]
# ## Write the below columns to a csv file

# %% [markdown]
# x
# - 'canonical_smiles'
# - assays.
#     - assay_id,
#     - chembl_id --> 'assay_chembl_id',
#     - doc_id,
#
#     in the maxMatch:
#     - **assay_type**, e.g. B, F.
#     - **assay_type_description**
#     - **assay_category**, (very sparse), e.g. Selectivity assay, Affinity biochemical assay, Affinity on-target cellular assay, Affinity phenotypic cellular assay, GPCR beta-arrestin assay, Thermal shift assay.
#     - **assay_organism**, e.g. Homo sapiens, Rattus norvegicus
#     - **assay_tax_id**, e.g. 9606 (for human), 1280 (for Staphylococcus aureus)
#     - **assay_strain**, (median sparse), e.g. LV9, BaL.
#     - **assay_tissue**, (median sparse), e.g. Brain, Plasma
#     - **assay_cell_type**, (median sparse), e.g. PC-3M, CHO
#     - **assay_subcellular_fraction**, (very sparse), e.g. Membrane, Microsome, Mitochondria
#     - **bao_format**, (e.g, BAO_0000019: could be cell-based format, organism-based format)
#     - **bao_lable**
#     - **variant_id**, (very sparse)
#     - **confidence_score**
#     - **confidence_score_description**
#
#     something else
#     - **assay_test_type**, (sparse), e.g. in vitro, in vivo.
#     - **description**
#     - cell_id, (median sparse)
#     - tissue_id, (median sparse)
#     - curated_by, e.g. Autocuration, Intermediate, Expert.
#     - relationship_type,  e.g. H, U, N, D, M, S
#         - D: Direct protein target assigned
#         - H: Homologous protein target assigned
#     - relationship_description,
#     - aidx,  e.g. CLD0, 1480429, 1480486.
#         Identifiers for key entities such as compounds and assays are defined within the deposition files by using Depositor-Defined Identifiers (DDIs). These identifiers are created and maintained by depositors themselves, and provide a way for depositors to. See details at https://chembl.gitbook.io/chembl-data-deposition-guide/deposition-overview/depositor-defined-identifiers
#
# support
# - target_dictionary.chembl_id --> 'target_chembl_id'
# - standard_type, standard_relation, standard_units
# 'compound_chembl_id'
# - assays.relationship_type (e.g. D, stands for direct protein target assigned)
#
# annotation
# - asaays.src_id (e.g. integers that are unique identifiers for sources in UniChem )
#
#
# y
# - 'pchembl_value'

# %% [markdown]
# # Functions

# %%
def gather_data_for_size(uniprot_id: List[str], standard_type:str,
                         onlyDocs=True,removeMutants=True,confidenceScore=8,):
    """ Get the data for the size of the dataset """
    
    if isinstance(uniprot_id, str):
        uniprot_id = [uniprot_id]
    uniprot_id_str = ",".join(f"'{id}'" for id in uniprot_id)

    print('table temp_targets')
    # %sql \
        drop table if exists temp_targets
    # %sql \
        create table temp_targets as \
        select tid, component_id, accession, target_type, pref_name target_pref_name, chembl_id target_chembl_id \
        from target_components \
        join component_sequences using(component_id) \
        join target_dictionary using(tid) \
        where accession in ({uniprot_id_str}) \
        and target_type = 'SINGLE PROTEIN';
    print(f"The shape of temp_targets is {pd.read_sql('select * from temp_targets', con=conn).shape}")

    # collect activities for the assays that meet the basic criteria
    print('table temp_assays')
    # %sql \
        drop table if exists temp_assays
    # %sql \
        create table temp_assays as \
        select assay_id, assays.chembl_id assay_chembl_id, assays.description assay_desc, assays.doc_id assay_doc_id, variant_id, \
        docs.year doc_date, docs.chembl_id doc_chembl_id, \
        tid, accession, target_type, target_pref_name, target_chembl_id, \
        count(distinct(molregno)) cnt \
        from activities \
        join assays using(assay_id) \
        join docs on (assays.doc_id = docs.doc_id) \
        join temp_targets using (tid) \
        where standard_type =:standard_type \
        group by tid, assay_doc_id, assay_id \
        order by cnt desc;
    print(f"The shape of temp_assays is {pd.read_sql('select * from temp_assays', con=conn).shape}")

    # now remove rows for assays which are not compatible without curation steps
    print('check onlyDocs')
    if onlyDocs:
        # %sql \
            delete from temp_assays where doc_date is null;

    print('check removeMutants')
    if removeMutants:
        # %sql \
            delete from temp_assays where variant_id is not null or lower(assay_desc) like '%mutant%'\
                or lower(assay_desc) like '%mutantion%' or lower(assay_desc) like '%variant%';
                
    print('check confidenceScore')
    # filter out assays with confidence score less than confidenceScore
    # %sql \
        drop table if exists temp_assays_filtered;
    # %sql \
        create table temp_assays_filtered as \
        select ta.*, confidence_score from temp_assays ta \
            join assays using(assay_id) \
            where confidence_score >= :confidenceScore;  
    print(f"The shape of temp_assays_filtered is {pd.read_sql('select * from temp_assays_filtered', con=conn).shape}")
    
    # select activities from the assays we've identified which have between less than maxAssaySize tested compounds --> delete this condition because we are creating a benchmark dataset
    # why are 'pchembl_value' and 'standard_type' used here again? because here join table 'activities' again only on 'assay_id'.
    print('temp_acts')
    # %sql \
        drop table if exists temp_acts
    # %sql \
        create table temp_acts as \
        select assay_id, assay_chembl_id, tid, target_chembl_id,molregno,doc_chembl_id,standard_type,activity_id \
        from activities \
        join temp_assays_filtered using (assay_id)\
        where standard_type =:standard_type  
    print(f"The shape of temp_acts is {pd.read_sql('select * from temp_acts', con=conn).shape}")

    # count the number of unique compounds in each assay_id
    # `group by`statemenet groups rows that have the same values into summary rows
    print('temp_acts_counts')
    # %sql \
        drop table if exists temp_acts_counts
    # %sql \
        create table temp_acts_counts as \
        select assay_id, assay_chembl_id, ta.tid, target_chembl_id, count(distinct molregno) cnt, doc_chembl_id \
        from temp_acts ta \
        join assays using (assay_id) \
        group by assay_chembl_id, target_chembl_id, doc_chembl_id \
        order by cnt desc;
    print(f"The shape of temp_acts_counts is {pd.read_sql('select * from temp_acts_counts', con=conn).shape}")
    
    # count the number of unique assays for each target
    print('temp_targets_counts')
    # %sql \
        drop table if exists temp_targets_counts
    # %sql \
        create table temp_targets_counts as \
        select tid, target_chembl_id, count(distinct assay_chembl_id) target_assay_count, sum(cnt) target_compound_count \
        from temp_acts_counts tac \
        group by target_chembl_id \
        order by target_assay_count desc;
    print(f"The shape of temp_targets_counts is {pd.read_sql('select * from temp_targets_counts', con=conn).shape}")

def append_assay_info(readout = 'Ki',uniprot_id = gpcr_uniprot_ids_list,
                      onlyDocs=True,removeMutants=True,confidenceScore=8):
    '''
    Append the assay information to the output of function gather_data_for_size
    '''
    
    gather_data_for_size(uniprot_id=uniprot_id,standard_type=readout,
                         onlyDocs=onlyDocs,removeMutants=removeMutants,confidenceScore=confidenceScore)

    print (f'raw_data for {readout}')
    
    # %sql \
        drop table if exists raw_data
    raw_data = %sql \
        SELECT activity_id, ta_1.assay_id, ta_1.assay_chembl_id, ta_1.tid, ta_1.target_chembl_id, standard_type, standard_relation, standard_value, standard_units, pchembl_value, \
        as1.assay_type, at1.assay_desc AS assay_type_desc, as1.assay_category, as1.assay_organism, as1.assay_tax_id, as1.assay_strain, as1.assay_tissue, as1.assay_cell_type, as1.assay_subcellular_fraction, as1.bao_format, bo1.label AS bao_label, ta_1.variant_id, as1.assay_test_type, \
        as1.description AS assay_desc, as1.cell_id, as1.tissue_id, as1.curated_by, as1.relationship_type, rs1.relationship_desc, as1.aidx, \
        ta_1.confidence_score, csl1.description AS confidence_score_desc, cs1.molregno, cid.chembl_id AS compound_chembl_id, canonical_smiles \
        FROM activities \
        JOIN temp_assays_filtered ta_1 ON ta_1.assay_id = activities.assay_id \
        JOIN temp_targets_counts ON temp_targets_counts.tid = ta_1.tid \
        JOIN temp_acts_counts ON temp_acts_counts.assay_id = ta_1.assay_id \
        JOIN assays as1 ON as1.assay_id = ta_1.assay_id \
        JOIN chembl_id_lookup cid ON cid.entity_type='COMPOUND' AND cid.entity_id= activities.molregno \
        JOIN compound_structures cs1 ON cs1.molregno = activities.molregno \
        JOIN assay_type at1 ON at1.assay_type = as1.assay_type \
        JOIN relationship_type rs1 ON rs1.relationship_type = as1.relationship_type \
        JOIN bioassay_ontology bo1 ON bo1.bao_id = as1.bao_format \
        JOIN confidence_score_lookup csl1 ON csl1.confidence_score = ta_1.confidence_score \
        WHERE standard_type=:readout;

    return raw_data
    
def hash_assay_info(raw_data, sel_cols:List[str]=['assay_type', 'assay_organism', 'assay_category',
                                                    'assay_tax_id','assay_strain','assay_tissue',
                                                    'assay_cell_type','assay_subcellular_fraction',
                                                    'bao_format', 'variant_id']):
    '''
    For the retrieved data from the database, concatenate the columns related to assay info, hash these values, and convert the data into a pandas dataframe.

    params:
        raw_data: The retrieved data from the database.
        sel_cols: A list of column names to be used for hashing.

    Returns:
        A pandas DataFrame with the original data and an additional 'assay_metadata_hash' column.

    The string in the sel_cols can be the below:
    'assay_type','assay_organism','assay_category',
    'assay_tax_id','assay_strain','assay_tissue',
    'assay_cell_type','assay_subcellular_fraction','bao_format','variant_id'
    '''

    processed_data = []
    for row in raw_data:
        original_data= [str(value) for value in row]
        # concatenate certain fields and hash
        assay_fields = ''.join([str(row[col]) for col in sel_cols])  # Add all fields you need
        hash_result = hashlib.md5(assay_fields.encode()).hexdigest()
        original_data.append(hash_result)
        processed_data.append(tuple(original_data))

    print(f'The length of the processed_data is {len(processed_data)}')

    return processed_data

# %% [markdown]
# ## IC50

# %%
readout = 'IC50'
print(f'raw_data for {readout}_maxcuration')
raw_data = append_assay_info(readout=readout, uniprot_id=gpcr_uniprot_ids_list,
                             onlyDocs=True,removeMutants=True,confidenceScore=8)
ic50_maxcur_8_data = hash_assay_info(raw_data)
# Out:
# raw_data for IC50_maxcuration
# table temp_targets
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets is (381, 6)
# table temp_assays
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays is (11432, 13)
# check onlyDocs
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 158 rows affected.
# check removeMutants
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 266 rows affected.
# check confidenceScore
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays_filtered is (11008, 14)
# temp_acts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts is (122286, 8)
# temp_acts_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts_counts is (11008, 6)
# temp_targets_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets_counts is (251, 4)
# raw_data for IC50
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The length of the processed_data is 122257

# %% [markdown]
# ## Ki

# %%
readout = 'Ki'
print(f'raw_data for {readout}_maxcuration')
raw_data = append_assay_info(readout=readout, uniprot_id=gpcr_uniprot_ids_list,
                             onlyDocs=True,removeMutants=True,confidenceScore=8)
ki_maxcur_8_data = hash_assay_info(raw_data)
# Out:
# raw_data for Ki_maxcuration
# table temp_targets
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets is (381, 6)
# table temp_assays
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays is (16610, 13)
# check onlyDocs
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 75 rows affected.
# check removeMutants
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 193 rows affected.
# check confidenceScore
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays_filtered is (16342, 14)
# temp_acts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts is (176588, 8)
# temp_acts_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts_counts is (16342, 6)
# temp_targets_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets_counts is (200, 4)
# raw_data for Ki
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The length of the processed_data is 176449

# %% [markdown]
# ## EC50

# %%
readout = 'EC50'
print(f'raw_data for {readout}_maxcuration')
raw_data = append_assay_info(readout=readout, uniprot_id=gpcr_uniprot_ids_list,
                             onlyDocs=True,removeMutants=True,confidenceScore=8)
ec50_maxcur_8_data = hash_assay_info(raw_data)
# Out:
# raw_data for EC50_maxcuration
# table temp_targets
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets is (381, 6)
# table temp_assays
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays is (7080, 13)
# check onlyDocs
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 114 rows affected.
# check removeMutants
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 241 rows affected.
# check confidenceScore
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays_filtered is (6725, 14)
# temp_acts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts is (79044, 8)
# temp_acts_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts_counts is (6725, 6)
# temp_targets_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets_counts is (237, 4)
# raw_data for EC50
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The length of the processed_data is 79012

# %% [markdown]
# # Write data

# %% [markdown]
# ### GPCR_type

# %%
def write_data(data, filename:str, columns=['activity_id',
                                   'assay_id', 'assay_chembl_id', 'tid', 'target_chembl_id', 'standard_type', 'standard_relation', 'standard_value', 'standard_units', 'pchembl_value', 
                                   'assay_type', 'assay_type_desc', 'assay_category', # checkpoint 1
                                   'assay_organism', 'assay_tax_id', 'assay_strain', 'assay_tissue', 'assay_cell_type', 'assay_subcellular_fraction', 'bao_format', 'bao_label', 'variant_id', 'assay_test_type', 
                                   'assay_desc', 'cell_id', 'tissue_id', 'curated_by', 'relationship_type', 'relationship_type_desc', 'aidx', 
                                   'confidence_score', 'confidence_score_desc', 'molregno', 'compound_chembl_id', 'canonical_smiles', 'assay_metadata_hash']):
    """Save the data to a pandas dataframe"""

    data_df = pd.DataFrame(data, columns=columns)
    
    # write the data to a csv file
    data_df.to_csv(f'{FETCH_DATA_DIR}/{filename}.csv',index=False)
    
    return data_df

# %%
ic50_maxcur_df = write_data(ic50_maxcur_8_data, 'IC50_gpcr_maxcur_8_data')
ki_maxcur_df = write_data(ki_maxcur_8_data, 'Ki_gpcr_maxcur_8_data')
ec50_maxcur_df = write_data(ec50_maxcur_8_data, 'EC50_gpcr_maxcur_8_data')

# %% [markdown]
# ### datapoints with unique 'assay_hash_info'

# %%
# only for dataset with maxcuration
def write_data_uniq_cond(df, min_dataset_size=100, readout='IC50', curation='maxcur'):
    """
    write the datasets with unique combinations of 'target_chembl_id' and 'assay_metadata_hash'
    """
    yaml=[]
    
    collected_data = defaultdict(list)
    assay_cond_accum = defaultdict(list)
    assay_accum = defaultdict(set)

    for i, row in df.iterrows():
        assay_metadata_hash = row['assay_metadata_hash']
        target_chembl_id = row['target_chembl_id']
        assay_chembl_id = row['assay_chembl_id']

        # append all columns to the collected_data
        collected_data[(target_chembl_id, assay_metadata_hash)].append(row.values)
        assay_cond_accum[target_chembl_id].append(assay_metadata_hash)
        assay_accum[(target_chembl_id,assay_metadata_hash)].add(assay_chembl_id)

    sets_to_keep = [k for k, v in collected_data.items() if len(v) >= min_dataset_size]
    for k in assay_cond_accum:
        assay_cond_accum[k] = [y for y in assay_cond_accum[k] if (k, y) in sets_to_keep]

    for target_chembl_id, conds in collected_data.keys():
        if (target_chembl_id, conds) not in sets_to_keep:
            continue
        rows = collected_data[(target_chembl_id, conds)]
        cols = np.array(rows).transpose()
        cond_idx = assay_cond_accum[target_chembl_id].index(conds)+1

        columns = df.columns
        df = pd.DataFrame(dict(zip(columns, cols)))
        fname = f'{readout}_target_{target_chembl_id}_{cond_idx}.csv'
        filepath = os.path.join(FETCH_DATA_DIR, f'{readout}_{curation}')
        mkdirs(filepath)
        df.to_csv(os.path.join(filepath, fname), index=False)

        #minAct = min(df.pchembl_value)
        #maxAct = max(df.pchembl_value)
        #medAct = np.median(pd.to_numeric(df.pchembl_value, errors='coerce'))
        actType = readout
        targetd = %sql \
        select * from target_dictionary  \
            where chembl_id=:target_chembl_id
        targetd = dict(targetd[0])    
        template=f'''  {target_chembl_id}-{cond_idx}:
        description: "Target {target_chembl_id}: {targetd['pref_name']}"
        args:
        filename: '{{{{ CATALOG_DIR }}}}/source_data/{fname}'
        smilesColumn: canonical_smiles
        metadata:
        url: https://www.ebi.ac.uk/chembl/target_report_card/{target_chembl_id}/
        source: ChEMBL_32
        target_organism: {targetd['organism']}
        assays_included: {','.join(assay_accum[(target_chembl_id,conds)])}
        num_points: {len(rows)}
        activity_type: {actType}
        driver: intake_rdkit.smiles.SmilesSource
        '''
        #min pchembl_value: {float(minAct):.2f}
        #max pchembl_value: {float(maxAct):.2f}
        #median pchembl_value: {float(medAct):.2f}
        yaml.append(template)
    print('\n'.join(yaml))
    with open(os.path.join(FETCH_DATA_DIR, f'{readout}_{curation}', f'{readout}_{curation}_datasets.yaml'),'w+') as outf:
        header=f'''metadata:

    summary: |
        Collection of {readout} datasets with pchembl_values for bioactivity prediction.
        
    sources:'''
        print(header,file=outf)
        print('\n'.join(yaml),file=outf)

# %%
write_data_uniq_cond(ic50_maxcur_df, min_dataset_size=100, readout='IC50', curation='maxcur')
write_data_uniq_cond(ki_maxcur_df, min_dataset_size=100, readout='Ki', curation='maxcur')
write_data_uniq_cond(ec50_maxcur_df, min_dataset_size=100, readout='EC50', curation='maxcur')
# Out:
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#   CHEMBL252-1:
#         description: "Target CHEMBL252: Endothelin receptor ET-A"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL252_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL252/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL677304,CHEMBL682359,CHEMBL677303,CHEMBL682356,CHEMBL679122,CHEMBL677305,CHEMBL681512,CHEMBL682358,CHEMBL682365,CHEMBL681509,CHEMBL681515,CHEMBL928137,CHEMBL682360,CHEMBL681514,CHEMBL677091,CHEMBL682971,CHEMBL677260,CHEMBL679837,CHEMBL682969,CHEMBL682364,CHEMBL682108,CHEMBL678230,CHEMBL682110,CHEMBL682366,CHEMBL873602,CHEMBL677307,CHEMBL682970,CHEMBL876873,CHEMBL677308,CHEMBL678229,CHEMBL682100
#         num_points: 454
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1785-1:
#         description: "Target CHEMBL1785: Endothelin receptor ET-B"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1785_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1785/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL670644,CHEMBL670643,CHEMBL670635,CHEMBL677443,CHEMBL878153,CHEMBL670478,CHEMBL670652,CHEMBL676633,CHEMBL677450,CHEMBL670476,CHEMBL670653,CHEMBL672254,CHEMBL670650,CHEMBL677268,CHEMBL673747,CHEMBL677444,CHEMBL678456,CHEMBL670477,CHEMBL670638,CHEMBL678457,CHEMBL670651,CHEMBL670640,CHEMBL677448
#         num_points: 349
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL4561-1:
#         description: "Target CHEMBL4561: Neuropeptide Y receptor type 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL4561_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL4561/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL750995,CHEMBL752047,CHEMBL750996,CHEMBL750832,CHEMBL755165,CHEMBL750834,CHEMBL750833,CHEMBL750823,CHEMBL750824,CHEMBL752046
#         num_points: 136
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1855-1:
#         description: "Target CHEMBL1855: Gonadotropin-releasing hormone receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1855_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1855/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL1804376,CHEMBL831490,CHEMBL871108,CHEMBL1804380,CHEMBL711950,CHEMBL3375484
#         num_points: 111
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL298-1:
#         description: "Target CHEMBL298: Cholecystokinin B receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL298_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL298/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL657477,CHEMBL656243,CHEMBL652235,CHEMBL661925,CHEMBL662562,CHEMBL662574,CHEMBL656244,CHEMBL657483,CHEMBL663098,CHEMBL657472,CHEMBL662565,CHEMBL656242,CHEMBL657476,CHEMBL657475,CHEMBL662566,CHEMBL662567,CHEMBL657484,CHEMBL653980,CHEMBL662559,CHEMBL661926,CHEMBL657474,CHEMBL662561,CHEMBL662573,CHEMBL662569,CHEMBL660029,CHEMBL657479,CHEMBL660023,CHEMBL662568,CHEMBL656249,CHEMBL662564,CHEMBL662563,CHEMBL653979,CHEMBL662575
#         num_points: 460
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL2413-1:
#         description: "Target CHEMBL2413: C-C chemokine receptor type 1"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL2413_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL2413/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL655681,CHEMBL884346,CHEMBL935642,CHEMBL843656,CHEMBL650697,CHEMBL893666,CHEMBL651705,CHEMBL1107995,CHEMBL1010848,CHEMBL2184883,CHEMBL650209,CHEMBL651704,CHEMBL655517,CHEMBL652583
#         num_points: 133
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL227-1:
#         description: "Target CHEMBL227: Type-1 angiotensin II receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL227_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL227/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL1670336,CHEMBL648566,CHEMBL650307,CHEMBL648492,CHEMBL647575,CHEMBL648562,CHEMBL648563,CHEMBL648565,CHEMBL647576,CHEMBL650308,CHEMBL2161529,CHEMBL652865,CHEMBL648564,CHEMBL1069624,CHEMBL650315,CHEMBL647574,CHEMBL648568,CHEMBL1949356
#         num_points: 240
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1917-1:
#         description: "Target CHEMBL1917: Somatostatin receptor 1"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1917_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1917/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL805042,CHEMBL805041,CHEMBL807422,CHEMBL801244,CHEMBL805040,CHEMBL805039,CHEMBL807423
#         num_points: 142
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1804-1:
#         description: "Target CHEMBL1804: Somatostatin receptor 2"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1804_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1804/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL801246,CHEMBL807429,CHEMBL807087,CHEMBL807428,CHEMBL806163,CHEMBL806165,CHEMBL807088,CHEMBL806164
#         num_points: 146
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL2028-1:
#         description: "Target CHEMBL2028: Somatostatin receptor 3"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL2028_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL2028/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL801248,CHEMBL807104,CHEMBL807102,CHEMBL803848,CHEMBL803847,CHEMBL807105,CHEMBL807103
#         num_points: 144
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1853-1:
#         description: "Target CHEMBL1853: Somatostatin receptor 4"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1853_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1853/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL807046,CHEMBL873241,CHEMBL801249,CHEMBL807045,CHEMBL803856,CHEMBL803857,CHEMBL807048,CHEMBL884900,CHEMBL803855,CHEMBL807047,CHEMBL976350
#         num_points: 154
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1792-1:
#         description: "Target CHEMBL1792: Somatostatin receptor 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1792_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1792/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL806597,CHEMBL806596,CHEMBL807063,CHEMBL801251,CHEMBL945054,CHEMBL806595,CHEMBL883371,CHEMBL807065,CHEMBL882393,CHEMBL807064
#         num_points: 151
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1855-5:
#         description: "Target CHEMBL1855: Gonadotropin-releasing hormone receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1855_5.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1855/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL685984,CHEMBL2160774,CHEMBL871112,CHEMBL684347,CHEMBL709251,CHEMBL684238,CHEMBL685982,CHEMBL685986,CHEMBL684348,CHEMBL684242,CHEMBL685985,CHEMBL709252,CHEMBL684239
#         num_points: 123
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL4561-4:
#         description: "Target CHEMBL4561: Neuropeptide Y receptor type 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL4561_4.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL4561/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL1772031,CHEMBL1042016,CHEMBL1074018,CHEMBL1043093,CHEMBL857550,CHEMBL750829,CHEMBL882034
#         num_points: 108
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL255-1:
#         description: "Target CHEMBL255: Adenosine A2b receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL255_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL255/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL1037719,CHEMBL2073181,CHEMBL4628744,CHEMBL1014570,CHEMBL1011027,CHEMBL639471,CHEMBL939195,CHEMBL2320330,CHEMBL4379764,CHEMBL950999,CHEMBL1120803,CHEMBL3802558,CHEMBL862545,CHEMBL3379789,CHEMBL901021,CHEMBL874953,CHEMBL4407534,CHEMBL3757839,CHEMBL3756030,CHEMBL4189479,CHEMBL4628751,CHEMBL865365,CHEMBL1936207,CHEMBL4156074,CHEMBL1959510,CHEMBL1764849,CHEMBL2034749,CHEMBL1175305,CHEMBL4333788,CHEMBL639467,CHEMBL4322429,CHEMBL1803408,CHEMBL3878905,CHEMBL1931872
#         num_points: 587
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL259-1:
#         description: "Target CHEMBL259: Melanocortin receptor 4"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL259_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL259/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL715712,CHEMBL713803,CHEMBL713804,CHEMBL715711,CHEMBL715713,CHEMBL713800,CHEMBL709902,CHEMBL717496,CHEMBL713797,CHEMBL713796,CHEMBL713798,CHEMBL878465,CHEMBL929034,CHEMBL715714,CHEMBL965659,CHEMBL713801,CHEMBL932304,CHEMBL713799,CHEMBL717497,CHEMBL709901,CHEMBL872791
#         num_points: 102
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL250-1:
#         description: "Target CHEMBL250: Platelet activating factor receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL250_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL250/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL760447,CHEMBL760446,CHEMBL764098,CHEMBL764095,CHEMBL880989,CHEMBL764097,CHEMBL764537,CHEMBL764538,CHEMBL764096
#         num_points: 119
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL217-1:
#         description: "Target CHEMBL217: Dopamine D2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL217_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL217/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL1947794,CHEMBL980770,CHEMBL672304,CHEMBL671076,CHEMBL663737,CHEMBL666192,CHEMBL670678,CHEMBL663738,CHEMBL1046708,CHEMBL672502,CHEMBL672501,CHEMBL1810621,CHEMBL672301,CHEMBL920904,CHEMBL1050444,CHEMBL671650,CHEMBL671075,CHEMBL1108779,CHEMBL672303,CHEMBL983581,CHEMBL670113,CHEMBL857158,CHEMBL671074,CHEMBL884444,CHEMBL671344,CHEMBL670685,CHEMBL946008,CHEMBL671343,CHEMBL985708,CHEMBL663736,CHEMBL1101348,CHEMBL928141,CHEMBL666193,CHEMBL670073,CHEMBL1936809,CHEMBL671342,CHEMBL667743,CHEMBL925073,CHEMBL979061,CHEMBL1285527,CHEMBL1827739
#         num_points: 235
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL249-1:
#         description: "Target CHEMBL249: Neurokinin 1 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL249_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL249/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL748490,CHEMBL752058,CHEMBL751717,CHEMBL807802,CHEMBL748487,CHEMBL809504,CHEMBL873470,CHEMBL748491,CHEMBL747297,CHEMBL807904,CHEMBL747305,CHEMBL751900,CHEMBL813804,CHEMBL748656,CHEMBL872729,CHEMBL807967,CHEMBL749392,CHEMBL807903,CHEMBL807958,CHEMBL749780,CHEMBL821389,CHEMBL749536,CHEMBL751718,CHEMBL807899,CHEMBL747298,CHEMBL807906,CHEMBL807959,CHEMBL812334,CHEMBL807907,CHEMBL807961,CHEMBL812541,CHEMBL749394,CHEMBL882327
#         num_points: 508
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3911-1:
#         description: "Target CHEMBL3911: Leukotriene B4 receptor 1"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL3911_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3911/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL705075,CHEMBL709307,CHEMBL708407,CHEMBL709312,CHEMBL704425,CHEMBL706534,CHEMBL708405,CHEMBL707238,CHEMBL706922,CHEMBL706536,CHEMBL707240,CHEMBL704424,CHEMBL879502,CHEMBL704428,CHEMBL709304,CHEMBL706535,CHEMBL706533,CHEMBL706537,CHEMBL704426,CHEMBL704430,CHEMBL709303,CHEMBL708406,CHEMBL707241,CHEMBL879635,CHEMBL707237,CHEMBL704422,CHEMBL707239,CHEMBL709308,CHEMBL704427,CHEMBL705074,CHEMBL707242
#         num_points: 123
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL274-1:
#         description: "Target CHEMBL274: C-C chemokine receptor type 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL274_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL274/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL654652,CHEMBL956846,CHEMBL659084,CHEMBL661604,CHEMBL659086,CHEMBL693290,CHEMBL1821334,CHEMBL654655,CHEMBL649936,CHEMBL654654,CHEMBL1107772,CHEMBL693289,CHEMBL661605,CHEMBL1912866,CHEMBL693291,CHEMBL659083,CHEMBL661606,CHEMBL654653,CHEMBL665164,CHEMBL873385
#         num_points: 480
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL4015-1:
#         description: "Target CHEMBL4015: C-C chemokine receptor type 2"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL4015_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL4015/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL2089603,CHEMBL843658,CHEMBL929490,CHEMBL662155,CHEMBL953063,CHEMBL655693,CHEMBL1211290,CHEMBL1107994,CHEMBL2184889,CHEMBL2032551,CHEMBL2184881,CHEMBL877280,CHEMBL1010849,CHEMBL655684
#         num_points: 122
#         activity_type: IC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3473-1:
# ...
#         assays_included: CHEMBL3887456
#         num_points: 234
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3227-576:
#         description: "Target CHEMBL3227: Metabotropic glutamate receptor 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3227_576.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3227/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888360,CHEMBL3887717,CHEMBL3888543,CHEMBL3887806,CHEMBL3888312
#         num_points: 227
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL218-1411:
#         description: "Target CHEMBL218: Cannabinoid CB1 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL218_1411.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL218/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888023
#         num_points: 171
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL253-1828:
#         description: "Target CHEMBL253: Cannabinoid CB2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL253_1828.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL253/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888024
#         num_points: 169
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL253-1997:
#         description: "Target CHEMBL253: Cannabinoid CB2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL253_1997.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL253/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888845,CHEMBL3888087,CHEMBL3888839,CHEMBL3888278
#         num_points: 950
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL218-1582:
#         description: "Target CHEMBL218: Cannabinoid CB1 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL218_1582.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL218/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888840,CHEMBL3888279,CHEMBL3888846,CHEMBL3888088
#         num_points: 925
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL2010631-1:
#         description: "Target CHEMBL2010631: C-X-C chemokine receptor type 7"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL2010631_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL2010631/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888966
#         num_points: 501
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL217-554:
#         description: "Target CHEMBL217: Dopamine D2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL217_554.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL217/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4394473,CHEMBL4000284,CHEMBL4339975,CHEMBL4368228,CHEMBL4008740,CHEMBL4344305,CHEMBL4371565,CHEMBL4345332,CHEMBL4236721
#         num_points: 136
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1889-149:
#         description: "Target CHEMBL1889: Vasopressin V1a receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1889_149.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1889/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4018368,CHEMBL4018362,CHEMBL4018363
#         num_points: 137
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1821-211:
#         description: "Target CHEMBL1821: Muscarinic acetylcholine receptor M4"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1821_211.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1821/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4030176,CHEMBL4046910,CHEMBL4035868,CHEMBL4306810,CHEMBL4306809
#         num_points: 208
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL253-2947:
#         description: "Target CHEMBL253: Cannabinoid CB2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL253_2947.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL253/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4030387,CHEMBL4040557,CHEMBL4367881,CHEMBL4367882,CHEMBL4361908
#         num_points: 107
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3297639-1:
#         description: "Target CHEMBL3297639: Probable G-protein coupled receptor 52"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3297639_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3297639/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4034862,CHEMBL4806971
#         num_points: 229
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1985-1:
#         description: "Target CHEMBL1985: Glucagon receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1985_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1985/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4052184,CHEMBL5215273,CHEMBL4124801,CHEMBL4052170,CHEMBL4432349,CHEMBL4220182,CHEMBL4671907,CHEMBL4132520
#         num_points: 118
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL214-256:
#         description: "Target CHEMBL214: Serotonin 1a (5-HT1a) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL214_256.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL214/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4229840,CHEMBL4670409,CHEMBL4709855,CHEMBL4119509,CHEMBL4707453,CHEMBL4707449,CHEMBL4195140,CHEMBL4409670,CHEMBL4670405,CHEMBL4230000,CHEMBL5146498,CHEMBL5146487
#         num_points: 101
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1875-135:
#         description: "Target CHEMBL1875: Serotonin 4 (5-HT4) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1875_135.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1875/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL5223929,CHEMBL5223843,CHEMBL4189919,CHEMBL4189943
#         num_points: 123
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL213-653:
#         description: "Target CHEMBL213: Beta-1 adrenergic receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL213_653.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL213/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4843197,CHEMBL5163496,CHEMBL4231528,CHEMBL4340582,CHEMBL4271651,CHEMBL4819539
#         num_points: 109
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL225-699:
#         description: "Target CHEMBL225: Serotonin 2c (5-HT2c) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL225_699.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL225/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4681101,CHEMBL4681089,CHEMBL4363107
#         num_points: 134
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL217-975:
#         description: "Target CHEMBL217: Dopamine D2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL217_975.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL217/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4392184,CHEMBL4406526,CHEMBL4394480,CHEMBL4397361,CHEMBL4392174,CHEMBL4394476
#         num_points: 203
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL234-168:
#         description: "Target CHEMBL234: Dopamine D3 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL234_168.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL234/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4406544,CHEMBL4397359,CHEMBL4406524,CHEMBL4406074,CHEMBL4392188
#         num_points: 143
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3714130-1:
#         description: "Target CHEMBL3714130: G-protein coupled receptor 6"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3714130_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3714130/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4742497,CHEMBL4739759,CHEMBL5039193,CHEMBL4418470
#         num_points: 375
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1832-1:
#         description: "Target CHEMBL1832: Calcitonin receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1832_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1832/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4421024,CHEMBL4421026
#         num_points: 239
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL4877-1:
#         description: "Target CHEMBL4877: Neuropeptide Y receptor type 4"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL4877_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL4877/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4621616,CHEMBL4621614
#         num_points: 100
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1681611-1:
#         description: "Target CHEMBL1681611: Prolactin-releasing peptide receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1681611_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1681611/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4700945,CHEMBL4700961
#         num_points: 131
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3632455-1:
#         description: "Target CHEMBL3632455: Probable G-protein coupled receptor 139"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3632455_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3632455/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4739806
#         num_points: 191
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3632455-192:
#         description: "Target CHEMBL3632455: Probable G-protein coupled receptor 139"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3632455_192.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3632455/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4739810
#         num_points: 133
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3632455-325:
#         description: "Target CHEMBL3632455: Probable G-protein coupled receptor 139"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3632455_325.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3632455/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4742409,CHEMBL4810043
#         num_points: 135
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL217-1259:
#         description: "Target CHEMBL217: Dopamine D2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL217_1259.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL217/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4842103,CHEMBL4815488,CHEMBL5151480,CHEMBL4842093,CHEMBL4842095
#         num_points: 218
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL224-639:
#         description: "Target CHEMBL224: Serotonin 2a (5-HT2a) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL224_639.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL224/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL5135838
#         num_points: 202
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL225-873:
#         description: "Target CHEMBL225: Serotonin 2c (5-HT2c) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL225_873.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL225/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL5135840
#         num_points: 198
#         activity_type: EC50
#         driver: intake_rdkit.smiles.SmilesSource
