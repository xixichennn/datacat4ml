# %%
# conda env: pyg (Python3.9.16)
import sys
from datacat4ml.const import DATA_DIR, FIG_DIR, FETCH_DATA_DIR , FETCH_FIG_DIR
from datacat4ml.const import OR_chembl_ids, OR_uniprot_ids
from datacat4ml.utils import mkdirs

import os
from typing import List
import string
# load ipython-sql, a Jupyter Notebook magic extension. 
# %load_ext sql 
import sqlite3
from sqlite3 import connect
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from sklearn.metrics import r2_score,cohen_kappa_score,balanced_accuracy_score,\
    median_absolute_error,matthews_corrcoef
import hashlib
from collections import Counter, defaultdict

from rdkit import Chem
from rdkit.Chem import AllChem
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# # Connect to the database

# %%
# %sql sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db

conn = sqlite3.connect('/storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db')

# %% [markdown]
# # Fetch GPCR data

# %% [markdown]
# ## Read Uniprot IDs for GPCR human

# %%
# All GPCR proteins in human
GPCR_human = pd.read_csv(os.path.join(DATA_DIR, 'GPCR_human.tsv'),sep='\t')
gpcr_uniprot_ids_list = GPCR_human['Entry'].tolist()
print(f'The number of proteins in GPCR_human is {len(gpcr_uniprot_ids_list)}')
print(f'The first 5 proteins in GPCR_human are {gpcr_uniprot_ids_list[:5]}')
# Out:
# The number of proteins in GPCR_human is 898
# The first 5 proteins in GPCR_human are ['Q16570', 'O00590', 'P25106', 'Q9NPB9', 'P18509']

# %% [markdown]
# ## Write the below columns to a csv file

# %% [markdown]
# x
# - 'canonical_smiles'
# - assays.
#     - assay_id,
#     - chembl_id --> 'assay_chembl_id',
#     - doc_id,
#
#     in the maxMatch:
#     - **assay_type**, e.g. B, F.
#     - **assay_category**, (very sparse), e.g. Selectivity assay, Affinity biochemical assay, Affinity on-target cellular assay, Affinity phenotypic cellular assay, GPCR beta-arrestin assay, Thermal shift assay.
#     - **assay_organism**, e.g. Homo sapiens, Rattus norvegicus
#     - **assay_tax_id**, e.g. 9606 (for human), 1280 (for Staphylococcus aureus)
#     - **assay_strain**, (median sparse), e.g. LV9, BaL.
#     - **assay_tissue**, (median sparse), e.g. Brain, Plasma
#     - **assay_cell_type**, (median sparse), e.g. PC-3M, CHO
#     - **assay_subcellular_fraction**, (very sparse), e.g. Membrane, Microsome, Mitochondria
#     - **bao_format**, (e.g, BAO_0000019: could be cell-based format, organism-based format)
#     - **variant_id**, (very sparse)
#
#     something else
#     - **assay_test_type**, (sparse), e.g. in vitro, in vivo.
#     - **description**
#     - cell_id, (median sparse)
#     - tissue_id, (median sparse)
#     - curated_by, e.g. Autocuration, Intermediate, Expert.
#     - relationship_type, ? e.g. H, U, N, D, M, S
#     - aidx,  ? e.g. CLD0, 1480429, 1480486
#
# support
# - target_dictionary.chembl_id --> 'target_chembl_id'
# - standard_type, standard_relation, standard_units
# 'compound_chembl_id'
# - assays.relationship_type (e.g. D, stands for direct protein target assigned)
#
# annotation
# - asaays.src_id (e.g. integers that are unique identifiers for sources in UniChem )
#
#
# y
# - 'pchembl_value'

# %% [markdown]
# # Functions

# %%
def gather_data_for_size(uniprot_id: List[str], standard_type:str,
                         onlyDocs=True,removeMutants=True,confidenceScore=8,):
    """ Get the data for the size of the dataset """
    
    if isinstance(uniprot_id, str):
        uniprot_id = [uniprot_id]
    uniprot_id_str = ",".join(f"'{id}'" for id in uniprot_id)

    print('table temp_targets')
    # %sql \
        drop table if exists temp_targets
    # %sql \
        create table temp_targets as \
        select tid, component_id, accession, target_type, pref_name target_pref_name, chembl_id target_chembl_id \
        from target_components \
        join component_sequences using(component_id) \
        join target_dictionary using(tid) \
        where accession in ({uniprot_id_str}) \
        and target_type = 'SINGLE PROTEIN';
    print(f"The shape of temp_targets is {pd.read_sql('select * from temp_targets', con=conn).shape}")

    # collect activities for the assays that meet the basic criteria
    print('table temp_assays')
    # %sql \
        drop table if exists temp_assays
    # %sql \
        create table temp_assays as \
        select assay_id, assays.chembl_id assay_chembl_id, assays.description assay_desc, assays.doc_id assay_doc_id, variant_id, \
        docs.year doc_date, docs.chembl_id doc_chembl_id, \
        tid, accession, target_type, target_pref_name, target_chembl_id, \
        count(distinct(molregno)) cnt \
        from activities \
        join assays using(assay_id) \
        join docs on (assays.doc_id = docs.doc_id) \
        join temp_targets using (tid) \
        where standard_type =:standard_type \
        and pchembl_value is not null \
        group by tid, assay_doc_id, assay_id \
        order by cnt desc;
    print(f"The shape of temp_assays is {pd.read_sql('select * from temp_assays', con=conn).shape}")

    # now remove rows for assays which are not compatible without curation steps
    print('check onlyDocs')
    if onlyDocs:
        # %sql \
            delete from temp_assays where doc_date is null;

    print('check removeMutants')
    if removeMutants:
        # %sql \
            delete from temp_assays where variant_id is not null or lower(assay_desc) like '%mutant%'\
                or lower(assay_desc) like '%mutantion%' or lower(assay_desc) like '%variant%';
                
    print('check confidenceScore')
    # filter out assays with confidence score less than confidenceScore
    # %sql \
        drop table if exists temp_assays_filtered;
    # %sql \
        create table temp_assays_filtered as \
        select ta.*, confidence_score from temp_assays ta \
            join assays using(assay_id) \
            where confidence_score >= :confidenceScore;  
    print(f"The shape of temp_assays_filtered is {pd.read_sql('select * from temp_assays_filtered', con=conn).shape}")
    
    # select activities from the assays we've identified which have between less than maxAssaySize tested compounds --> delete this condition because we are creating a benchmark dataset
    # why are 'pchembl_value' and 'standard_type' used here again? because here join table 'activities' again only on 'assay_id'.
    print('temp_acts')
    # %sql \
        drop table if exists temp_acts
    # %sql \
        create table temp_acts as \
        select assay_id, assay_chembl_id, tid, target_chembl_id,molregno,pchembl_value,doc_chembl_id,standard_type,activity_id \
        from activities \
        join temp_assays_filtered using (assay_id)\
        where standard_type =:standard_type  
    print(f"The shape of temp_acts is {pd.read_sql('select * from temp_acts', con=conn).shape}")

    # count the number of unique compounds in each assay_id
    # `group by`statemenet groups rows that have the same values into summary rows
    print('temp_acts_counts')
    # %sql \
        drop table if exists temp_acts_counts
    # %sql \
        create table temp_acts_counts as \
        select assay_id, assay_chembl_id, ta.tid, target_chembl_id, count(distinct molregno) cnt, doc_chembl_id \
        from temp_acts ta \
        join assays using (assay_id) \
        group by assay_chembl_id, target_chembl_id, doc_chembl_id \
        order by cnt desc;
    print(f"The shape of temp_acts_counts is {pd.read_sql('select * from temp_acts_counts', con=conn).shape}")
    
    # count the number of unique assays for each target
    print('temp_targets_counts')
    # %sql \
        drop table if exists temp_targets_counts
    # %sql \
        create table temp_targets_counts as \
        select tid, target_chembl_id, count(distinct assay_chembl_id) target_assay_count, sum(cnt) target_compound_count \
        from temp_acts_counts tac \
        group by target_chembl_id \
        order by target_assay_count desc;
    print(f"The shape of temp_targets_counts is {pd.read_sql('select * from temp_targets_counts', con=conn).shape}")

def append_assay_info(readout = 'Ki',uniprot_id = gpcr_uniprot_ids_list,
                      onlyDocs=True,removeMutants=True,confidenceScore=8):
    '''
    Append the assay information to the output of function gather_data_for_size
    '''
    
    gather_data_for_size(uniprot_id=uniprot_id,standard_type=readout,
                         onlyDocs=onlyDocs,removeMutants=removeMutants,confidenceScore=confidenceScore)

    print (f'raw_data for {readout}')
    
    # %sql \
        drop table if exists raw_data
    raw_data = %sql \
        select assay_id, ta_1.assay_chembl_id, ta_1.tid, ta_1.target_chembl_id, standard_type, standard_relation, standard_value, standard_units, pchembl_value, \
        assay_type,assay_category,assay_organism, assay_tax_id, assay_strain, assay_tissue, assay_cell_type, assay_subcellular_fraction, bao_format, ta_1.variant_id, assay_test_type, \
        assay_desc, cell_id, tissue_id, curated_by, relationship_type, aidx, \
        ta_1.confidence_score, molregno, cid.chembl_id compound_chembl_id,canonical_smiles \
        from activities \
        join temp_assays_filtered ta_1 using (assay_id) \
        join temp_targets_counts using (tid) \
        join temp_acts_counts using (assay_id) \
        join assays using (assay_id) \
        join chembl_id_lookup cid on (entity_type='COMPOUND' and molregno=entity_id) \
        join compound_structures using (molregno) \
        where pchembl_value is not null \
        and standard_type=:readout;

    return raw_data
    
def hash_assay_info(raw_data, sel_cols:List[str]=['assay_type', 'assay_organism', 'assay_category',
                                                    'assay_tax_id','assay_strain','assay_tissue',
                                                    'assay_cell_type','assay_subcellular_fraction',
                                                    'bao_format', 'variant_id']):
    '''
    For the retrieved data from the database, concatenate the columns related to assay info, hash these values, and convert the data into a pandas dataframe.

    params:
        raw_data: The retrieved data from the database.
        sel_cols: A list of column names to be used for hashing.

    Returns:
        A pandas DataFrame with the original data and an additional 'assay_info_hash' column.

    The string in the sel_cols can be the below:
    'assay_type','assay_organism','assay_category',
    'assay_tax_id','assay_strain','assay_tissue',
    'assay_cell_type','assay_subcellular_fraction','bao_format','variant_id'
    '''

    processed_data = []
    for row in raw_data:
        original_data= [str(value) for value in row]
        # concatenate certain fields and hash
        assay_fields = ''.join([str(row[col]) for col in sel_cols])  # Add all fields you need
        hash_result = hashlib.md5(assay_fields.encode()).hexdigest()
        original_data.append(hash_result)
        processed_data.append(tuple(original_data))

    print(f'The length of the processed_data is {len(processed_data)}')

    return processed_data

# %% [markdown]
# ## IC50

# %%
readout = 'IC50'
print(f'raw_data for {readout}_maxcuration')
raw_data = append_assay_info(readout=readout, uniprot_id=gpcr_uniprot_ids_list,
                             onlyDocs=True,removeMutants=True,confidenceScore=8)
ic50_maxcur_8_data = hash_assay_info(raw_data)
# Out:
# raw_data for IC50_maxcuration
# table temp_targets
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets is (381, 6)
# table temp_assays
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays is (9299, 13)
# check onlyDocs
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 124 rows affected.
# check removeMutants
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 232 rows affected.
# check confidenceScore
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays_filtered is (8943, 14)
# temp_acts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts is (115602, 9)
# temp_acts_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts_counts is (8943, 6)
# temp_targets_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets_counts is (242, 4)
# raw_data for IC50
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The length of the processed_data is 99857

# %% [markdown]
# ## Ki

# %%
readout = 'Ki'
print(f'raw_data for {readout}_maxcuration')
raw_data = append_assay_info(readout=readout, uniprot_id=gpcr_uniprot_ids_list,
                             onlyDocs=True,removeMutants=True,confidenceScore=8)
ki_maxcur_8_data = hash_assay_info(raw_data)
# Out:
# raw_data for Ki_maxcuration
# table temp_targets
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets is (381, 6)
# table temp_assays
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays is (14519, 13)
# check onlyDocs
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 59 rows affected.
# check removeMutants
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 181 rows affected.
# check confidenceScore
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays_filtered is (14279, 14)
# temp_acts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts is (169245, 9)
# temp_acts_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts_counts is (14279, 6)
# temp_targets_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets_counts is (194, 4)
# raw_data for Ki
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The length of the processed_data is 147777

# %% [markdown]
# ## EC50

# %%
readout = 'EC50'
print(f'raw_data for {readout}_maxcuration')
raw_data = append_assay_info(readout=readout, uniprot_id=gpcr_uniprot_ids_list,
                             onlyDocs=True,removeMutants=True,confidenceScore=8)
ec50_maxcur_8_data = hash_assay_info(raw_data)
# Out:
# raw_data for EC50_maxcuration
# table temp_targets
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets is (381, 6)
# table temp_assays
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays is (6008, 13)
# check onlyDocs
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 67 rows affected.
# check removeMutants
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# 209 rows affected.
# check confidenceScore
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_assays_filtered is (5732, 14)
# temp_acts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts is (75694, 9)
# temp_acts_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_acts_counts is (5732, 6)
# temp_targets_counts
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The shape of temp_targets_counts is (225, 4)
# raw_data for EC50
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
# The length of the processed_data is 60626

# %% [markdown]
# ## Write data

# %% [markdown]
# ### GPCR_type

# %%
def write_data(data, filename:str, columns=['assay_id', 'assay_chembl_id', 'tid', 'target_chembl_id', 'standard_type', 'standard_relation', 'standard_value', 'standard_units', 'pchembl_value', 
                                   'assay_type', 'assay_category', # checkpoint 1
                                   'assay_organism', 'assay_tax_id', 'assay_strain', 'assay_tissue', 'assay_cell_type', 'assay_subcellular_fraction', 'bao_format', 'variant_id', 'assay_test_type', 
                                   'assay_desc', 'cell_id', 'tissue_id', 'curated_by', 'relationship_type', 'aidx', 
                                   'confidence_score', 'molregno', 'compound_chembl_id', 'canonical_smiles', 'assay_info_hash']):
    """Save the data to a pandas dataframe"""

    data_df = pd.DataFrame(data, columns=columns)
    
    # write the data to a csv file
    data_df.to_csv(f'{FETCH_DATA_DIR}/{filename}.csv',index=False)
    
    return data_df

# %%
ic50_maxcur_df = write_data(ic50_maxcur_8_data, 'EC50_gpcr_maxcur_8_data')
ki_maxcur_df = write_data(ki_maxcur_8_data, 'Ki_gpcr_maxcur_8_data')
ec50_maxcur_df = write_data(ec50_maxcur_8_data, 'EC50_gpcr_maxcur_8_data')

# %% [markdown]
# ### datapoints with unique 'assay_hash_info'

# %%
# only for dataset with maxcuration
def write_data_uniq_cond(df, min_dataset_size=100, readout='IC50', curation='maxcur'):
    """
    write the datasets with unique combinations of 'target_chembl_id' and 'assay_info_hash'
    """
    yaml=[]
    
    collected_data = defaultdict(list)
    assay_cond_accum = defaultdict(list)
    assay_accum = defaultdict(set)

    for i, row in df.iterrows():
        assay_info_hash = row['assay_info_hash']
        target_chembl_id = row['target_chembl_id']
        assay_chembl_id = row['assay_chembl_id']

        # append all columns to the collected_data
        collected_data[(target_chembl_id, assay_info_hash)].append(row.values)
        assay_cond_accum[target_chembl_id].append(assay_info_hash)
        assay_accum[(target_chembl_id,assay_info_hash)].add(assay_chembl_id)

    sets_to_keep = [k for k, v in collected_data.items() if len(v) >= min_dataset_size]
    for k in assay_cond_accum:
        assay_cond_accum[k] = [y for y in assay_cond_accum[k] if (k, y) in sets_to_keep]

    for target_chembl_id, conds in collected_data.keys():
        if (target_chembl_id, conds) not in sets_to_keep:
            continue
        rows = collected_data[(target_chembl_id, conds)]
        cols = np.array(rows).transpose()
        cond_idx = assay_cond_accum[target_chembl_id].index(conds)+1

        columns = df.columns
        df = pd.DataFrame(dict(zip(columns, cols)))
        fname = f'{readout}_target_{target_chembl_id}_{cond_idx}.csv'
        filepath = os.path.join(FETCH_DATA_DIR, f'{readout}_{curation}')
        mkdirs(filepath)
        df.to_csv(os.path.join(filepath, fname), index=False)

        minAct = min(df.pchembl_value)
        maxAct = max(df.pchembl_value)
        medAct = np.median(pd.to_numeric(df.pchembl_value, errors='coerce'))
        actType = readout
        targetd = %sql \
        select * from target_dictionary  \
            where chembl_id=:target_chembl_id
        targetd = dict(targetd[0])    
        template=f'''  {target_chembl_id}-{cond_idx}:
        description: "Target {target_chembl_id}: {targetd['pref_name']}"
        args:
        filename: '{{{{ CATALOG_DIR }}}}/source_data/{fname}'
        smilesColumn: canonical_smiles
        metadata:
        url: https://www.ebi.ac.uk/chembl/target_report_card/{target_chembl_id}/
        source: ChEMBL_32
        target_organism: {targetd['organism']}
        assays_included: {','.join(assay_accum[(target_chembl_id,conds)])}
        num_points: {len(rows)}
        activity_type: {actType}
        min pchembl_value: {float(minAct):.2f}
        max pchembl_value: {float(maxAct):.2f}
        median pchembl_value: {float(medAct):.2f}
        driver: intake_rdkit.smiles.SmilesSource
        '''
        yaml.append(template)
    print('\n'.join(yaml))
    with open(os.path.join(FETCH_DATA_DIR, f'{readout}_{curation}', f'{readout}_{curation}_datasets.yaml'),'w+') as outf:
        header=f'''metadata:

    summary: |
        Collection of {readout} datasets with pchembl_values for bioactivity prediction.
        
    sources:'''
        print(header,file=outf)
        print('\n'.join(yaml),file=outf)

# %%
write_data_uniq_cond(ic50_maxcur_df, min_dataset_size=100, readout='IC50', curation='maxcur')
write_data_uniq_cond(ki_maxcur_df, min_dataset_size=100, readout='Ki', curation='maxcur')
write_data_uniq_cond(ec50_maxcur_df, min_dataset_size=100, readout='EC50', curation='maxcur')
# Out:
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#  * sqlite:////storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/chembl_34_sqlite/chembl_34.db
# Done.
#   CHEMBL252-1:
#         description: "Target CHEMBL252: Endothelin receptor ET-A"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL252_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL252/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL873602,CHEMBL681512,CHEMBL678229,CHEMBL679122,CHEMBL677305,CHEMBL681514,CHEMBL682365,CHEMBL682100,CHEMBL677091,CHEMBL876873,CHEMBL677307,CHEMBL679837,CHEMBL677308,CHEMBL682970,CHEMBL682360,CHEMBL677303,CHEMBL682971,CHEMBL677260,CHEMBL682356,CHEMBL682359,CHEMBL678230,CHEMBL682969,CHEMBL681515,CHEMBL682366,CHEMBL682358,CHEMBL682110,CHEMBL682108,CHEMBL681509,CHEMBL682364,CHEMBL677304
#         num_points: 446
#         activity_type: IC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.96
#         median pchembl_value: 7.52
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1785-1:
#         description: "Target CHEMBL1785: Endothelin receptor ET-B"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1785_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1785/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL878153,CHEMBL678456,CHEMBL670643,CHEMBL672254,CHEMBL670477,CHEMBL670638,CHEMBL677443,CHEMBL670476,CHEMBL670478,CHEMBL670651,CHEMBL678457,CHEMBL670640,CHEMBL670653,CHEMBL673747,CHEMBL676633,CHEMBL670650,CHEMBL677268,CHEMBL670644,CHEMBL677448,CHEMBL670652,CHEMBL670635
#         num_points: 282
#         activity_type: IC50
#         min pchembl_value: 4.01
#         max pchembl_value: 9.57
#         median pchembl_value: 5.84
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL4561-1:
#         description: "Target CHEMBL4561: Neuropeptide Y receptor type 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL4561_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL4561/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL750824,CHEMBL755165,CHEMBL750996,CHEMBL752046,CHEMBL750834,CHEMBL750833,CHEMBL750823,CHEMBL750832,CHEMBL750995,CHEMBL752047
#         num_points: 119
#         activity_type: IC50
#         min pchembl_value: 6.05
#         max pchembl_value: 9.64
#         median pchembl_value: 7.57
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1855-1:
#         description: "Target CHEMBL1855: Gonadotropin-releasing hormone receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1855_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1855/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL871108,CHEMBL831490,CHEMBL711950,CHEMBL1804380,CHEMBL3375484,CHEMBL1804376
#         num_points: 110
#         activity_type: IC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.92
#         median pchembl_value: 9.22
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL298-1:
#         description: "Target CHEMBL298: Cholecystokinin B receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL298_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL298/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL653979,CHEMBL657479,CHEMBL656249,CHEMBL662567,CHEMBL662575,CHEMBL657476,CHEMBL657472,CHEMBL661925,CHEMBL657474,CHEMBL662565,CHEMBL656242,CHEMBL662568,CHEMBL662564,CHEMBL660023,CHEMBL656243,CHEMBL662561,CHEMBL657477,CHEMBL653980,CHEMBL656244,CHEMBL662559,CHEMBL662563,CHEMBL660029,CHEMBL657483,CHEMBL662573,CHEMBL663098,CHEMBL657475,CHEMBL662566,CHEMBL662569,CHEMBL662562,CHEMBL661926,CHEMBL652235,CHEMBL657484
#         num_points: 430
#         activity_type: IC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.62
#         median pchembl_value: 6.57
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL227-1:
#         description: "Target CHEMBL227: Type-1 angiotensin II receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL227_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL227/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL648564,CHEMBL650307,CHEMBL650308,CHEMBL647574,CHEMBL648566,CHEMBL652865,CHEMBL1670336,CHEMBL647576,CHEMBL648568,CHEMBL648562,CHEMBL648492,CHEMBL648565,CHEMBL1949356,CHEMBL1069624,CHEMBL647575,CHEMBL648563,CHEMBL650315,CHEMBL2161529
#         num_points: 168
#         activity_type: IC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.77
#         median pchembl_value: 8.39
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1804-1:
#         description: "Target CHEMBL1804: Somatostatin receptor 2"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1804_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1804/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL806163,CHEMBL806164,CHEMBL807088,CHEMBL801246,CHEMBL807087,CHEMBL807428,CHEMBL806165
#         num_points: 112
#         activity_type: IC50
#         min pchembl_value: 5.59
#         max pchembl_value: 8.64
#         median pchembl_value: 6.76
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL2028-1:
#         description: "Target CHEMBL2028: Somatostatin receptor 3"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL2028_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL2028/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL807103,CHEMBL807102,CHEMBL801248,CHEMBL803847,CHEMBL807105,CHEMBL807104
#         num_points: 112
#         activity_type: IC50
#         min pchembl_value: 5.51
#         max pchembl_value: 8.51
#         median pchembl_value: 6.49
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1853-1:
#         description: "Target CHEMBL1853: Somatostatin receptor 4"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1853_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1853/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL807048,CHEMBL807046,CHEMBL803857,CHEMBL873241,CHEMBL801249,CHEMBL807047,CHEMBL807045,CHEMBL884900,CHEMBL803855
#         num_points: 140
#         activity_type: IC50
#         min pchembl_value: 10.10
#         max pchembl_value: 9.29
#         median pchembl_value: 8.05
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1792-1:
#         description: "Target CHEMBL1792: Somatostatin receptor 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1792_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1792/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL806597,CHEMBL807063,CHEMBL945054,CHEMBL801251,CHEMBL806596,CHEMBL807065,CHEMBL882393,CHEMBL883371,CHEMBL807064
#         num_points: 117
#         activity_type: IC50
#         min pchembl_value: 5.43
#         max pchembl_value: 9.40
#         median pchembl_value: 6.70
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1855-5:
#         description: "Target CHEMBL1855: Gonadotropin-releasing hormone receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1855_5.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1855/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL685986,CHEMBL684238,CHEMBL684242,CHEMBL709251,CHEMBL709252,CHEMBL685982,CHEMBL684347,CHEMBL684239,CHEMBL2160774,CHEMBL685984,CHEMBL871112,CHEMBL684348,CHEMBL685985
#         num_points: 123
#         activity_type: IC50
#         min pchembl_value: 5.70
#         max pchembl_value: 9.70
#         median pchembl_value: 9.05
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL4561-3:
#         description: "Target CHEMBL4561: Neuropeptide Y receptor type 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL4561_3.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL4561/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL750829,CHEMBL1043093,CHEMBL1074018,CHEMBL882034,CHEMBL857550
#         num_points: 104
#         activity_type: IC50
#         min pchembl_value: 6.55
#         max pchembl_value: 9.27
#         median pchembl_value: 8.45
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL255-1:
#         description: "Target CHEMBL255: Adenosine A2b receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL255_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL255/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3756030,CHEMBL901021,CHEMBL4628744,CHEMBL939195,CHEMBL1037719,CHEMBL1936207,CHEMBL1014570,CHEMBL3379789,CHEMBL3878905,CHEMBL874953,CHEMBL1959510,CHEMBL4322429,CHEMBL4628751,CHEMBL2320330,CHEMBL4189479,CHEMBL2034749,CHEMBL3757839,CHEMBL1120803,CHEMBL1175305,CHEMBL4156074,CHEMBL4407534,CHEMBL1764849,CHEMBL3802558,CHEMBL862545,CHEMBL1931872,CHEMBL639471,CHEMBL2073181,CHEMBL639467
#         num_points: 289
#         activity_type: IC50
#         min pchembl_value: 4.30
#         max pchembl_value: 9.47
#         median pchembl_value: 6.91
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL250-1:
#         description: "Target CHEMBL250: Platelet activating factor receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL250_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL250/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL760446,CHEMBL764096,CHEMBL764537,CHEMBL764098,CHEMBL764095,CHEMBL880989,CHEMBL764538,CHEMBL764097
#         num_points: 116
#         activity_type: IC50
#         min pchembl_value: 10.82
#         max pchembl_value: 9.00
#         median pchembl_value: 6.17
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL249-1:
#         description: "Target CHEMBL249: Neurokinin 1 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL249_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL249/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL807903,CHEMBL748656,CHEMBL807904,CHEMBL821389,CHEMBL747297,CHEMBL872729,CHEMBL748487,CHEMBL807899,CHEMBL807959,CHEMBL751717,CHEMBL748490,CHEMBL749394,CHEMBL813804,CHEMBL747305,CHEMBL807907,CHEMBL751900,CHEMBL751718,CHEMBL882327,CHEMBL812541,CHEMBL807961,CHEMBL749780,CHEMBL749536,CHEMBL873470,CHEMBL807958,CHEMBL812334,CHEMBL748491,CHEMBL749392,CHEMBL747298,CHEMBL807967,CHEMBL809504,CHEMBL752058,CHEMBL807906
#         num_points: 497
#         activity_type: IC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.96
#         median pchembl_value: 7.87
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3911-1:
#         description: "Target CHEMBL3911: Leukotriene B4 receptor 1"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL3911_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3911/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL879635,CHEMBL706922,CHEMBL705075,CHEMBL704425,CHEMBL706533,CHEMBL709304,CHEMBL706534,CHEMBL706535,CHEMBL704426,CHEMBL704428,CHEMBL708406,CHEMBL705074,CHEMBL879502,CHEMBL707239,CHEMBL704422,CHEMBL708407,CHEMBL706537,CHEMBL709307,CHEMBL704427,CHEMBL707242,CHEMBL707241,CHEMBL709312,CHEMBL709303,CHEMBL704424,CHEMBL709308,CHEMBL706536,CHEMBL704430,CHEMBL708405
#         num_points: 112
#         activity_type: IC50
#         min pchembl_value: 5.24
#         max pchembl_value: 8.89
#         median pchembl_value: 7.30
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL274-1:
#         description: "Target CHEMBL274: C-C chemokine receptor type 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL274_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL274/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL956846,CHEMBL693290,CHEMBL659084,CHEMBL665164,CHEMBL659086,CHEMBL654653,CHEMBL661604,CHEMBL649936,CHEMBL1912866,CHEMBL873385,CHEMBL1821334,CHEMBL654652,CHEMBL661605,CHEMBL654655,CHEMBL659083,CHEMBL693289,CHEMBL654654,CHEMBL1107772
#         num_points: 459
#         activity_type: IC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.89
#         median pchembl_value: 8.30
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL4607-1:
#         description: "Target CHEMBL4607: Angiotensin II type 2 (AT-2) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL4607_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL4607/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL643596,CHEMBL996322,CHEMBL1949357,CHEMBL647511,CHEMBL647510,CHEMBL643595,CHEMBL647512,CHEMBL643594,CHEMBL649910,CHEMBL643597,CHEMBL876769,CHEMBL647513,CHEMBL1670671
#         num_points: 147
#         activity_type: IC50
#         min pchembl_value: 5.00
#         max pchembl_value: 9.92
#         median pchembl_value: 7.70
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL214-1:
#         description: "Target CHEMBL214: Serotonin 1a (5-HT1a) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL214_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL214/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL1285517,CHEMBL615580,CHEMBL616219,CHEMBL615579,CHEMBL615934,CHEMBL615746,CHEMBL857064,CHEMBL1827736,CHEMBL857073,CHEMBL616220,CHEMBL615747,CHEMBL616218,CHEMBL921839,CHEMBL965244,CHEMBL1069075,CHEMBL1101345,CHEMBL923690,CHEMBL616244,CHEMBL616216,CHEMBL616359,CHEMBL1046701,CHEMBL616273
#         num_points: 136
#         activity_type: IC50
#         min pchembl_value: 4.01
#         max pchembl_value: 9.89
#         median pchembl_value: 6.32
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL224-1:
#         description: "Target CHEMBL224: Serotonin 2a (5-HT2a) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL224_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL224/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL617334,CHEMBL1285519,CHEMBL920900,CHEMBL616249,CHEMBL945451,CHEMBL882924,CHEMBL1046702,CHEMBL962308,CHEMBL617357,CHEMBL617354,CHEMBL617355,CHEMBL643237,CHEMBL617399,CHEMBL872339,CHEMBL923692,CHEMBL617392,CHEMBL881489,CHEMBL925072
#         num_points: 102
#         activity_type: IC50
#         min pchembl_value: 4.55
#         max pchembl_value: 9.21
#         median pchembl_value: 6.42
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL298-17:
#         description: "Target CHEMBL298: Cholecystokinin B receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL298_17.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL298/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL682555,CHEMBL656247,CHEMBL658773,CHEMBL657478,CHEMBL657480,CHEMBL682554,CHEMBL857378,CHEMBL657473,CHEMBL656248,CHEMBL662570,CHEMBL657471,CHEMBL657470
#         num_points: 225
#         activity_type: IC50
#         min pchembl_value: 4.00
#         max pchembl_value: 9.85
#         median pchembl_value: 7.10
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL233-1:
#         description: "Target CHEMBL233: Mu opioid receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL233_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL233/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL872833,CHEMBL749747,CHEMBL744603,CHEMBL749746,CHEMBL757059,CHEMBL757823,CHEMBL961463,CHEMBL749744,CHEMBL757307,CHEMBL980777,CHEMBL756439,CHEMBL757306,CHEMBL754684,CHEMBL935652,CHEMBL874639,CHEMBL757060,CHEMBL756578,CHEMBL948139
#         num_points: 206
#         activity_type: IC50
#         min pchembl_value: 4.11
#         max pchembl_value: 9.19
#         median pchembl_value: 6.11
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL236-1:
#         description: "Target CHEMBL236: Delta opioid receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL236_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL236/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL980775,CHEMBL756176,CHEMBL756175,CHEMBL750416,CHEMBL750419,CHEMBL750412,CHEMBL750411,CHEMBL750421,CHEMBL750415,CHEMBL750413,CHEMBL750420,CHEMBL756174,CHEMBL751925,CHEMBL961464,CHEMBL750410
#         num_points: 161
#         activity_type: IC50
#         min pchembl_value: 5.03
#         max pchembl_value: 9.89
#         median pchembl_value: 7.43
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL249-10:
#         description: "Target CHEMBL249: Neurokinin 1 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL249_10.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL249/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL749779,CHEMBL749477,CHEMBL745040,CHEMBL981109,CHEMBL812171,CHEMBL814181,CHEMBL809501,CHEMBL813331,CHEMBL745034,CHEMBL872831,CHEMBL807971,CHEMBL873267,CHEMBL809503,CHEMBL745039,CHEMBL809497,CHEMBL814769,CHEMBL814770,CHEMBL813805,CHEMBL1013871,CHEMBL880850,CHEMBL747301,CHEMBL750227,CHEMBL807956,CHEMBL812544,CHEMBL749476
#         num_points: 304
#         activity_type: IC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.77
#         median pchembl_value: 7.56
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL237-1:
#         description: "Target CHEMBL237: Kappa opioid receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL237_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL237/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL1112311,CHEMBL751988,CHEMBL882039,CHEMBL751992,CHEMBL756112,CHEMBL980776,CHEMBL751987,CHEMBL751990,CHEMBL751993,CHEMBL756114,CHEMBL751989
#         num_points: 189
#         activity_type: IC50
#         min pchembl_value: 4.43
#         max pchembl_value: 9.16
#         median pchembl_value: 6.10
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3473-1:
#         description: "Target CHEMBL3473: C-C chemokine receptor type 3"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL3473_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3473/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL650505,CHEMBL652233,CHEMBL1019589,CHEMBL650420,CHEMBL650419,CHEMBL2184862,CHEMBL650504,CHEMBL662157,CHEMBL982456,CHEMBL843659,CHEMBL2184879,CHEMBL650502
#         num_points: 191
#         activity_type: IC50
#         min pchembl_value: 4.48
#         max pchembl_value: 9.92
#         median pchembl_value: 7.30
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3157-1:
#         description: "Target CHEMBL3157: Bradykinin B2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL3157_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3157/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL884128,CHEMBL653418,CHEMBL653423,CHEMBL653425,CHEMBL653424
#         num_points: 165
#         activity_type: IC50
#         min pchembl_value: 5.04
#         max pchembl_value: 9.77
#         median pchembl_value: 8.40
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL252-22:
#         description: "Target CHEMBL252: Endothelin receptor ET-A"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL252_22.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL252/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL682361,CHEMBL682972,CHEMBL873596,CHEMBL682967,CHEMBL2166382,CHEMBL682973,CHEMBL681510
#         num_points: 186
#         activity_type: IC50
#         min pchembl_value: 10.11
#         max pchembl_value: 9.96
#         median pchembl_value: 7.61
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1785-10:
#         description: "Target CHEMBL1785: Endothelin receptor ET-B"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL1785_10.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1785/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL670655,CHEMBL2166381,CHEMBL677449,CHEMBL670645,CHEMBL672255,CHEMBL677441
#         num_points: 161
#         activity_type: IC50
#         min pchembl_value: 5.02
#         max pchembl_value: 9.85
#         median pchembl_value: 6.34
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL213-1:
#         description: "Target CHEMBL213: Beta-1 adrenergic receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/IC50_target_CHEMBL213_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL213/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
# ...
#         median pchembl_value: 6.47
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL5652-728:
#         description: "Target CHEMBL5652: Glucose-dependent insulinotropic receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL5652_728.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL5652/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3889243,CHEMBL3887259
#         num_points: 381
#         activity_type: EC50
#         min pchembl_value: 5.03
#         max pchembl_value: 8.70
#         median pchembl_value: 6.61
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL237-578:
#         description: "Target CHEMBL237: Kappa opioid receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL237_578.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL237/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3887304,CHEMBL3888048,CHEMBL3887477,CHEMBL3888606,CHEMBL3887794
#         num_points: 128
#         activity_type: EC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.96
#         median pchembl_value: 7.23
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL4333-1279:
#         description: "Target CHEMBL4333: Sphingosine 1-phosphate receptor Edg-1"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL4333_1279.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL4333/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3887321
#         num_points: 152
#         activity_type: EC50
#         min pchembl_value: 4.71
#         max pchembl_value: 8.70
#         median pchembl_value: 6.33
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1784-122:
#         description: "Target CHEMBL1784: Glucagon-like peptide 1 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1784_122.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1784/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3887456
#         num_points: 234
#         activity_type: EC50
#         min pchembl_value: 6.07
#         max pchembl_value: 8.70
#         median pchembl_value: 6.91
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3227-367:
#         description: "Target CHEMBL3227: Metabotropic glutamate receptor 5"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3227_367.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3227/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888360,CHEMBL3888312,CHEMBL3888543,CHEMBL3887717,CHEMBL3887806
#         num_points: 227
#         activity_type: EC50
#         min pchembl_value: 6.01
#         max pchembl_value: 8.15
#         median pchembl_value: 7.42
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL218-716:
#         description: "Target CHEMBL218: Cannabinoid CB1 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL218_716.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL218/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888023
#         num_points: 156
#         activity_type: EC50
#         min pchembl_value: 5.01
#         max pchembl_value: 8.52
#         median pchembl_value: 6.92
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL253-1466:
#         description: "Target CHEMBL253: Cannabinoid CB2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL253_1466.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL253/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888845,CHEMBL3888839,CHEMBL3888087,CHEMBL3888278
#         num_points: 950
#         activity_type: EC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.70
#         median pchembl_value: 7.39
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL218-872:
#         description: "Target CHEMBL218: Cannabinoid CB1 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL218_872.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL218/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888088,CHEMBL3888846,CHEMBL3888840,CHEMBL3888279
#         num_points: 125
#         activity_type: EC50
#         min pchembl_value: 5.00
#         max pchembl_value: 8.24
#         median pchembl_value: 6.21
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL2010631-1:
#         description: "Target CHEMBL2010631: C-X-C chemokine receptor type 7"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL2010631_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL2010631/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL3888966
#         num_points: 501
#         activity_type: EC50
#         min pchembl_value: 5.56
#         max pchembl_value: 9.40
#         median pchembl_value: 7.92
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL217-295:
#         description: "Target CHEMBL217: Dopamine D2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL217_295.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL217/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4345332,CHEMBL4236721,CHEMBL4394473,CHEMBL4344305,CHEMBL4371565,CHEMBL4339975,CHEMBL4000284,CHEMBL4368228,CHEMBL4008740
#         num_points: 108
#         activity_type: EC50
#         min pchembl_value: 10.02
#         max pchembl_value: 9.43
#         median pchembl_value: 7.71
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1821-109:
#         description: "Target CHEMBL1821: Muscarinic acetylcholine receptor M4"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1821_109.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1821/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4046910,CHEMBL4035868,CHEMBL4030176,CHEMBL4306809,CHEMBL4306810
#         num_points: 179
#         activity_type: EC50
#         min pchembl_value: 5.00
#         max pchembl_value: 8.52
#         median pchembl_value: 6.67
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3297639-1:
#         description: "Target CHEMBL3297639: Probable G-protein coupled receptor 52"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3297639_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3297639/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4034862,CHEMBL4806971
#         num_points: 228
#         activity_type: EC50
#         min pchembl_value: 5.41
#         max pchembl_value: 8.97
#         median pchembl_value: 8.96
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL214-135:
#         description: "Target CHEMBL214: Serotonin 1a (5-HT1a) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL214_135.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL214/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4707449,CHEMBL4670405,CHEMBL4670409,CHEMBL4229840,CHEMBL4195140,CHEMBL4409670,CHEMBL4119509,CHEMBL4707453,CHEMBL4230000,CHEMBL4709855,CHEMBL5146498,CHEMBL5146487
#         num_points: 101
#         activity_type: EC50
#         min pchembl_value: 10.06
#         max pchembl_value: 9.95
#         median pchembl_value: 7.39
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1875-132:
#         description: "Target CHEMBL1875: Serotonin 4 (5-HT4) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1875_132.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1875/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL5223843,CHEMBL4189919,CHEMBL4189943,CHEMBL5223929
#         num_points: 113
#         activity_type: EC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.52
#         median pchembl_value: 7.44
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL225-630:
#         description: "Target CHEMBL225: Serotonin 2c (5-HT2c) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL225_630.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL225/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4363107,CHEMBL4681101,CHEMBL4681089
#         num_points: 132
#         activity_type: EC50
#         min pchembl_value: 5.28
#         max pchembl_value: 9.87
#         median pchembl_value: 7.62
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL217-507:
#         description: "Target CHEMBL217: Dopamine D2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL217_507.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL217/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4392174,CHEMBL4394480,CHEMBL4397361,CHEMBL4406526,CHEMBL4394476,CHEMBL4392184
#         num_points: 114
#         activity_type: EC50
#         min pchembl_value: 4.31
#         max pchembl_value: 9.22
#         median pchembl_value: 6.31
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL234-1:
#         description: "Target CHEMBL234: Dopamine D3 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL234_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL234/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4406544,CHEMBL4406074,CHEMBL4392188,CHEMBL4397359,CHEMBL4406524
#         num_points: 111
#         activity_type: EC50
#         min pchembl_value: 4.66
#         max pchembl_value: 8.59
#         median pchembl_value: 6.70
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3714130-1:
#         description: "Target CHEMBL3714130: G-protein coupled receptor 6"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3714130_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3714130/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL5039193,CHEMBL4418470,CHEMBL4742497,CHEMBL4739759
#         num_points: 350
#         activity_type: EC50
#         min pchembl_value: 4.00
#         max pchembl_value: 7.78
#         median pchembl_value: 6.70
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL1832-1:
#         description: "Target CHEMBL1832: Calcitonin receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL1832_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL1832/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4421026,CHEMBL4421024
#         num_points: 186
#         activity_type: EC50
#         min pchembl_value: 10.00
#         max pchembl_value: 9.99
#         median pchembl_value: 10.43
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3632455-1:
#         description: "Target CHEMBL3632455: Probable G-protein coupled receptor 139"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3632455_1.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3632455/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4739806
#         num_points: 104
#         activity_type: EC50
#         min pchembl_value: 8.00
#         max pchembl_value: 9.00
#         median pchembl_value: 9.00
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL3632455-105:
#         description: "Target CHEMBL3632455: Probable G-protein coupled receptor 139"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL3632455_105.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL3632455/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4742409,CHEMBL4810043
#         num_points: 120
#         activity_type: EC50
#         min pchembl_value: 5.82
#         max pchembl_value: 8.22
#         median pchembl_value: 7.61
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL217-696:
#         description: "Target CHEMBL217: Dopamine D2 receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL217_696.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL217/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL4842093,CHEMBL5151480,CHEMBL4815488,CHEMBL4842103,CHEMBL4842095
#         num_points: 195
#         activity_type: EC50
#         min pchembl_value: 5.27
#         max pchembl_value: 8.99
#         median pchembl_value: 7.80
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL224-181:
#         description: "Target CHEMBL224: Serotonin 2a (5-HT2a) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL224_181.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL224/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL5135838
#         num_points: 196
#         activity_type: EC50
#         min pchembl_value: 5.10
#         max pchembl_value: 9.46
#         median pchembl_value: 6.56
#         driver: intake_rdkit.smiles.SmilesSource
#
#   CHEMBL225-792:
#         description: "Target CHEMBL225: Serotonin 2c (5-HT2c) receptor"
#         args:
#         filename: '{{ CATALOG_DIR }}/source_data/EC50_target_CHEMBL225_792.csv'
#         smilesColumn: canonical_smiles
#         metadata:
#         url: https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL225/
#         source: ChEMBL_32
#         target_organism: Homo sapiens
#         assays_included: CHEMBL5135840
#         num_points: 188
#         activity_type: EC50
#         min pchembl_value: 4.75
#         max pchembl_value: 9.49
#         median pchembl_value: 6.76
#         driver: intake_rdkit.smiles.SmilesSource
