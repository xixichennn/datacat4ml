# %%
# conda env: datacat (Python 3.8.20)
import os
import csv
import random
import json
from collections import defaultdict
import shutil

import pandas as pd
from datacat4ml.const import CURA_CAT_GPCR_DIR, CURA_CAT_OR_DIR, OR_chemblids, SPLIT_DATA_DIR
from datacat4ml.Scripts.data_prep.data_curate.utils.apply_thresholds import apply_thresholds

# %% [markdown]
# # Read MHDs from `CURA_CAT_GPCR_DIR` and `CURA_CAT_OR_DIR`

# %%
def read_MHDs_generate_LHDs(input_path:str, task:str = 'cls') -> list:
    """
    Read the MHDs from the input path and filter out the MHDs that contains over 32 data points, and generate LHDs from the MHDs.
    Args:
        input_path (str): The path to the input directory containing the MHDs. The options are: CURA_CAT_GPCR_DIR, CURA_CAT_OR_DIR
    Returns:
        MHDs_min32: A list of MHDs that contains over 32 data points.
        LHDs_min32: A list of LHDs that contains over 32 data points.
    """
    #==================== Read the MHDs =========================
    # Put the file names of all the csv files in the input directory into a list
    
    MHDs = [f for f in os.listdir(os.path.join(input_path, task)) if f.startswith('CHEMBL')] 
    print(f"Found {len(MHDs)} MHDs in {input_path}/{task}")

    # Get the unique target_chembl_id in the list of MHDs
    MHDs_tgt = list(set([f.split('_')[0] for f in MHDs]))
    print(f"Found {len(MHDs_tgt)} unique target_chembl_id in {input_path}/{task}")

    # Filter out the MHDs that contains over 32 data points
    MHDs_min32 = []
    for mhd in MHDs:
        assay_path = os.path.join(input_path, task, mhd)
        # count rows using csv reader
        with open(assay_path, 'r', newline='') as f:
            row_count = sum(1 for row in csv.reader(f))

        # Subtract 1 for for header row
        if row_count -1 >= 32:
            MHDs_min32.append(mhd)
    print(f"Found {len(MHDs_min32)} MHDs with over 32 data points in {input_path}/{task}")

    #==================== Generate LHDs =========================
    LHDs_dict = defaultdict(list)
    LHDs_dir = os.path.join(input_path, task, 'LHDs')
    if os.path.exists(LHDs_dir):
        shutil.rmtree(LHDs_dir)
    os.makedirs(LHDs_dir)

    for assay in MHDs_min32:
        assay_path = os.path.join(input_path, task, assay)

        try:
            # Read the CSV files
            assay_df = pd.read_csv(assay_path).drop(columns=['Unnamed: 0'])

            # Get counts and filter valid IDs
            id_counts = assay_df['assay_chembl_id'].value_counts()

            # the number of data points in a single assay should,on the one hand, be at least 32 to ensure the model can be trained;
            # on the other hand, should not exceed 5000 to avoid high-throughput screens, as these are generally considered noisy
            valid_ids = id_counts[(id_counts >= 32) & (id_counts <= 5000)].index.tolist()

            if not valid_ids:
                print(f"No valid IDs found for {assay}. Skipping...")
                continue

            # Save the valid IDs to a new CSV file
            for assay_chembl_id in valid_ids:
                df = assay_df[assay_df['assay_chembl_id'] == assay_chembl_id]
                # delete the old threshold column
                df = df.drop(columns=['threshold', 'activity_string', 'activity'])
                # apply thresholds again because the new data may have different thresholds
                df = apply_thresholds(df)

                # save to csv
                basename = os.path.splitext(assay)[0]
                output_fname = f"{basename[:-8]}_{assay_chembl_id}_curated.csv"
                output_path = os.path.join(LHDs_dir, output_fname)
                df.to_csv(output_path, index=False)

                # Add to dictionary
                LHDs_dict[basename].append(assay_chembl_id)

        except Exception as e:
            print(f"Error processing {assay}: {e}")

    print(f"{len(LHDs_dict)} MHDs csv files contains qualified LHDs in {input_path}/{task}/LHDs")

    LHDs = [f for f in os.listdir(LHDs_dir) if f.startswith('CHEMBL')]
    LHDs_min32 = []


    for lhd in LHDs:
        lhd_path = os.path.join(LHDs_dir, lhd)

        with open(lhd_path, 'r', newline='') as f:
            row_count = sum(1 for row in csv.reader(f))


        if row_count - 1 >= 32:
            LHDs_min32.append(lhd)
    print(f"Found {len(LHDs_min32)} LHDs with over 32 data points in {input_path}/{task}/LHDs")

    return MHDs_min32, LHDs_min32

# %%
cat_or_MHDs, cat_or_LHDs = read_MHDs_generate_LHDs(CURA_CAT_OR_DIR, task='cls')
cat_or_reg_MHDs, cat_or_reg_LHDs = read_MHDs_generate_LHDs(CURA_CAT_OR_DIR, task='reg')
# Out:
# Found 38 MHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/cls
# Found 4 unique target_chembl_id in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/cls
# Found 32 MHDs with over 32 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/cls
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_antag_B_arrest_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_antag_G_GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_agon_B_arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_antag_G_GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_antag_G_GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2014_agon_G_GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2014_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# 19 MHDs csv files contains qualified LHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/cls/LHDs
# Found 109 LHDs with over 32 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/cls/LHDs
# Found 38 MHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/reg
# Found 4 unique target_chembl_id in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/reg
# Found 32 MHDs with over 32 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/reg
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_antag_B_arrest_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_antag_G_GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_agon_B_arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_antag_G_GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_antag_G_GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2014_agon_G_GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2014_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# 19 MHDs csv files contains qualified LHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/reg/LHDs
# Found 109 LHDs with over 32 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/reg/LHDs

# %%
cat_gpcr_MHDs, cat_gpcr_LHDs = read_MHDs_generate_LHDs(CURA_CAT_GPCR_DIR, 'cls')
cat_gpcr_reg_MHDs, cat_gpcr_reg_LHDs = read_MHDs_generate_LHDs(CURA_CAT_GPCR_DIR, 'reg')
# Out:
# Found 934 MHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/cls
# Found 238 unique target_chembl_id in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/cls
# Found 573 MHDs with over 32 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/cls
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL229_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1628461_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL256_agon_G_cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL225_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2888_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3371_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1867_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1946_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1836_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1946_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1853_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1983_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL264_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL252_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL234_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL245_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1811_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL211_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1875_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5493_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2274_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3974_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL231_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3759_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL3759_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3371_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL5951_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1941_agon_B_arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2434_antag_G_GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4644_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4777_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4029_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4422_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3795_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_antag_B_arrest_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL231_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1821_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4333_antag_G_GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4714_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1833_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1995_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_agon_B_arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1881_agon_B_arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3250_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2069161_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2056_agon_B_arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2414_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1785_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1917_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4080_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4018_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3892_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_antag_G_GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2069_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1855_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL214_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4383_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1811_antag_G_Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL253_antag_G_GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_antag_G_GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1804_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL226_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5038_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL274_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2327_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL234_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1945_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3710_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4523923_agon_B_arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2010631_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1987_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3710_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3250_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL264_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1916_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL232_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4561_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2955_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL256_agon_G_GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2373_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3911_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL251_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL229_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3759_agon_G_GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3785_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2487_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3230_agon_B_arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5413_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3764_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1881_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4227_agon_B_arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1985_agon_G_cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_B_arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3227_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2888_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5137_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2056_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5113_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4714_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL217_antag_G_GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4315_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1941_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1987_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL217_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4607_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL226_agon_G_GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4761_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4608_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL226_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3426_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4333_antag_B_arrest_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL232_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4333_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3764_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL217_agon_G_GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL211_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL226_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4777_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2736_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL255_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2035_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1878_antag_G_GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3230_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1811_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3772_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2203_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2049_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL5137_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1836_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4029_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2955_antag_G_Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5413_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4018_antag_G_GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL5137_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL223_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3371_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2736_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3777_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2842_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL234_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1921_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3795_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4123_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3540_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL256_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1987_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2182_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1898_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL214_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL253_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL5952_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL288_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1836_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4644_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4877_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL218_antag_G_GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4959_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3091266_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL264_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1790_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2049_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL219_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# 401 MHDs csv files contains qualified LHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/cls/LHDs
# Found 1531 LHDs with over 32 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/cls/LHDs
# Found 955 MHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/reg
# Found 238 unique target_chembl_id in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/reg
# Found 586 MHDs with over 32 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/reg
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL229_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1628461_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL256_agon_G_cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL225_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2888_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3371_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# ...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4315_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1941_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1987_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL217_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4607_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL226_agon_G_GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4761_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4608_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL226_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3426_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4333_antag_B_arrest_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL232_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4333_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3764_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL217_agon_G_GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL211_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL226_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4777_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2736_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL255_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2035_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1878_antag_G_GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3230_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1811_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3772_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2203_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2049_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL5137_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1836_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4029_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2955_antag_G_Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5413_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4018_antag_G_GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL5137_agon_G_GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL223_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3371_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2736_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3777_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2842_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL234_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1921_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3795_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4123_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3540_agon_G_Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3250_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL256_agon_G_cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1987_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2182_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1898_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL214_antag_G_GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL253_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL5952_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL288_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1836_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4644_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4877_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL218_antag_G_GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4959_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3091266_agon_G_Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_agon_G_cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL264_agon_G_cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1790_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3724_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2049_antag_G_Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL219_antag_B_arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# 410 MHDs csv files contains qualified LHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/reg/LHDs
# Found 1577 LHDs with over 32 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/reg/LHDs

# %% [markdown]
# # train-valid-test split (cls)

# %%
print(f'The length of cat_or_MHDs is {len(cat_or_MHDs)}') # => all as the test dataset
print(f'The length of cat_or_LHDs is {len(cat_or_LHDs)}') 
print(f'The length of cat_gpcr_MHDs is {len(cat_gpcr_MHDs)}') # => all except the or as the pretraining
print(f'The length of cat_gpcr_LHDs is {len(cat_gpcr_LHDs)}')
# Out:
# The length of cat_or_MHDs is 32
# The length of cat_or_LHDs is 109
# The length of cat_gpcr_MHDs is 573
# The length of cat_gpcr_LHDs is 1531

# %%
def split_OR_holdout(cat_gpcr_MHDs, cat_or_MHDs, ratio=100, seed=None):
    """
    Splits a list of csv files (either MHDs or LHDs) into train, valid, and test based on OR_chemblids and a given ratio.

    Parameters:
        datasets (list): List of datasets (csv files: MHDs or LHDs), e.g. 'CHEMBL233_bind_RBA_IC50_curated.csv'.
        ratio (int): Ratio of train to valid (e.g., 100 means 100:1 train:valid split).
        seed (int, optional): Random seed for reproducibility.

    Returns:
        dict: A dictionary with keys 'train', 'valid', and 'test', each containing a list of dataset.
    """
    if seed is not None:
        random.seed(seed)

    DataFold = defaultdict(list)

    # Split into initial train/test
    for assay in cat_or_MHDs:
        DataFold['test'].append(assay)
    for assay in cat_gpcr_MHDs:
        if not any(assay.startswith(x + '_') for x in OR_chemblids):
            DataFold['train'].append(assay)

    # Shuffle for randomness
    random.shuffle(DataFold['train'])

    # Calculate validation set size
    n_total = len(DataFold['train'])
    n_valid = max(1, n_total // (ratio + 1))  # ratio:1 split

    # Split into train/valid
    DataFold['valid'] = DataFold['train'][:n_valid]
    DataFold['train'] = DataFold['train'][n_valid:]

    return DataFold

# %%
# MHDsFold: based on the MHDs because all files except the OR related MHDs should be used during pretraining
MHDsFold = split_OR_holdout(cat_gpcr_MHDs, cat_or_MHDs, ratio=100, seed=42)
with open(os.path.join(SPLIT_DATA_DIR, 'MHDsFold.json'), 'w') as f:
    json.dump(MHDsFold, f, indent=2)

# %%
MHDsFold
print(f'len(MHDsFold): {len(MHDsFold)}')
print(f'len(MHDsFold["train"]): {len(MHDsFold["train"])}; len(MHDsFold["valid"]): {len(MHDsFold["valid"])}; len(MHDsFold["test"]): {len(MHDsFold["test"])}')
# Out:
# len(MHDsFold): 3
# len(MHDsFold["train"]): 536; len(MHDsFold["valid"]): 5; len(MHDsFold["test"]): 32
