# %%
# conda env: datacat (Python 3.8.20)
import os
import csv
import random
import json
from collections import defaultdict
import shutil

import pandas as pd
from datacat4ml.const import CURA_CAT_GPCR_DIR, CURA_LHD_GPCR_DIR, CURA_CAT_50_5k_GPCR_DIR, CURA_CAT_OR_DIR, CURA_LHD_OR_DIR, CURA_CAT_50_5K_OR_DIR
from datacat4ml.const import OR_chemblids, SPLIT_DATA_DIR
from datacat4ml.Scripts.data_prep.data_curate.curate_utils.apply_thresholds import apply_thresholds

# %% [markdown]
# # Read MHDs from `CURA_CAT_GPCR_DIR` and `CURA_CAT_OR_DIR`

# %%
cat_lhd_dic = {
    CURA_CAT_GPCR_DIR: [CURA_CAT_50_5k_GPCR_DIR, CURA_LHD_GPCR_DIR],
    CURA_CAT_OR_DIR: [CURA_CAT_50_5K_OR_DIR, CURA_LHD_OR_DIR]
}

def write_stats_file(in_dir: str, task: str, ds_list: list, ds_str: str):
    """
    Write a stats file for the datasets in ds_list, which is a list of dataset filenames in one subfolder of 'data_curate' folder.

    params:
    --------
    in_dir: the input directory, e.g. CURA_CAT_GPCR_DIR or CURA_CAT_OR_DIR
    task: 'cls' or 'reg'
    ds_list: a list of dataset filenames. e.g. MHDs, MHDs_50_5k, or LHDs
    ds_str: the string to indicate which type of datasets, either 'MHDs_50_5k' or 'LHDs'
    """

    # out_dir depends on ds_str
    if ds_str == 'MHDs_50_5k':
        out_dir = os.path.join(cat_lhd_dic[in_dir][0], task) # e.g. CURA_CAT_50_5k_OR_DIR
    elif ds_str == 'LHDs':
        out_dir = os.path.join(cat_lhd_dic[in_dir][1], task) # e.g. CURA_LHD_OR_DIR
    
    # stats file
    stats_file = os.path.join(out_dir, f'{task}_stats.csv')
    if not os.path.exists(stats_file): # don't use check_file_exists() and then remove the file if it exists
        os.makedirs(os.path.dirname(stats_file), exist_ok=True)
        with open(stats_file, 'w') as f:
            f.write('task,target,effect,assay,standard_type,assay_chembl_id,threshold,datasize,num_active,num_inactive,%_active\n')

    for ds in ds_list:
        segs = ds.split('_')
        target = segs[0]
        effect = segs[1]
        assay = segs[2]
        std_type = segs[3]

        if ds_str == 'MHDs_50_5k':
            assay_chembl_id = 'None'
        elif ds_str == 'LHDs':
            assay_chembl_id = segs[4]

        ds_path = os.path.join(out_dir, ds)
        ds_df = pd.read_csv(ds_path)

        ds_size = ds_df.shape[0]
        threshold = ds_df['threshold'].unique()[0]
        num_active = sum(ds_df['activity'])
        percent_a = round(num_active / ds_size * 100, 2)

        with open(stats_file, 'a') as f:
            f.write(f'{task},{target},{effect},{assay},{std_type},{assay_chembl_id},{threshold},{ds_size},{num_active},{ds_size - num_active},{percent_a}\n')

# %%
def read_MHDs_generate_LHDs(in_dir:str=CURA_CAT_OR_DIR, task:str = 'cls') -> list:
    """
    Read the MHDs from the in_dir and filter out the MHDs that contains over 50 data points and smaller than 5000 data points, 
    and generate LHDs from the corresponding MHDs
    
    Args:
        in_dir (str): The path to the input directory containing the MHDs. The options are: CURA_CAT_GPCR_DIR, CURA_CAT_OR_DIR
        task (str): 'cls' or 'reg'.
    
    Returns:
        MHDs: A list of all MHDs in the input directory.
        MHDs_50_5k: A list of MHDs that contains over 50 data points and smaller than 5000 data points.
        LHDs: A list of all LHDs generated from the MHDs, already filtered to be between 50-5k data points.
    """
    #==================== Read the MHDs  =========================
    # Put the file names of all the csv files in the input directory into a list
    
    MHDs = [f for f in os.listdir(os.path.join(in_dir, task)) if f.startswith('CHEMBL')] 
    print(f"Found {len(MHDs)} MHDs in {in_dir}/{task}")

    # Get the unique target_chembl_id in the list of MHDs
    MHDs_tgt = list(set([f.split('_')[0] for f in MHDs]))
    print(f"Found {len(MHDs_tgt)} unique target_chembl_id in {in_dir}/{task}")

    # ==================== Generate MHDs_50_5k =========================
    MHDs_50_5k = []
    LHDs = []
    for mhd in MHDs:
        mhd_path = os.path.join(in_dir, task, mhd)
        # count rows using csv reader
        with open(mhd_path, 'r', newline='') as f:
            row_count = sum(1 for row in csv.reader(f))

        # Subtract 1 for for header row
        if row_count -1 >= 50 and row_count - 1 <= 5000:
            MHDs_50_5k.append(mhd)

            # ===================== Write MHDs_50_5k CSV files =========================
            mhd_df = pd.read_csv(mhd_path).drop(columns=['Unnamed: 0'])
            mhd_50_5k_path = os.path.join(cat_lhd_dic[in_dir][0], task, mhd)
            os.makedirs(os.path.dirname(mhd_50_5k_path), exist_ok=True)
            mhd_df.to_csv(mhd_50_5k_path, index=False)

            #==================== Generate LHDs =========================
            try:
                # Get counts and filter valid IDs
                id_counts = mhd_df['assay_chembl_id'].value_counts()

                # the number of data points in a single assay should,on the one hand, be at least 50 to ensure the model can be trained;
                # on the other hand, should not exceed 5000 to avoid high-throughput screens, as these are generally considered noisy
                valid_ids = id_counts[(id_counts >= 50) & (id_counts <= 5000)].index.tolist()

                if not valid_ids:
                    print(f"No valid IDs found for {mhd}. Skipping...")
                    continue

                 # Save the valid IDs to a new CSV file
                for valid_id in valid_ids:
                    lhd_df = mhd_df[mhd_df['assay_chembl_id'] == valid_id]
                    # delete the old threshold column
                    lhd_df = lhd_df.drop(columns=['threshold', 'activity_string', 'activity'])
                    # apply thresholds again because the new data may have different thresholds
                    lhd_df = apply_thresholds(lhd_df)
                    
                    lhd_name = f"{mhd[:-12]}_{valid_id}_curated.csv"
                    LHDs.append(lhd_name)  # Append to LHDs list

                    # save to csv
                    lhd_path = os.path.join(cat_lhd_dic[in_dir][1], task, lhd_name)
                    os.makedirs(os.path.dirname(lhd_path), exist_ok=True)
                    lhd_df.to_csv(lhd_path, index=False)

            except Exception as e:
                print(f"Error processing {mhd}: {e}")

    print(f"Found {len(MHDs_50_5k)} MHDs with over 50 data points and smaller than 5000 data points in {in_dir}/{task}")

    # ==================== Write stats_file for MHDs_50_5k ========================
    write_stats_file(in_dir, task, MHDs_50_5k, 'MHDs_50_5k')

    #==================== Write stats_file for LHDs (already between 50-5k) ========================
    write_stats_file(in_dir, task, LHDs, 'LHDs')

    return MHDs, MHDs_50_5k, LHDs

# %%
# or_cls
cat_or_cls_MHDs, cat_or_cls_MHDs_50_5k, cat_or_cls_LHDs = read_MHDs_generate_LHDs(CURA_CAT_OR_DIR, task='cls')
# or_reg
cat_or_reg_MHDs, cat_or_reg_MHDs_50_5k, cat_or_reg_LHDs = read_MHDs_generate_LHDs(CURA_CAT_OR_DIR, task='reg')
# Out:
# Found 38 MHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/cls
# Found 4 unique target_chembl_id in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/cls
# No valid IDs found for CHEMBL233_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2014_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2014_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_B-arrest_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_bind_RBA_IC50_curated.csv. Skipping...
# Found 28 MHDs with over 50 data points and smaller than 5000 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/cls
# Found 38 MHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/reg
# Found 4 unique target_chembl_id in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/reg
# No valid IDs found for CHEMBL233_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2014_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2014_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_B-arrest_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_bind_RBA_IC50_curated.csv. Skipping...
# Found 28 MHDs with over 50 data points and smaller than 5000 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_ors/reg

# %%
# gpcr_cls
cat_gpcr_cls_MHDs, cat_gpcr_cls_MHDs_50_5k, cat_gpcr_cls_LHDs = read_MHDs_generate_LHDs(CURA_CAT_GPCR_DIR, 'cls')
# gpcr_reg
cat_gpcr_reg_MHDs, cat_gpcr_reg_MHDs_50_5k, cat_gpcr_reg_LHDs = read_MHDs_generate_LHDs(CURA_CAT_GPCR_DIR, 'reg')
# Out:
# Found 934 MHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/cls
# Found 238 unique target_chembl_id in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/cls
# No valid IDs found for CHEMBL210_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL229_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1075162_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3974_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4761_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4315_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1867_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4894_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2373_agon_G-cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4015_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4518_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL213_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2056_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1853_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4015_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL234_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4596_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL252_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL216_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL234_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4235_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1811_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3636_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1875_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL223_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL229_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2434_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4015_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4761_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4792_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4608_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL229_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4333_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4029_antag_B-arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3974_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL231_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1836_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1821_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3371_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5951_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4777_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3892_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL232_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1833_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2487_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3764_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1878_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4422_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1821_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5137_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1681611_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1983_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1942_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1790_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2010631_antag_B-arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL218_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3746_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1946_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4227_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL251_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL226_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3759_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL211_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4441_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3798_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2414_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1995_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2414_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3785_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL213_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4105907_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL253_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1628481_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4330_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2028_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL223_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL217_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4644_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3795_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1792_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2014_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2414_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4429_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL211_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4429_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3359_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2274_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1898_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1785_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2035_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4080_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3892_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3250_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL218_antag_G-GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL224_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3540_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2049_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2434_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1800_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL264_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2069161_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3710_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1945_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2056_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4333_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL226_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1941_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1946_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3227_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3798_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5113_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4383_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4398_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1804_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL256_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3359_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL226_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5339_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1628472_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1293316_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL274_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4427_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2327_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1898_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2010631_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1921_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1628481_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2695_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL251_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL256_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL218_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1293267_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5113_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3795_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2955_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3764_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL278_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4029_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5137_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL217_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5137_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL231_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2955_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3371_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL274_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2955_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2373_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3911_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2069_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2384898_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2487_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1995_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4123_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1628461_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL214_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3157_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1881_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL217_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2035_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2888_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2056_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5113_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL3759_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL250_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1628481_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1987_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2107_antag_B-arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5857_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4422_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL253_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4607_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL5162_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3426_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3371_agon_G-cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4421_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3230_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2069_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4333_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL255_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL251_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2107_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL3785_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3764_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1901_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1983_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1867_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2514_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL253_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4777_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1945_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5852_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL226_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5517_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL264_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL3759_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_antag_G-GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4561_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4422_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3230_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL234_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1855_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_agon_G-cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1804_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1916_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1836_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4029_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5413_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4315_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4235_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2842_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL264_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1921_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3714079_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3473_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2434_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL264_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL344_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3795_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL255_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5137_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4123_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL255_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1075322_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1878_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4792_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL218_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL223_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4123_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL256_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4714_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2049_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1987_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2182_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3228_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL237_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3399910_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1878_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1917_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL5952_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4644_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL5071_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4427_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4123_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4714_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4877_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL218_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_B-arrest_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1792_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4018_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL5339_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4616_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL232_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1983_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1790_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1921_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3911_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Found 490 MHDs with over 50 data points and smaller than 5000 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/cls
# Found 955 MHDs in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/reg
# Found 238 unique target_chembl_id in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/reg
# No valid IDs found for CHEMBL210_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL229_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1075162_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3974_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4761_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4315_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1867_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4894_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2373_agon_G-cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4015_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4518_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL213_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2056_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1853_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4015_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL234_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4596_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL252_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL216_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL234_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1889_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4235_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1811_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3636_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1875_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL223_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL229_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2434_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4015_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4761_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4792_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4608_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL229_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4333_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4029_antag_B-arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3974_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL231_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1836_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1821_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3371_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5951_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4777_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3892_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL232_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1889_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1833_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2487_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3764_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1878_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4422_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1821_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5137_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1681611_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1983_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1942_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1790_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2010631_antag_B-arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL218_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3746_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1946_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4227_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL251_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL226_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3759_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL211_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4441_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3798_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2414_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1995_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2414_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3785_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL213_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4105907_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL253_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1628481_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4330_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2028_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL223_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL217_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4644_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3795_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1792_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2014_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2414_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4429_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL211_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4429_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3359_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2274_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1898_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1785_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2035_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4080_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL227_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3892_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3250_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL218_antag_G-GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL224_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3540_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3724_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2049_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2434_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1800_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL264_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2069161_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3710_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1945_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2056_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4333_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL226_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1941_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1946_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3227_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3798_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5113_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4383_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4398_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1804_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL256_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3359_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL226_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL233_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5339_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1628472_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1293316_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL274_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4427_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2327_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1898_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2010631_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1921_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1628481_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2695_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL251_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL256_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL218_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1293267_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5113_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3795_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2955_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3764_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL278_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4029_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5137_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL217_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5137_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL231_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2955_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3371_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL274_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2955_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2373_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3911_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2069_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2384898_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2487_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1995_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4123_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1628461_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL214_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3157_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1881_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL217_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2035_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2888_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2056_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5113_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3759_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL250_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1628481_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1987_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL2107_antag_B-arrest_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5857_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4422_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL253_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4607_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL5162_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3426_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3371_agon_G-cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4421_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3230_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2069_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4333_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL255_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL251_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2107_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL3785_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3764_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1901_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1983_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1867_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL2514_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL253_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4777_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1945_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5852_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL226_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5517_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL264_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL3759_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL236_antag_G-GTP_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4561_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4422_agon_B-arrest_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3230_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL234_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1855_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2014_agon_G-cAMP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1804_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1916_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL1836_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4029_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL5413_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4315_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4235_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2842_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL264_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1921_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3714079_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3473_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2434_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL264_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL344_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL233_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3795_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL255_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL5137_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4123_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL255_agon_G-cAMP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1075322_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1878_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4792_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL218_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL223_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4123_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL256_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL4714_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2049_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL236_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1987_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL2182_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL3228_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL237_antag_G-GTP_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL2955_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL3399910_agon_G-GTP_EC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1878_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1917_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL5952_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4644_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL237_agon_G-Ca_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL5071_antag_G-GTP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4427_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4123_bind_RBA_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL4714_antag_G-Ca_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4877_bind_RBA_Ki_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL218_agon_G-cAMP_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_antag_B-arrest_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1792_agon_G-cAMP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL4018_antag_G-GTP_Ki_curated.csv. Skipping...
# No valid IDs found for CHEMBL5339_agon_B-arrest_EC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL4616_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL232_antag_G-Ca_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL1983_agon_G-GTP_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL1790_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# No valid IDs found for CHEMBL1921_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_agon_G-Ca_EC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL237_bind_RBA_IC50_curated.csv. Skipping...
# No valid IDs found for CHEMBL214_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Applying thresholds
# No valid IDs found for CHEMBL3911_bind_RBA_IC50_curated.csv. Skipping...
# Applying thresholds
# Found 503 MHDs with over 50 data points and smaller than 5000 data points in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Data/data_prep/data_curate/cura_cat_gpcrs/reg

# %% [markdown]
# # train-valid-test split (cls)

# %%
print(f'======== cls ==============')
print(f'The length of cat_or_cls_MHDs is {len(cat_or_cls_MHDs)}') # => all as the test dataset
print(f'The length of cat_or_cls_MHDs_50_5k is {len(cat_or_cls_MHDs_50_5k)}')
print(f'The length of cat_or_cls_LHDs is {len(cat_or_cls_LHDs)}') 

print(f'The length of cat_gpcr_cls_MHDs is {len(cat_gpcr_cls_MHDs)}') # => all except the or as the pretraining
print(f'The length of cat_gpcr_cls_MHDs_50_5k is {len(cat_gpcr_cls_MHDs_50_5k)}')
print(f'The length of cat_gpcr_cls_LHDs is {len(cat_gpcr_cls_LHDs)}') 

print(f'========= reg ===========')
print(f'The length of cat_or_reg_MHDs is {len(cat_or_reg_MHDs)}') # => all as the test dataset
print(f'The length of cat_or_reg_MHDs_50_5k is {len(cat_or_reg_MHDs_50_5k)}')
print(f'The length of cat_or_reg_LHDs is {len(cat_or_reg_LHDs)}') 

print(f'The length of cat_gpcr_reg_MHDs is {len(cat_gpcr_reg_MHDs)}') # => all except the or as the pretraining
print(f'The length of cat_gpcr_reg_MHDs_50_5k is {len(cat_gpcr_reg_MHDs_50_5k)}')
print(f'The length of cat_gpcr_reg_LHDs is {len(cat_gpcr_reg_LHDs)}')
# Out:
# ======== cls ==============
# The length of cat_or_cls_MHDs is 38
# The length of cat_or_cls_MHDs_50_5k is 28
# The length of cat_or_cls_LHDs is 26
# The length of cat_gpcr_cls_MHDs is 934
# The length of cat_gpcr_cls_MHDs_50_5k is 490
# The length of cat_gpcr_cls_LHDs is 434
# ========= reg ===========
# The length of cat_or_reg_MHDs is 38
# The length of cat_or_reg_MHDs_50_5k is 28
# The length of cat_or_reg_LHDs is 26
# The length of cat_gpcr_reg_MHDs is 955
# The length of cat_gpcr_reg_MHDs_50_5k is 503
# The length of cat_gpcr_reg_LHDs is 453

# %%
def split_OR_holdout(gpcr_ds, or_ds, ratio=100, seed=None):
    """
    Splits a list of csv files (either MHDs or LHDs) into train, valid, and test based on OR_chemblids and a given ratio.

    Parameters:
        datasets (list): List of datasets (csv files: MHDs or LHDs), e.g. 'CHEMBL233_bind_RBA_IC50_curated.csv'.
        ratio (int): Ratio of train to valid (e.g., 100 means 100:1 train:valid split).
        seed (int, optional): Random seed for reproducibility.

    Returns:
        dict: A dictionary with keys 'train', 'valid', and 'test', each containing a list of dataset.
    """
    if seed is not None:
        random.seed(seed)

    DataFold = defaultdict(list)

    # Split into initial train/test
    for assay in or_ds:
        DataFold['test'].append(assay)
    for assay in gpcr_ds:
        if not any(assay.startswith(x + '_') for x in OR_chemblids):
            DataFold['train'].append(assay)

    # Shuffle for randomness
    random.shuffle(DataFold['train'])

    # Calculate validation set size
    n_total = len(DataFold['train'])
    n_valid = max(1, n_total // (ratio + 1))  # ratio:1 split

    # Split into train/valid
    DataFold['valid'] = DataFold['train'][:n_valid]
    DataFold['train'] = DataFold['train'][n_valid:]

    return DataFold

# %%
# ClsMHDsFold: based on the MHDs because all files except the OR related MHDs should be used during pretraining
ClsMHDsFold = split_OR_holdout(cat_gpcr_cls_MHDs, cat_or_cls_MHDs, ratio=100, seed=42)
with open(os.path.join(SPLIT_DATA_DIR, 'ClsMHDsFold.json'), 'w') as f:
    json.dump(ClsMHDsFold, f, indent=2)

# RegMHDsFold
RegMHDsFold = split_OR_holdout(cat_gpcr_reg_MHDs, cat_or_reg_MHDs, ratio=100, seed=42)
with open(os.path.join(SPLIT_DATA_DIR, 'RegMHDsFold.json'), 'w') as f:
    json.dump(RegMHDsFold, f, indent=2)

# %%
ClsMHDsFold
print(f'len(ClsMHDsFold): {len(ClsMHDsFold)}')
print(f'len(ClsMHDsFold["train"]): {len(ClsMHDsFold["train"])}; len(ClsMHDsFold["valid"]): {len(ClsMHDsFold["valid"])}; len(ClsMHDsFold["test"]): {len(ClsMHDsFold["test"])}')
# Out:
# len(ClsMHDsFold): 3
# len(ClsMHDsFold["train"]): 887; len(ClsMHDsFold["valid"]): 8; len(ClsMHDsFold["test"]): 38

# %%
RegMHDsFold
print(f'len(RegMHDsFold): {len(RegMHDsFold)}')
print(f'len(RegMHDsFold["train"]): {len(RegMHDsFold["train"])}; len(RegMHDsFold["valid"]): {len(RegMHDsFold["valid"])}; len(RegMHDsFold["test"]): {len(RegMHDsFold["test"])}')
# Out:
# len(RegMHDsFold): 3
# len(RegMHDsFold["train"]): 907; len(RegMHDsFold["valid"]): 9; len(RegMHDsFold["test"]): 38
