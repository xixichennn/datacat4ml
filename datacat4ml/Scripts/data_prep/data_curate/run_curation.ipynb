# %%
# conda env: pyg (Python3.9.16)
import shutil
import argparse

from datacat4ml.const import *
from datacat4ml.Scripts.data_prep.data_curate.utils.curate_dataset_type import curate_datasets_and_get_stats

# %%
def main():

    """
    run the curation process on datasets including:
    - categorize datasets for ORs
    - heterogeneous datasets for ORs
    - heterogeneous datasets for GPCRs

    and get the stats for each dataset type.

    """

    for task in Tasks:
        # keep the 'task' in the argument to ensure the stats are generated only once
        print(f'----------->Task is {task}\n')


        ## ==== categorized data for ORs ====
        print('Processing categorized datasets of ORs...')
        #if os.path.exists(os.path.join(CURA_CAT_DATASETS_DIR, task)):
        #    # remove the directory and its contents
        #    shutil.rmtree(os.path.join(CURA_CAT_DATASETS_DIR, task))

        # Binding affinity
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='bind', assay='RBA', std_types=["Ki", 'IC50'], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)

        # Agonism
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='agon', assay='G_GTP', std_types=["EC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='agon', assay='G_Ca', std_types=["EC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='agon', assay='G_cAMP', std_types=["IC50", "EC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='agon', assay='B_arrest', std_types=["EC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        
        ## Antagonism
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='antag', assay='G_GTP', std_types=["IC50", "Ki", "Kb", "Ke"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='antag', assay='B_arrest', std_types=["IC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        
        ## ==== het data for ORs ====
        print('Processing heterogeneous data of ORs...')
        if os.path.exists(os.path.join(CURA_HET_DATASETS_DIR, task)):
            # remove the directory and its contents
            shutil.rmtree(os.path.join(CURA_HET_DATASETS_DIR, task))
            
        curate_datasets_and_get_stats(dataset_type='het', task=task, target_list=OR_names, effect=None, assay=None, std_types=["Ki", "IC50", 'EC50'],
                                    input_path=HET_DATASETS_DIR, output_path=CURA_HET_DATASETS_DIR)

        ## ==== het data for GPCRs ====
        print('Processing heterogeneous data of GPCRs...') 
        if os.path.exists(os.path.join(CURA_GPCR_DATASETS_DIR, task)):
            # remove the directory and its contents
            shutil.rmtree(os.path.join(CURA_GPCR_DATASETS_DIR, task))
        GPCR_chembl_ids = [id for id in os.listdir(HET_GPCR_DIR) if os.path.isdir(os.path.join(HET_GPCR_DIR, id))]
        curate_datasets_and_get_stats(dataset_type='het', task=task, target_list=GPCR_chembl_ids, effect=None, assay=None, std_types=["Ki", "IC50", 'EC50'],
                                    input_path=HET_GPCR_DIR, output_path=CURA_GPCR_DATASETS_DIR)

# %%
main()
# Out:
# ----------->Task is cls
#
# Processing categorized datasets of ORs...
# Processing mor_bind_RBA_Ki...
# The length of the raw dataset is 5557
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (5403, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (5206, 34)
# After removing the mols with multiple values, the shape of the df:(4523, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 154
# After standardizing the SMILES, the shape of the df: (154, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (144, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(131, 35)
# Done curation.
#
# Processing mor_bind_RBA_IC50...
# The length of the raw dataset is 687
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (665, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (630, 34)
# After removing the mols with multiple values, the shape of the df:(561, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 22
# After standardizing the SMILES, the shape of the df: (22, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (21, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(21, 35)
# Done curation.
#
# ====================
#
# Processing kor_bind_RBA_Ki...
# The length of the raw dataset is 4646
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (4531, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4302, 34)
# After removing the mols with multiple values, the shape of the df:(3761, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 115
# After standardizing the SMILES, the shape of the df: (115, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (115, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(101, 35)
# Done curation.
#
# Processing kor_bind_RBA_IC50...
# The length of the raw dataset is 485
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (477, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (453, 34)
# After removing the mols with multiple values, the shape of the df:(408, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 8
# After standardizing the SMILES, the shape of the df: (8, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (8, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(8, 35)
# Done curation.
#
# ====================
#
# Processing dor_bind_RBA_Ki...
# The length of the raw dataset is 4997
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (4859, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4532, 34)
# After removing the mols with multiple values, the shape of the df:(3923, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 131
# After standardizing the SMILES, the shape of the df: (131, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (126, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(112, 35)
# Done curation.
#
# Processing dor_bind_RBA_IC50...
# The length of the raw dataset is 964
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (942, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (753, 34)
# After removing the mols with multiple values, the shape of the df:(672, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 22
# After standardizing the SMILES, the shape of the df: (22, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (21, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(21, 35)
# Done curation.
#
# ====================
#
# Processing nor_bind_RBA_Ki...
# The length of the raw dataset is 1332
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1312, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1245, 34)
# After removing the mols with multiple values, the shape of the df:(1126, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 20
# After standardizing the SMILES, the shape of the df: (20, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (17, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(16, 35)
# Done curation.
#
# Processing nor_bind_RBA_IC50...
# The length of the raw dataset is 507
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (507, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (442, 34)
# After removing the mols with multiple values, the shape of the df:(417, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing mor_agon_G_GTP_EC50...
# The length of the raw dataset is 1124
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (997, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (971, 34)
# After removing the mols with multiple values, the shape of the df:(869, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 117
# After standardizing the SMILES, the shape of the df: (117, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (113, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(111, 35)
# Done curation.
#
# ====================
#
# Processing kor_agon_G_GTP_EC50...
# The length of the raw dataset is 1468
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1220, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1190, 34)
# After removing the mols with multiple values, the shape of the df:(1022, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 235
# After standardizing the SMILES, the shape of the df: (235, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (233, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(224, 35)
# Done curation.
#
# ====================
#
# Processing dor_agon_G_GTP_EC50...
# The length of the raw dataset is 922
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (851, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (682, 34)
# After removing the mols with multiple values, the shape of the df:(581, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 68
# After standardizing the SMILES, the shape of the df: (68, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (67, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(67, 35)
# Done curation.
#
# ====================
#
# Processing nor_agon_G_GTP_EC50...
# The length of the raw dataset is 314
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (271, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (198, 34)
# After removing the mols with multiple values, the shape of the df:(190, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 36
# After standardizing the SMILES, the shape of the df: (36, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (32, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(32, 35)
# Done curation.
#
# ====================
#
# Processing mor_agon_G_Ca_EC50...
# The length of the raw dataset is 176
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (176, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (155, 34)
# After removing the mols with multiple values, the shape of the df:(144, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing kor_agon_G_Ca_EC50...
# The length of the raw dataset is 86
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (86, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (82, 34)
# After removing the mols with multiple values, the shape of the df:(74, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing dor_agon_G_Ca_EC50...
# The length of the raw dataset is 45
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (45, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (42, 34)
# After removing the mols with multiple values, the shape of the df:(40, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing nor_agon_G_Ca_EC50...
# The length of the raw dataset is 66
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (44, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (9, 34)
# After removing the mols with multiple values, the shape of the df:(9, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 22
# After standardizing the SMILES, the shape of the df: (22, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (22, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(22, 35)
# Done curation.
#
# ====================
#
# Processing mor_agon_G_cAMP_IC50...
# The length of the raw dataset is 85
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (81, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (75, 34)
# After removing the mols with multiple values, the shape of the df:(53, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 4
# After standardizing the SMILES, the shape of the df: (4, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(2, 35)
# Done curation.
#
# Processing mor_agon_G_cAMP_EC50...
# The length of the raw dataset is 587
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (570, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (490, 34)
# After removing the mols with multiple values, the shape of the df:(418, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 17
# After standardizing the SMILES, the shape of the df: (17, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (17, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(17, 35)
# Done curation.
#
# ====================
#
# Processing kor_agon_G_cAMP_IC50...
# The length of the raw dataset is 36
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (36, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (36, 34)
# After removing the mols with multiple values, the shape of the df:(27, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing kor_agon_G_cAMP_EC50...
# The length of the raw dataset is 346
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (326, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (254, 34)
# After removing the mols with multiple values, the shape of the df:(237, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 20
# After standardizing the SMILES, the shape of the df: (20, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (18, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(16, 35)
# Done curation.
#
# ====================
#
# Processing dor_agon_G_cAMP_IC50...
# The length of the raw dataset is 33
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (22, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (19, 34)
# After removing the mols with multiple values, the shape of the df:(17, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 11
# After standardizing the SMILES, the shape of the df: (11, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (11, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(11, 35)
# Done curation.
#
# Processing dor_agon_G_cAMP_EC50...
# The length of the raw dataset is 202
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (187, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (117, 34)
# After removing the mols with multiple values, the shape of the df:(113, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 15
# After standardizing the SMILES, the shape of the df: (15, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (14, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(12, 35)
# Done curation.
#
# ====================
#
# Processing nor_agon_G_cAMP_IC50...
# The length of the raw dataset is 80
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (70, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (70, 34)
# After removing the mols with multiple values, the shape of the df:(59, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 10
# After standardizing the SMILES, the shape of the df: (10, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (10, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(10, 35)
# Done curation.
#
# Processing nor_agon_G_cAMP_EC50...
# The length of the raw dataset is 37
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (36, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (5, 34)
# After removing the mols with multiple values, the shape of the df:(5, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 1
# After standardizing the SMILES, the shape of the df: (1, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(1, 35)
# Done curation.
#
# ====================
#
# Processing mor_agon_B_arrest_EC50...
# The length of the raw dataset is 267
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (227, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (213, 34)
# After removing the mols with multiple values, the shape of the df:(169, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 40
# After standardizing the SMILES, the shape of the df: (40, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (40, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(38, 35)
# Done curation.
#
# ====================
#
# Processing kor_agon_B_arrest_EC50...
# The length of the raw dataset is 66
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (49, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (45, 34)
# After removing the mols with multiple values, the shape of the df:(33, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 17
# After standardizing the SMILES, the shape of the df: (17, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (17, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(17, 35)
# Done curation.
#
# ====================
#
# Processing dor_agon_B_arrest_EC50...
# The length of the raw dataset is 53
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (35, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (31, 34)
# After removing the mols with multiple values, the shape of the df:(18, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 18
# After standardizing the SMILES, the shape of the df: (18, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (18, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(18, 35)
# Done curation.
#
# ====================
#
# Processing nor_agon_B_arrest_EC50...
# The length of the raw dataset is 47
# Curating dataset
# start standardizing with value
# Failed curating the dataset due to cannot set a frame with no defined index and a scalar
# After standardizing the SMILES, the shape of the df: (47, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2, 34)
# After removing the mols with multiple values, the shape of the df:(1, 35)
# start applying thresholds
# Applying thresholds
# ====================
#
# Processing mor_antag_G_GTP_IC50...
# The length of the raw dataset is 377
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (301, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (294, 34)
# After removing the mols with multiple values, the shape of the df:(268, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 76
# After standardizing the SMILES, the shape of the df: (76, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (76, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(71, 35)
# Done curation.
#
# Processing mor_antag_G_GTP_Ki...
# The length of the raw dataset is 63
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (63, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (63, 34)
# After removing the mols with multiple values, the shape of the df:(61, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing mor_antag_G_GTP_Kb...
# Empty dataset for mor-antag-G_GTP-Kb
# Processing mor_antag_G_GTP_Ke...
# Empty dataset for mor-antag-G_GTP-Ke
# ====================
#
# Processing kor_antag_G_GTP_IC50...
# The length of the raw dataset is 212
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (155, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (146, 34)
# After removing the mols with multiple values, the shape of the df:(133, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 57
# After standardizing the SMILES, the shape of the df: (57, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (53, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(52, 35)
# Done curation.
#
# Processing kor_antag_G_GTP_Ki...
# The length of the raw dataset is 57
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (57, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (57, 34)
# After removing the mols with multiple values, the shape of the df:(53, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing kor_antag_G_GTP_Kb...
# Empty dataset for kor-antag-G_GTP-Kb
# Processing kor_antag_G_GTP_Ke...
# Empty dataset for kor-antag-G_GTP-Ke
# ====================
#
# Processing dor_antag_G_GTP_IC50...
# The length of the raw dataset is 197
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (179, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (159, 34)
# After removing the mols with multiple values, the shape of the df:(151, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 18
# After standardizing the SMILES, the shape of the df: (18, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (18, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(18, 35)
# Done curation.
#
# Processing dor_antag_G_GTP_Ki...
# The length of the raw dataset is 91
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (88, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (88, 34)
# After removing the mols with multiple values, the shape of the df:(71, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 2
# After standardizing the SMILES, the shape of the df: (2, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(2, 35)
# Done curation.
#
# Processing dor_antag_G_GTP_Kb...
# Empty dataset for dor-antag-G_GTP-Kb
# Processing dor_antag_G_GTP_Ke...
# Empty dataset for dor-antag-G_GTP-Ke
# ====================
#
# Processing nor_antag_G_GTP_IC50...
# The length of the raw dataset is 157
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (127, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (127, 34)
# After removing the mols with multiple values, the shape of the df:(120, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 30
# After standardizing the SMILES, the shape of the df: (30, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (30, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(30, 35)
# Done curation.
#
# Processing nor_antag_G_GTP_Ki...
# The length of the raw dataset is 6
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (6, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (6, 34)
# After removing the mols with multiple values, the shape of the df:(6, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing nor_antag_G_GTP_Kb...
# Empty dataset for nor-antag-G_GTP-Kb
# Processing nor_antag_G_GTP_Ke...
# Empty dataset for nor-antag-G_GTP-Ke
# ====================
#
# Processing mor_antag_B_arrest_IC50...
# The length of the raw dataset is 40
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (40, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (40, 34)
# After removing the mols with multiple values, the shape of the df:(40, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing kor_antag_B_arrest_IC50...
# The length of the raw dataset is 73
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (72, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (72, 34)
# After removing the mols with multiple values, the shape of the df:(52, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 1
# After standardizing the SMILES, the shape of the df: (1, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(1, 35)
# Done curation.
#
# ====================
#
# Processing dor_antag_B_arrest_IC50...
# The length of the raw dataset is 38
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (38, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (38, 34)
# After removing the mols with multiple values, the shape of the df:(38, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing nor_antag_B_arrest_IC50...
# Empty dataset for nor-antag-B_arrest-IC50
# ====================
#
# Processing heterogeneous data of ORs...
# Processing mor_None_None_Ki...
# The length of the raw dataset is 5682
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (5511, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (5314, 34)
# After removing the mols with multiple values, the shape of the df:(4587, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 171
# After standardizing the SMILES, the shape of the df: (171, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (161, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(148, 35)
# Done curation.
#
# Processing mor_None_None_IC50...
# The length of the raw dataset is 1366
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1258, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1202, 34)
# After removing the mols with multiple values, the shape of the df:(1013, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 108
# After standardizing the SMILES, the shape of the df: (108, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (105, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(98, 35)
# Done curation.
#
# Processing mor_None_None_EC50...
# The length of the raw dataset is 2296
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (2103, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1954, 34)
# After removing the mols with multiple values, the shape of the df:(1448, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 183
