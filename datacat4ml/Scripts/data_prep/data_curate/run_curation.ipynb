# %%
# conda env: pyg (Python3.9.16)
import shutil
import argparse

from datacat4ml.const import *
from datacat4ml.Scripts.data_prep.data_curate.utils.curate_dataset_type import curate_datasets_and_get_stats

# %%
def main():

    """
    run the curation process on datasets including:
    - categorize datasets for ORs
    - heterogeneous datasets for ORs
    - heterogeneous datasets for GPCRs

    and get the stats for each dataset type.

    """

    for task in Tasks:
        # keep the 'task' in the argument to ensure the stats are generated only once
        print(f'----------->Task is {task}\n')


        ## ==== categorized data for ORs ====
        print('Processing categorized datasets of ORs...')
        #if os.path.exists(os.path.join(CURA_CAT_DATASETS_DIR, task)):
        #    # remove the directory and its contents
        #    shutil.rmtree(os.path.join(CURA_CAT_DATASETS_DIR, task))

        # Binding affinity
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='bind', assay='RBA', std_types=["Ki", 'IC50'], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)

        # Agonism
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='agon', assay='G_GTP', std_types=["EC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='agon', assay='G_Ca', std_types=["EC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='agon', assay='G_cAMP', std_types=["IC50", "EC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='agon', assay='B_arrest', std_types=["EC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        
        ## Antagonism
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='antag', assay='G_GTP', std_types=["IC50", "Ki", "Kb", "Ke"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        curate_datasets_and_get_stats(dataset_type='cat', task=task, target_list=OR_names, effect='antag', assay='B_arrest', std_types=["IC50"], 
                                    input_path=CAT_DATASETS_DIR, output_path= CURA_CAT_DATASETS_DIR)
        
        ## ==== het data for ORs ====
        print('Processing heterogeneous data of ORs...')
        if os.path.exists(os.path.join(CURA_HET_DATASETS_DIR, task)):
            # remove the directory and its contents
            shutil.rmtree(os.path.join(CURA_HET_DATASETS_DIR, task))
            
        curate_datasets_and_get_stats(dataset_type='het', task=task, target_list=OR_names, effect=None, assay=None, std_types=["Ki", "IC50", 'EC50'],
                                    input_path=HET_DATASETS_DIR, output_path=CURA_HET_DATASETS_DIR)

        ## ==== het data for GPCRs ====
        print('Processing heterogeneous data of GPCRs...') 
        if os.path.exists(os.path.join(CURA_GPCR_DATASETS_DIR, task)):
            # remove the directory and its contents
            shutil.rmtree(os.path.join(CURA_GPCR_DATASETS_DIR, task))
        GPCR_chembl_ids = [id for id in os.listdir(HET_GPCR_DIR) if os.path.isdir(os.path.join(HET_GPCR_DIR, id))]
        curate_datasets_and_get_stats(dataset_type='het', task=task, target_list=GPCR_chembl_ids, effect=None, assay=None, std_types=["Ki", "IC50", 'EC50'],
                                    input_path=HET_GPCR_DIR, output_path=CURA_GPCR_DATASETS_DIR)

# %%
main()
# Out:
# ----------->Task is cls
#
# Processing categorized datasets of ORs...
# Processing mor_bind_RBA_Ki...
# The length of the raw dataset is 5557
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (5403, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (5206, 34)
# After removing the mols with multiple values, the shape of the df:(4523, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 154
# After standardizing the SMILES, the shape of the df: (154, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (144, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(131, 35)
# Done curation.
#
# Processing mor_bind_RBA_IC50...
# The length of the raw dataset is 687
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (665, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (630, 34)
# After removing the mols with multiple values, the shape of the df:(561, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 22
# After standardizing the SMILES, the shape of the df: (22, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (21, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(21, 35)
# Done curation.
#
# ====================
#
# Processing kor_bind_RBA_Ki...
# The length of the raw dataset is 4646
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (4531, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4302, 34)
# After removing the mols with multiple values, the shape of the df:(3761, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 115
# After standardizing the SMILES, the shape of the df: (115, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (115, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(101, 35)
# Done curation.
#
# Processing kor_bind_RBA_IC50...
# The length of the raw dataset is 485
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (477, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (453, 34)
# After removing the mols with multiple values, the shape of the df:(408, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 8
# After standardizing the SMILES, the shape of the df: (8, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (8, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(8, 35)
# Done curation.
#
# ====================
#
# Processing dor_bind_RBA_Ki...
# The length of the raw dataset is 4997
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (4859, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4532, 34)
# After removing the mols with multiple values, the shape of the df:(3923, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 131
# After standardizing the SMILES, the shape of the df: (131, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (126, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(112, 35)
# Done curation.
#
# Processing dor_bind_RBA_IC50...
# The length of the raw dataset is 964
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (942, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (753, 34)
# After removing the mols with multiple values, the shape of the df:(672, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 22
# After standardizing the SMILES, the shape of the df: (22, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (21, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(21, 35)
# Done curation.
#
# ====================
#
# Processing nor_bind_RBA_Ki...
# The length of the raw dataset is 1332
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1312, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1245, 34)
# After removing the mols with multiple values, the shape of the df:(1126, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 20
# After standardizing the SMILES, the shape of the df: (20, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (17, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(16, 35)
# Done curation.
#
# Processing nor_bind_RBA_IC50...
# The length of the raw dataset is 507
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (507, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (442, 34)
# After removing the mols with multiple values, the shape of the df:(417, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing mor_agon_G_GTP_EC50...
# The length of the raw dataset is 1124
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (997, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (971, 34)
# After removing the mols with multiple values, the shape of the df:(869, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 117
# After standardizing the SMILES, the shape of the df: (117, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (113, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(111, 35)
# Done curation.
#
# ====================
#
# Processing kor_agon_G_GTP_EC50...
# The length of the raw dataset is 1468
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1220, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1190, 34)
# After removing the mols with multiple values, the shape of the df:(1022, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 235
# After standardizing the SMILES, the shape of the df: (235, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (233, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(224, 35)
# Done curation.
#
# ====================
#
# Processing dor_agon_G_GTP_EC50...
# The length of the raw dataset is 922
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (851, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (682, 34)
# After removing the mols with multiple values, the shape of the df:(581, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 68
# After standardizing the SMILES, the shape of the df: (68, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (67, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(67, 35)
# Done curation.
#
# ====================
#
# Processing nor_agon_G_GTP_EC50...
# The length of the raw dataset is 314
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (271, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (198, 34)
# After removing the mols with multiple values, the shape of the df:(190, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 36
# After standardizing the SMILES, the shape of the df: (36, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (32, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(32, 35)
# Done curation.
#
# ====================
#
# Processing mor_agon_G_Ca_EC50...
# The length of the raw dataset is 176
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (176, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (155, 34)
# After removing the mols with multiple values, the shape of the df:(144, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing kor_agon_G_Ca_EC50...
# The length of the raw dataset is 86
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (86, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (82, 34)
# After removing the mols with multiple values, the shape of the df:(74, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing dor_agon_G_Ca_EC50...
# The length of the raw dataset is 45
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (45, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (42, 34)
# After removing the mols with multiple values, the shape of the df:(40, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing nor_agon_G_Ca_EC50...
# The length of the raw dataset is 66
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (44, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (9, 34)
# After removing the mols with multiple values, the shape of the df:(9, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 22
# After standardizing the SMILES, the shape of the df: (22, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (22, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(22, 35)
# Done curation.
#
# ====================
#
# Processing mor_agon_G_cAMP_IC50...
# The length of the raw dataset is 85
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (81, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (75, 34)
# After removing the mols with multiple values, the shape of the df:(53, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 4
# After standardizing the SMILES, the shape of the df: (4, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(2, 35)
# Done curation.
#
# Processing mor_agon_G_cAMP_EC50...
# The length of the raw dataset is 587
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (570, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (490, 34)
# After removing the mols with multiple values, the shape of the df:(418, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 17
# After standardizing the SMILES, the shape of the df: (17, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (17, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(17, 35)
# Done curation.
#
# ====================
#
# Processing kor_agon_G_cAMP_IC50...
# The length of the raw dataset is 36
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (36, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (36, 34)
# After removing the mols with multiple values, the shape of the df:(27, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing kor_agon_G_cAMP_EC50...
# The length of the raw dataset is 346
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (326, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (254, 34)
# After removing the mols with multiple values, the shape of the df:(237, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 20
# After standardizing the SMILES, the shape of the df: (20, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (18, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(16, 35)
# Done curation.
#
# ====================
#
# Processing dor_agon_G_cAMP_IC50...
# The length of the raw dataset is 33
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (22, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (19, 34)
# After removing the mols with multiple values, the shape of the df:(17, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 11
# After standardizing the SMILES, the shape of the df: (11, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (11, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(11, 35)
# Done curation.
#
# Processing dor_agon_G_cAMP_EC50...
# The length of the raw dataset is 202
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (187, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (117, 34)
# After removing the mols with multiple values, the shape of the df:(113, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 15
# After standardizing the SMILES, the shape of the df: (15, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (14, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(12, 35)
# Done curation.
#
# ====================
#
# Processing nor_agon_G_cAMP_IC50...
# The length of the raw dataset is 80
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (70, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (70, 34)
# After removing the mols with multiple values, the shape of the df:(59, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 10
# After standardizing the SMILES, the shape of the df: (10, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (10, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(10, 35)
# Done curation.
#
# Processing nor_agon_G_cAMP_EC50...
# The length of the raw dataset is 37
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (36, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (5, 34)
# After removing the mols with multiple values, the shape of the df:(5, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 1
# After standardizing the SMILES, the shape of the df: (1, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(1, 35)
# Done curation.
#
# ====================
#
# Processing mor_agon_B_arrest_EC50...
# The length of the raw dataset is 267
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (227, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (213, 34)
# After removing the mols with multiple values, the shape of the df:(169, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 40
# After standardizing the SMILES, the shape of the df: (40, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (40, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(38, 35)
# Done curation.
#
# ====================
#
# Processing kor_agon_B_arrest_EC50...
# The length of the raw dataset is 66
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (49, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (45, 34)
# After removing the mols with multiple values, the shape of the df:(33, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 17
# After standardizing the SMILES, the shape of the df: (17, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (17, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(17, 35)
# Done curation.
#
# ====================
#
# Processing dor_agon_B_arrest_EC50...
# The length of the raw dataset is 53
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (35, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (31, 34)
# After removing the mols with multiple values, the shape of the df:(18, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 18
# After standardizing the SMILES, the shape of the df: (18, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (18, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(18, 35)
# Done curation.
#
# ====================
#
# Processing nor_agon_B_arrest_EC50...
# The length of the raw dataset is 47
# Curating dataset
# start standardizing with value
# Failed curating the dataset due to cannot set a frame with no defined index and a scalar
# After standardizing the SMILES, the shape of the df: (47, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2, 34)
# After removing the mols with multiple values, the shape of the df:(1, 35)
# start applying thresholds
# Applying thresholds
# ====================
#
# Processing mor_antag_G_GTP_IC50...
# The length of the raw dataset is 377
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (301, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (294, 34)
# After removing the mols with multiple values, the shape of the df:(268, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 76
# After standardizing the SMILES, the shape of the df: (76, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (76, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(71, 35)
# Done curation.
#
# Processing mor_antag_G_GTP_Ki...
# The length of the raw dataset is 63
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (63, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (63, 34)
# After removing the mols with multiple values, the shape of the df:(61, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing mor_antag_G_GTP_Kb...
# Empty dataset for mor-antag-G_GTP-Kb
# Processing mor_antag_G_GTP_Ke...
# Empty dataset for mor-antag-G_GTP-Ke
# ====================
#
# Processing kor_antag_G_GTP_IC50...
# The length of the raw dataset is 212
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (155, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (146, 34)
# After removing the mols with multiple values, the shape of the df:(133, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 57
# After standardizing the SMILES, the shape of the df: (57, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (53, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(52, 35)
# Done curation.
#
# Processing kor_antag_G_GTP_Ki...
# The length of the raw dataset is 57
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (57, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (57, 34)
# After removing the mols with multiple values, the shape of the df:(53, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing kor_antag_G_GTP_Kb...
# Empty dataset for kor-antag-G_GTP-Kb
# Processing kor_antag_G_GTP_Ke...
# Empty dataset for kor-antag-G_GTP-Ke
# ====================
#
# Processing dor_antag_G_GTP_IC50...
# The length of the raw dataset is 197
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (179, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (159, 34)
# After removing the mols with multiple values, the shape of the df:(151, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 18
# After standardizing the SMILES, the shape of the df: (18, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (18, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(18, 35)
# Done curation.
#
# Processing dor_antag_G_GTP_Ki...
# The length of the raw dataset is 91
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (88, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (88, 34)
# After removing the mols with multiple values, the shape of the df:(71, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 2
# After standardizing the SMILES, the shape of the df: (2, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(2, 35)
# Done curation.
#
# Processing dor_antag_G_GTP_Kb...
# Empty dataset for dor-antag-G_GTP-Kb
# Processing dor_antag_G_GTP_Ke...
# Empty dataset for dor-antag-G_GTP-Ke
# ====================
#
# Processing nor_antag_G_GTP_IC50...
# The length of the raw dataset is 157
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (127, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (127, 34)
# After removing the mols with multiple values, the shape of the df:(120, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 30
# After standardizing the SMILES, the shape of the df: (30, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (30, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(30, 35)
# Done curation.
#
# Processing nor_antag_G_GTP_Ki...
# The length of the raw dataset is 6
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (6, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (6, 34)
# After removing the mols with multiple values, the shape of the df:(6, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing nor_antag_G_GTP_Kb...
# Empty dataset for nor-antag-G_GTP-Kb
# Processing nor_antag_G_GTP_Ke...
# Empty dataset for nor-antag-G_GTP-Ke
# ====================
#
# Processing mor_antag_B_arrest_IC50...
# The length of the raw dataset is 40
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (40, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (40, 34)
# After removing the mols with multiple values, the shape of the df:(40, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing kor_antag_B_arrest_IC50...
# The length of the raw dataset is 73
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (72, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (72, 34)
# After removing the mols with multiple values, the shape of the df:(52, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 1
# After standardizing the SMILES, the shape of the df: (1, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(1, 35)
# Done curation.
#
# ====================
#
# Processing dor_antag_B_arrest_IC50...
# The length of the raw dataset is 38
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (38, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (38, 34)
# After removing the mols with multiple values, the shape of the df:(38, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# ====================
#
# Processing nor_antag_B_arrest_IC50...
# Empty dataset for nor-antag-B_arrest-IC50
# ====================
#
# Processing heterogeneous data of ORs...
# Processing mor_None_None_Ki...
# The length of the raw dataset is 5682
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (5511, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (5314, 34)
# After removing the mols with multiple values, the shape of the df:(4587, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 171
# After standardizing the SMILES, the shape of the df: (171, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (161, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(148, 35)
# Done curation.
#
# Processing mor_None_None_IC50...
# The length of the raw dataset is 1366
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1258, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1202, 34)
# After removing the mols with multiple values, the shape of the df:(1013, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 108
# After standardizing the SMILES, the shape of the df: (108, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (105, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(98, 35)
# Done curation.
#
# Processing mor_None_None_EC50...
# The length of the raw dataset is 2296
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (2103, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1954, 34)
# After removing the mols with multiple values, the shape of the df:(1448, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 183
# After standardizing the SMILES, the shape of the df: (183, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (179, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(171, 35)
# Done curation.
#
# ====================
#
# Processing kor_None_None_Ki...
# The length of the raw dataset is 4857
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (4720, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4489, 34)
# After removing the mols with multiple values, the shape of the df:(3887, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 137
# After standardizing the SMILES, the shape of the df: (137, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (137, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(123, 35)
# Done curation.
#
# Processing kor_None_None_IC50...
# The length of the raw dataset is 1049
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (973, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (910, 34)
# After removing the mols with multiple values, the shape of the df:(772, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 76
# After standardizing the SMILES, the shape of the df: (76, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (72, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(69, 35)
# Done curation.
#
# Processing kor_None_None_EC50...
# The length of the raw dataset is 2062
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1776, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1656, 34)
# After removing the mols with multiple values, the shape of the df:(1362, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 273
# After standardizing the SMILES, the shape of the df: (273, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (269, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(251, 35)
# Done curation.
#
# ====================
#
# Processing dor_None_None_Ki...
# The length of the raw dataset is 5152
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (4990, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4662, 34)
# After removing the mols with multiple values, the shape of the df:(3997, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 154
# After standardizing the SMILES, the shape of the df: (154, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (149, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(134, 35)
# Done curation.
#
# Processing dor_None_None_IC50...
# The length of the raw dataset is 1316
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1260, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1039, 34)
# After removing the mols with multiple values, the shape of the df:(924, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 56
# After standardizing the SMILES, the shape of the df: (56, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (52, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(51, 35)
# Done curation.
#
# Processing dor_None_None_EC50...
# The length of the raw dataset is 1324
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1212, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (953, 34)
# After removing the mols with multiple values, the shape of the df:(769, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 109
# After standardizing the SMILES, the shape of the df: (109, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (107, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(93, 35)
# Done curation.
#
# ====================
#
# Processing nor_None_None_Ki...
# The length of the raw dataset is 1381
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1361, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1294, 34)
# After removing the mols with multiple values, the shape of the df:(1172, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 20
# After standardizing the SMILES, the shape of the df: (20, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (17, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(16, 35)
# Done curation.
#
# Processing nor_None_None_IC50...
# The length of the raw dataset is 747
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (707, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (641, 34)
# After removing the mols with multiple values, the shape of the df:(498, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 40
# After standardizing the SMILES, the shape of the df: (40, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (40, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(40, 35)
# Done curation.
#
# Processing nor_None_None_EC50...
# The length of the raw dataset is 524
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (458, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (221, 34)
# After removing the mols with multiple values, the shape of the df:(194, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 59
# After standardizing the SMILES, the shape of the df: (59, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (55, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(55, 35)
# Done curation.
#
# ====================
#
# Processing heterogeneous data of GPCRs...
# Processing CHEMBL2434_None_None_Ki...
# The length of the raw dataset is 229
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (223, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (223, 34)
# After removing the mols with multiple values, the shape of the df:(219, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 6
# After standardizing the SMILES, the shape of the df: (6, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (6, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(6, 35)
# Done curation.
#
# Processing CHEMBL2434_None_None_IC50...
# The length of the raw dataset is 1264
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1264, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1264, 34)
# After removing the mols with multiple values, the shape of the df:(921, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing CHEMBL2434_None_None_EC50...
# The length of the raw dataset is 1
# Curating dataset
# start standardizing with value
# Failed curating the dataset due to cannot set a frame with no defined index and a scalar
# After standardizing the SMILES, the shape of the df: (1, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After removing the mols with multiple values, the shape of the df:(1, 35)
# start applying thresholds
# Applying thresholds
# ====================
#
# Processing CHEMBL4523255_None_None_Ki...
# No dataset for CHEMBL4523255-Ki
# Processing CHEMBL4523255_None_None_IC50...
# No dataset for CHEMBL4523255-IC50
# Processing CHEMBL4523255_None_None_EC50...
# The length of the raw dataset is 2
# Curating dataset
# start standardizing with value
# Failed curating the dataset due to cannot set a frame with no defined index and a scalar
# After standardizing the SMILES, the shape of the df: (1, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After removing the mols with multiple values, the shape of the df:(1, 35)
# start applying thresholds
# Applying thresholds
# ====================
#
# Processing CHEMBL3785_None_None_Ki...
# The length of the raw dataset is 47
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (47, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (47, 34)
# After removing the mols with multiple values, the shape of the df:(25, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing CHEMBL3785_None_None_IC50...
# The length of the raw dataset is 335
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (330, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (330, 34)
# After removing the mols with multiple values, the shape of the df:(291, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 4
# After standardizing the SMILES, the shape of the df: (4, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(4, 35)
# Done curation.
#
# Processing CHEMBL3785_None_None_EC50...
# The length of the raw dataset is 758
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (750, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (750, 34)
# After removing the mols with multiple values, the shape of the df:(625, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 8
# After standardizing the SMILES, the shape of the df: (8, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (8, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(8, 35)
# Done curation.
#
# ====================
#
# Processing CHEMBL1075144_None_None_Ki...
# The length of the raw dataset is 4
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (4, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4, 34)
# After removing the mols with multiple values, the shape of the df:(4, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing CHEMBL1075144_None_None_IC50...
# The length of the raw dataset is 55
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (49, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2, 34)
# After removing the mols with multiple values, the shape of the df:(2, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 6
# Failed curating the dataset due to index 0 is out of bounds for axis 0 with size 0
# After standardizing the SMILES, the shape of the df: (6, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (0, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(0, 35)
# Processing CHEMBL1075144_None_None_EC50...
# The length of the raw dataset is 159
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (135, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (13, 34)
# After removing the mols with multiple values, the shape of the df:(11, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 24
# After standardizing the SMILES, the shape of the df: (24, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (24, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(24, 35)
# Done curation.
#
# ====================
#
# Processing CHEMBL3371_None_None_Ki...
# The length of the raw dataset is 4721
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (4592, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4592, 34)
# After removing the mols with multiple values, the shape of the df:(3867, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 129
# After standardizing the SMILES, the shape of the df: (129, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (129, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(117, 35)
# Done curation.
#
# Processing CHEMBL3371_None_None_IC50...
# The length of the raw dataset is 959
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (939, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (939, 34)
# After removing the mols with multiple values, the shape of the df:(829, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 20
# After standardizing the SMILES, the shape of the df: (20, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (20, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(20, 35)
# Done curation.
#
# Processing CHEMBL3371_None_None_EC50...
# The length of the raw dataset is 150
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (135, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (135, 34)
# After removing the mols with multiple values, the shape of the df:(123, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 15
# After standardizing the SMILES, the shape of the df: (15, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (15, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(15, 35)
# Done curation.
#
# ====================
#
# Processing CHEMBL1811_None_None_Ki...
# The length of the raw dataset is 513
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (465, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (464, 34)
# After removing the mols with multiple values, the shape of the df:(411, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 48
# After standardizing the SMILES, the shape of the df: (48, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (48, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(48, 35)
# Done curation.
#
# Processing CHEMBL1811_None_None_IC50...
# The length of the raw dataset is 757
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (729, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (729, 34)
# After removing the mols with multiple values, the shape of the df:(670, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 28
# After standardizing the SMILES, the shape of the df: (28, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (28, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(28, 35)
# Done curation.
#
# Processing CHEMBL1811_None_None_EC50...
# The length of the raw dataset is 143
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (52, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (52, 34)
# After removing the mols with multiple values, the shape of the df:(47, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 91
# After standardizing the SMILES, the shape of the df: (91, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (91, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(90, 35)
# Done curation.
#
# ====================
#
# Processing CHEMBL2321627_None_None_Ki...
# No dataset for CHEMBL2321627-Ki
# Processing CHEMBL2321627_None_None_IC50...
# The length of the raw dataset is 173
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (173, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (173, 34)
# After removing the mols with multiple values, the shape of the df:(146, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing CHEMBL2321627_None_None_EC50...
# No dataset for CHEMBL2321627-EC50
# ====================
#
# Processing CHEMBL2736_None_None_Ki...
# The length of the raw dataset is 86
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (86, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (86, 34)
# After removing the mols with multiple values, the shape of the df:(77, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing CHEMBL2736_None_None_IC50...
# The length of the raw dataset is 165
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (120, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (120, 34)
# After removing the mols with multiple values, the shape of the df:(96, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 45
# After standardizing the SMILES, the shape of the df: (45, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (45, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(45, 35)
# Done curation.
#
# Processing CHEMBL2736_None_None_EC50...
# The length of the raw dataset is 1262
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (1192, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1192, 34)
# After removing the mols with multiple values, the shape of the df:(948, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 70
# After standardizing the SMILES, the shape of the df: (70, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (70, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(70, 35)
# Done curation.
#
# ====================
#
# Processing CHEMBL4561_None_None_Ki...
# The length of the raw dataset is 741
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (701, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (475, 34)
# After removing the mols with multiple values, the shape of the df:(456, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 40
# After standardizing the SMILES, the shape of the df: (40, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (23, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(22, 35)
# Done curation.
#
# Processing CHEMBL4561_None_None_IC50...
# The length of the raw dataset is 883
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (850, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (847, 34)
# After removing the mols with multiple values, the shape of the df:(787, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 33
# After standardizing the SMILES, the shape of the df: (33, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (33, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(33, 35)
# Done curation.
#
# Processing CHEMBL4561_None_None_EC50...
# The length of the raw dataset is 59
# Curating dataset
# start standardizing with value
# Failed curating the dataset due to cannot set a frame with no defined index and a scalar
# After standardizing the SMILES, the shape of the df: (55, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After removing the mols with multiple values, the shape of the df:(1, 35)
# start applying thresholds
# Applying thresholds
# ====================
#
# Processing CHEMBL1075178_None_None_Ki...
# The length of the raw dataset is 4
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (4, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4, 34)
# After removing the mols with multiple values, the shape of the df:(4, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 0
# Done curation.
#
# Processing CHEMBL1075178_None_None_IC50...
# The length of the raw dataset is 55
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (49, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2, 34)
# After removing the mols with multiple values, the shape of the df:(2, 35)
# start applying thresholds
# Applying thresholds
# The length of df_novalue is 6
# Failed curating the dataset due to index 0 is out of bounds for axis 0 with size 0
# After standardizing the SMILES, the shape of the df: (6, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (0, 34)
# After dropping the duplicate combinations of (smiles, value) , the shape of the df:(0, 35)
# Processing CHEMBL1075178_None_None_EC50...
# The length of the raw dataset is 125
# Curating dataset
# start standardizing with value
# Failed curating the dataset due to cannot set a frame with no defined index and a scalar
# After standardizing the SMILES, the shape of the df: (125, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After removing the mols with multiple values, the shape of the df:(1, 35)
# start applying thresholds
# Applying thresholds
# ====================
#
# Processing CHEMBL234_None_None_Ki...
# The length of the raw dataset is 6650
# Curating dataset
# start standardizing with value
# After standardizing the SMILES, the shape of the df: (6465, 34)
# ...
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4596_None_None_IC50...
# The length of the raw dataset is 141
# Curating dataset
# After standardizing the SMILES, the shape of the df: (135, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (135, 34)
# After removing the mols with multiple values, the shape of the df:(125, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4596_None_None_EC50...
# The length of the raw dataset is 45
# Curating dataset
# After standardizing the SMILES, the shape of the df: (45, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (45, 34)
# After removing the mols with multiple values, the shape of the df:(23, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL4333_None_None_Ki...
# The length of the raw dataset is 144
# Curating dataset
# After standardizing the SMILES, the shape of the df: (144, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (144, 34)
# After removing the mols with multiple values, the shape of the df:(139, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4333_None_None_IC50...
# The length of the raw dataset is 645
# Curating dataset
# After standardizing the SMILES, the shape of the df: (642, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (642, 34)
# After removing the mols with multiple values, the shape of the df:(574, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4333_None_None_EC50...
# The length of the raw dataset is 2553
# Curating dataset
# After standardizing the SMILES, the shape of the df: (2496, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2496, 34)
# After removing the mols with multiple values, the shape of the df:(2140, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL6144_None_None_Ki...
# The length of the raw dataset is 10
# Curating dataset
# After standardizing the SMILES, the shape of the df: (10, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (10, 34)
# After removing the mols with multiple values, the shape of the df:(10, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL6144_None_None_IC50...
# The length of the raw dataset is 231
# Curating dataset
# After standardizing the SMILES, the shape of the df: (231, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (231, 34)
# After removing the mols with multiple values, the shape of the df:(213, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL6144_None_None_EC50...
# No dataset for CHEMBL6144-EC50
# ====================
#
# Processing CHEMBL1875_None_None_Ki...
# The length of the raw dataset is 603
# Curating dataset
# After standardizing the SMILES, the shape of the df: (555, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (534, 34)
# After removing the mols with multiple values, the shape of the df:(454, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL1875_None_None_IC50...
# The length of the raw dataset is 91
# Curating dataset
# After standardizing the SMILES, the shape of the df: (91, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (91, 34)
# After removing the mols with multiple values, the shape of the df:(89, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL1875_None_None_EC50...
# The length of the raw dataset is 405
# Curating dataset
# After standardizing the SMILES, the shape of the df: (405, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (404, 34)
# After removing the mols with multiple values, the shape of the df:(350, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL3777_None_None_Ki...
# The length of the raw dataset is 19
# Curating dataset
# After standardizing the SMILES, the shape of the df: (19, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (19, 34)
# After removing the mols with multiple values, the shape of the df:(18, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL3777_None_None_IC50...
# The length of the raw dataset is 63
# Curating dataset
# After standardizing the SMILES, the shape of the df: (63, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (63, 34)
# After removing the mols with multiple values, the shape of the df:(46, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL3777_None_None_EC50...
# The length of the raw dataset is 133
# Curating dataset
# After standardizing the SMILES, the shape of the df: (128, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (128, 34)
# After removing the mols with multiple values, the shape of the df:(114, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL1867_None_None_Ki...
# The length of the raw dataset is 1053
# Curating dataset
# After standardizing the SMILES, the shape of the df: (979, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (977, 34)
# After removing the mols with multiple values, the shape of the df:(816, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL1867_None_None_IC50...
# The length of the raw dataset is 167
# Curating dataset
# After standardizing the SMILES, the shape of the df: (158, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (157, 34)
# After removing the mols with multiple values, the shape of the df:(149, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL1867_None_None_EC50...
# The length of the raw dataset is 171
# Curating dataset
# After standardizing the SMILES, the shape of the df: (166, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (165, 34)
# After removing the mols with multiple values, the shape of the df:(129, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL3638324_None_None_Ki...
# No dataset for CHEMBL3638324-Ki
# Processing CHEMBL3638324_None_None_IC50...
# The length of the raw dataset is 84
# Curating dataset
# After standardizing the SMILES, the shape of the df: (84, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (84, 34)
# After removing the mols with multiple values, the shape of the df:(73, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL3638324_None_None_EC50...
# No dataset for CHEMBL3638324-EC50
# ====================
#
# Processing CHEMBL4421_None_None_Ki...
# No dataset for CHEMBL4421-Ki
# Processing CHEMBL4421_None_None_IC50...
# The length of the raw dataset is 5
# Curating dataset
# After standardizing the SMILES, the shape of the df: (4, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (4, 34)
# After removing the mols with multiple values, the shape of the df:(4, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4421_None_None_EC50...
# The length of the raw dataset is 148
# Curating dataset
# After standardizing the SMILES, the shape of the df: (140, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (140, 34)
# After removing the mols with multiple values, the shape of the df:(122, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL4295740_None_None_Ki...
# No dataset for CHEMBL4295740-Ki
# Processing CHEMBL4295740_None_None_IC50...
# The length of the raw dataset is 15
# Curating dataset
# Failed curating the dataset due to Expected a 1D array, got an array with shape (0, 34)
# After standardizing the SMILES, the shape of the df: (15, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (0, 34)
# Processing CHEMBL4295740_None_None_EC50...
# No dataset for CHEMBL4295740-EC50
# ====================
#
# Processing CHEMBL3988599_None_None_Ki...
# No dataset for CHEMBL3988599-Ki
# Processing CHEMBL3988599_None_None_IC50...
# The length of the raw dataset is 371
# Curating dataset
# After standardizing the SMILES, the shape of the df: (371, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (371, 34)
# After removing the mols with multiple values, the shape of the df:(321, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL3988599_None_None_EC50...
# The length of the raw dataset is 1
# Curating dataset
# Failed curating the dataset due to cannot set a frame with no defined index and a scalar
# After standardizing the SMILES, the shape of the df: (1, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After removing the mols with multiple values, the shape of the df:(1, 35)
# Applying thresholds
# ====================
#
# Processing CHEMBL1987_None_None_Ki...
# The length of the raw dataset is 125
# Curating dataset
# After standardizing the SMILES, the shape of the df: (103, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (103, 34)
# After removing the mols with multiple values, the shape of the df:(96, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL1987_None_None_IC50...
# The length of the raw dataset is 147
# Curating dataset
# After standardizing the SMILES, the shape of the df: (147, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (147, 34)
# After removing the mols with multiple values, the shape of the df:(113, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL1987_None_None_EC50...
# The length of the raw dataset is 165
# Curating dataset
# After standardizing the SMILES, the shape of the df: (66, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (66, 34)
# After removing the mols with multiple values, the shape of the df:(65, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL4105907_None_None_Ki...
# The length of the raw dataset is 694
# Curating dataset
# After standardizing the SMILES, the shape of the df: (678, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (671, 34)
# After removing the mols with multiple values, the shape of the df:(513, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4105907_None_None_IC50...
# The length of the raw dataset is 2
# Curating dataset
# After standardizing the SMILES, the shape of the df: (2, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (2, 34)
# After removing the mols with multiple values, the shape of the df:(2, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4105907_None_None_EC50...
# No dataset for CHEMBL4105907-EC50
# ====================
#
# Processing CHEMBL4398_None_None_Ki...
# The length of the raw dataset is 18
# Curating dataset
# After standardizing the SMILES, the shape of the df: (18, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (18, 34)
# After removing the mols with multiple values, the shape of the df:(15, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4398_None_None_IC50...
# The length of the raw dataset is 102
# Curating dataset
# After standardizing the SMILES, the shape of the df: (99, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (95, 34)
# After removing the mols with multiple values, the shape of the df:(81, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4398_None_None_EC50...
# The length of the raw dataset is 392
# Curating dataset
# After standardizing the SMILES, the shape of the df: (370, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (346, 34)
# After removing the mols with multiple values, the shape of the df:(251, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL4777_None_None_Ki...
# The length of the raw dataset is 854
# Curating dataset
# After standardizing the SMILES, the shape of the df: (831, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (461, 34)
# After removing the mols with multiple values, the shape of the df:(416, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4777_None_None_IC50...
# The length of the raw dataset is 435
# Curating dataset
# After standardizing the SMILES, the shape of the df: (406, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (345, 34)
# After removing the mols with multiple values, the shape of the df:(297, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL4777_None_None_EC50...
# The length of the raw dataset is 73
# Curating dataset
# Failed curating the dataset due to cannot set a frame with no defined index and a scalar
# After standardizing the SMILES, the shape of the df: (68, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After removing the mols with multiple values, the shape of the df:(1, 35)
# Applying thresholds
# ====================
#
# Processing CHEMBL1854_None_None_Ki...
# The length of the raw dataset is 1
# Curating dataset
# Failed curating the dataset due to cannot set a frame with no defined index and a scalar
# After standardizing the SMILES, the shape of the df: (1, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (1, 34)
# After removing the mols with multiple values, the shape of the df:(1, 35)
# Applying thresholds
# Processing CHEMBL1854_None_None_IC50...
# The length of the raw dataset is 50
# Curating dataset
# After standardizing the SMILES, the shape of the df: (50, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (50, 34)
# After removing the mols with multiple values, the shape of the df:(37, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL1854_None_None_EC50...
# The length of the raw dataset is 45
# Curating dataset
# After standardizing the SMILES, the shape of the df: (33, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (23, 34)
# After removing the mols with multiple values, the shape of the df:(22, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL1925_None_None_Ki...
# The length of the raw dataset is 2
# Curating dataset
# Failed curating the dataset due to Expected a 1D array, got an array with shape (0, 34)
# After standardizing the SMILES, the shape of the df: (2, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (0, 34)
# Processing CHEMBL1925_None_None_IC50...
# No dataset for CHEMBL1925-IC50
# Processing CHEMBL1925_None_None_EC50...
# The length of the raw dataset is 2
# Curating dataset
# Failed curating the dataset due to Expected a 1D array, got an array with shape (0, 34)
# After standardizing the SMILES, the shape of the df: (2, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (0, 34)
# ====================
#
# Processing CHEMBL1821_None_None_Ki...
# The length of the raw dataset is 967
# Curating dataset
# After standardizing the SMILES, the shape of the df: (906, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (781, 34)
# After removing the mols with multiple values, the shape of the df:(676, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL1821_None_None_IC50...
# The length of the raw dataset is 408
# Curating dataset
# After standardizing the SMILES, the shape of the df: (400, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (395, 34)
# After removing the mols with multiple values, the shape of the df:(268, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL1821_None_None_EC50...
# The length of the raw dataset is 931
# Curating dataset
# After standardizing the SMILES, the shape of the df: (894, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (893, 34)
# After removing the mols with multiple values, the shape of the df:(630, 35)
# Applying thresholds
# Done curation.
#
# ====================
#
# Processing CHEMBL3911_None_None_Ki...
# The length of the raw dataset is 193
# Curating dataset
# After standardizing the SMILES, the shape of the df: (193, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (193, 34)
# After removing the mols with multiple values, the shape of the df:(142, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL3911_None_None_IC50...
# The length of the raw dataset is 384
# Curating dataset
# After standardizing the SMILES, the shape of the df: (376, 34)
# After dropping the mols with MW > 900.0 , the shape of the df: (369, 34)
# After removing the mols with multiple values, the shape of the df:(217, 35)
# Applying thresholds
# Done curation.
#
# Processing CHEMBL3911_None_None_EC50...
# No dataset for CHEMBL3911-EC50
# ====================
