# %%
# conda env: pyg(Python 3.9.16)
import os
import pandas as pd

import seaborn as sns
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

from datacat4ml.utils import mkdirs
from datacat4ml.const import FETCH_DATA_DIR, HET_OR_DIR, HET_GPCR_DIR, CAT_OR_DIR, CAT_GPCR_DIR, CAT_FIG_DIR
from datacat4ml.const import OR_names, OR_chemblids,OR_name_chemblids
from datacat4ml.Scripts.data_prep.data_categorize.categorize_regex import categorize_GPCRs, categorize_ORs, OR_dfs, GPCR_dfs, ki_gpcr_df
# Out:
# /storage/homefs/yc24j783/datacat4ml/datacat4ml/Scripts/data_prep/data_categorize/categorize_regex.py:9: DtypeWarning: Columns (10,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   ki_gpcr_df = pd.read_csv(os.path.join(FETCH_DATA_DIR, 'Ki_gpcr_maxcur_8_data.csv'))
# /storage/homefs/yc24j783/datacat4ml/datacat4ml/Scripts/data_prep/data_categorize/categorize_regex.py:10: DtypeWarning: Columns (10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   ic50_gpcr_df = pd.read_csv(os.path.join(FETCH_DATA_DIR, 'IC50_gpcr_maxcur_8_data.csv'))
# /storage/homefs/yc24j783/datacat4ml/datacat4ml/Scripts/data_prep/data_categorize/categorize_regex.py:11: DtypeWarning: Columns (10,16,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   ec50_gpcr_df = pd.read_csv(os.path.join(FETCH_DATA_DIR, 'EC50_gpcr_maxcur_8_data.csv'))

# %%
ki_gpcr_df.columns
# Out:
# Index(['assay_id', 'assay_chembl_id', 'tid', 'target_chembl_id',
#        'standard_type', 'standard_relation', 'standard_value',
#        'standard_units', 'pchembl_value', 'assay_type', 'assay_category',
#        'assay_organism', 'assay_tax_id', 'assay_strain', 'assay_tissue',
#        'assay_cell_type', 'assay_subcellular_fraction', 'bao_format',
#        'variant_id', 'assay_test_type', 'assay_desc', 'cell_id', 'tissue_id',
#        'curated_by', 'relationship_type', 'aidx', 'confidence_score',
#        'molregno', 'compound_chembl_id', 'canonical_smiles',
#        'assay_info_hash'],
#       dtype='object')

# %% [markdown]
# # het_datasets: ORs

# %%
for name in OR_names:
    chembl_id = OR_name_chemblids[name]
    or_df = OR_dfs[name]
    for standard_type in ['Ki', 'IC50', 'EC50']:
        or_type_df = or_df[or_df['standard_type'] == standard_type]
        file_path = os.path.join(HET_OR_DIR, chembl_id, standard_type)
        mkdirs(file_path)
        or_type_df.to_csv(os.path.join(file_path, f'{chembl_id}_{standard_type}.csv' ), index=False)

# %% [markdown]
# # het_gpcr_datasets: All GPCRs

# %%
ki_gpcr_df = pd.read_csv(os.path.join(FETCH_DATA_DIR, 'Ki_gpcr_maxcur_8_data.csv'))
ic50_gpcr_df = pd.read_csv(os.path.join(FETCH_DATA_DIR, 'IC50_gpcr_maxcur_8_data.csv'))
ec50_gpcr_df = pd.read_csv(os.path.join(FETCH_DATA_DIR, 'EC50_gpcr_maxcur_8_data.csv'))
# Out:
# /tmp/ipykernel_3553557/384224194.py:1: DtypeWarning: Columns (10,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   ki_gpcr_df = pd.read_csv(os.path.join(FETCH_DATA_DIR, 'Ki_gpcr_maxcur_8_data.csv'))
# /tmp/ipykernel_3553557/384224194.py:2: DtypeWarning: Columns (10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   ic50_gpcr_df = pd.read_csv(os.path.join(FETCH_DATA_DIR, 'IC50_gpcr_maxcur_8_data.csv'))
# /tmp/ipykernel_3553557/384224194.py:3: DtypeWarning: Columns (10,16,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   ec50_gpcr_df = pd.read_csv(os.path.join(FETCH_DATA_DIR, 'EC50_gpcr_maxcur_8_data.csv'))

# %%
for target_chembl_id in ki_gpcr_df['target_chembl_id'].unique():
    target_df = ki_gpcr_df[ki_gpcr_df['target_chembl_id'] == target_chembl_id]
    file_path = os.path.join(HET_GPCR_DIR, target_chembl_id, 'Ki')
    mkdirs(file_path)
    target_df.to_csv(os.path.join(HET_GPCR_DIR, target_chembl_id, 'Ki', f'{target_chembl_id}_Ki.csv'), index=False)

for target_chembl_id in ic50_gpcr_df['target_chembl_id'].unique():
    target_df = ic50_gpcr_df[ic50_gpcr_df['target_chembl_id'] == target_chembl_id]
    file_path = os.path.join(HET_GPCR_DIR, target_chembl_id, 'IC50')
    mkdirs(file_path)
    target_df.to_csv(os.path.join(HET_GPCR_DIR, target_chembl_id, 'IC50', f'{target_chembl_id}_IC50.csv'), index=False)

for target_chembl_id in ec50_gpcr_df['target_chembl_id'].unique():
    target_df = ec50_gpcr_df[ec50_gpcr_df['target_chembl_id'] == target_chembl_id]
    file_path = os.path.join(HET_GPCR_DIR, target_chembl_id, 'EC50')
    mkdirs(file_path)
    target_df.to_csv(os.path.join(HET_GPCR_DIR, target_chembl_id, 'EC50', f'{target_chembl_id}_EC50.csv'), index=False)

# %% [markdown]
# # cat_datasets (ORs) & cat_gpcr_datasets

# %% [markdown]
# ## Radio
# radioligand replacement binding assay

# %% [markdown]
# ### binding affinity: Ki, IC50

# %%
# create a boolean mask to filter rows that match p_bind 
# and do not match p_bind_ex
p_bind_RBA = r"(?i)affinity|displacement|3H|125I"
p_bind_RBA_ex = r"(?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis"

# cat_datasets: ORs
or_type_dfs, or_bind_type_dfs, or_bind_plus_dfs, or_bind_exclude_dfs, or_bind_final_dfs, or_bind_len_dfs = categorize_ORs(targets='ORs', effect='bind', assay='RBA', std_types=['Ki', 'IC50'], 
                                                                                        pattern=p_bind_RBA, pattern_ex=p_bind_RBA_ex)
# Out:
# target_chembl_id: CHEMBL233
#
# Target: CHEMBL233
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (5682, 31)
#
# The shape of  is (5418, 31)
# #assay_desc:
# count                                                  5418
# unique                                                  374
# top       Displacement of [3H]-diprenorphine from human ...
# freq                                                    207
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  5418
# unique                                                 4794
# top       C[C@@H](NC(=O)[C@@H](N)Cc1ccc(O)cc1)C(=O)NCC(=...
# freq                                                     39
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (139, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (5557, 31)
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (1366, 31)
#
# The shape of  is (668, 31)
# #assay_desc:
# count                                                   668
# unique                                                   71
# top       Binding affinity against mu-opiate receptor (h...
# freq                                                     46
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   668
# unique                                                  599
# top       C[C@@H](NC(=O)[C@@H](N)Cc1ccc(O)cc1)C(=O)NCC(=...
# freq                                                      7
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (19, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (687, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL237
#
# Target: CHEMBL237
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (4857, 31)
#
# The shape of  is (4535, 31)
# #assay_desc:
# count                                                  4535
# unique                                                  347
# top       Radioligand Binding Assay: Radioligand dose di...
# freq                                                    192
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  4535
# unique                                                 4013
# top       CN(C(=O)Cc1ccc(Cl)c(Cl)c1)[C@@H]1CCCC[C@H]1N1C...
# freq                                                     29
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (140, 31)
#
# The shape of exclude_df is (29, 31)
#
# The shape of final_df is (4646, 31)
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (1049, 31)
#
# The shape of  is (478, 31)
# #assay_desc:
# count                                                   478
# unique                                                   51
# top       Binding affinity against opioid receptor kappa...
# freq                                                     45
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   478
# unique                                                  435
# top       CN(C(=O)Cc1ccc(Cl)c(Cl)c1)[C@@H]1CCCC[C@H]1N1C...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (7, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (485, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL236
#
# Target: CHEMBL236
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (5152, 31)
#
# The shape of  is (4933, 31)
# #assay_desc:
# count                                                  4933
# unique                                                  397
# top       Displacement of [3H]-diprenorphine from human ...
# freq                                                    206
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  4933
# unique                                                 4310
# top       O=C1CC[C@@]2(O)[C@H]3Cc4ccc(O)c5c4[C@@]2(CCN3C...
# freq                                                     37
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (65, 31)
#
# The shape of exclude_df is (1, 31)
#
# The shape of final_df is (4997, 31)
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (1316, 31)
#
# The shape of  is (930, 31)
# #assay_desc:
# count                                                   930
# unique                                                  102
# top       Displacement of [3H]DPDPE from human delta opi...
# freq                                                     48
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   930
# unique                                                  857
# top       CC1(C)SSC(C)(C)[C@@H](NC(=O)[C@@H](N)Cc2ccc(O)...
# freq                                                     10
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (34, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (964, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL2014
#
# Target: CHEMBL2014
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (1381, 31)
#
# The shape of  is (1320, 31)
# #assay_desc:
# count                                                  1320
# unique                                                   76
# top       Displacement of [3H]nociceptin from human NOP ...
# freq                                                    123
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  1320
# unique                                                 1204
# top       CC(C)C[C@H](NC(=O)[C@H](CCCCN)NC(=O)[C@H](CCCN...
# freq                                                     15
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (12, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (1332, 31)
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (747, 31)
#
# The shape of  is (496, 31)
# #assay_desc:
# count                                                   496
# unique                                                   35
# top       Displacement of [125I]Tyr-nociceptin from clon...
# freq                                                     71
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   496
# unique                                                  458
# top       CC(C)C[C@H](NC(=O)[C@H](CCCCN)NC(=O)[C@H](CCCN...
# freq                                                     10
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (11, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (507, 31)
#
# ##########################
# ================================================================

# %%
# cat_datasets: GPCRs
gpcr_type_dfs, gpcr_bind_type_dfs, gpcr_bind_len_dfs = categorize_GPCRs(targets='GPCRs', effect='bind', assay='RBA', std_types=['Ki', 'IC50'], 
                                                    pattern=p_bind_RBA, pattern_ex=p_bind_RBA_ex)
# Out:
# Target: CHEMBL2327
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (873, 31)
#
# The shape of  is (840, 31)
# #assay_desc:
# count                                                   840
# unique                                                   56
# top       Binding affinity for human tachykinin receptor...
# freq                                                     86
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   840
# unique                                                  792
# top       O=C1CCC(=O)N[C@@H](Cc2c[nH]c3ccccc23)C(=O)N[C@...
# freq                                                      5
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (290, 31)
#
# The shape of  is (214, 31)
# #assay_desc:
# count                                                   214
# unique                                                   36
# top       Displacement of [125I]-NKA from NK2 receptor (...
# freq                                                     32
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   214
# unique                                                  209
# top       CCCC[C@H](NC(=O)[C@H](CC(C)C)NC(=O)CNC(=O)[C@@...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3713916
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5144
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (1, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Binding affinity to human VPAC1 receptor by ra...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       CC[C@H](C)[C@H](NC(=O)[C@H](CO)NC(=O)[C@H](CC(...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (18, 31)
#
# The shape of  is (14, 31)
# #assay_desc:
# count                                                    14
# unique                                                    6
# top       Displacement of Ac-[125I]-PACAP27 from recombi...
# freq                                                      6
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    14
# unique                                                   10
# top       CC[C@H](C)[C@H](NC(=O)[C@H](CO)NC(=O)[C@H](CC(...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL223
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (1437, 31)
#
# The shape of  is (1365, 31)
# #assay_desc:
# count                                                  1365
# unique                                                  124
# top       Binding affinity to human cloned adrenergic Al...
# freq                                                     57
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                              1365
# unique                                             1160
# top       COc1cc2nc(N3CCN(C(=O)c4ccco4)CC3)nc(N)c2cc1OC
# freq                                                 16
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (188, 31)
#
# The shape of  is (64, 31)
# #assay_desc:
# count                                                    64
# unique                                                    7
# top       Displacement of radiolabeled Prazosin from alp...
# freq                                                     35
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                64
# unique                               63
# top       c1ccc(-c2ccccc2OCC2=NCCN2)cc1
# freq                                  2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2049
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (821, 31)
#
# The shape of  is (590, 31)
# #assay_desc:
# count                                                   590
# unique                                                   60
# top       Ability to displace [3H]oxytocin from human OT...
# freq                                                     41
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   590
# unique                                                  516
# top       CC[C@H](C)[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=...
# freq                                                     10
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (137, 31)
#
# The shape of  is (35, 31)
# #assay_desc:
# count                                                    35
# unique                                                    4
# top       Displacement of [3H]OT from human OT receptor ...
# freq                                                     21
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    35
# unique                                                   35
# top       CC[C@H](C)[C@@H]1NC(=O)[C@H]([C@@H](C)c2c(C)cc...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075178
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (4, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                             4
# unique                            1
# top       Binding affinity to NMUR1
# freq                              4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                               4
# unique                                              4
# top       O=C(C1CCCCC1)N1CCCN(C(c2ccccc2)c2ccccc2)CC1
# freq                                                1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (55, 31)
#
# The shape of  is (55, 31)
# #assay_desc:
# count                                                    55
# unique                                                    2
# top       Displacement of [3H]-NMU-8 from human NMUR1 ex...
# freq                                                     42
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    55
# unique                                                   53
# top       CC(C)C[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C@@H]...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4714
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (5, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (82, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4308
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (824, 31)
#
# The shape of  is (607, 31)
# #assay_desc:
# count                                                  607
# unique                                                  36
# top       Binding affinity to human bradykinin B1 receptor
# freq                                                    87
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   607
# unique                                                  569
# top       O=C(C[C@@H]1C(=O)Nc2ccccc2N1S(=O)(=O)c1ccc(Cl)...
# freq                                                      5
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (495, 31)
#
# The shape of  is (8, 31)
# #assay_desc:
# count                                                     8
# unique                                                    3
# top       Binding affinity to human bradykinin B1 recept...
# freq                                                      6
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     8
# unique                                                    8
# top       COC(=O)c1c(Cl)cc(Cl)cc1-c1cnc([C@@H](C)NC(=O)[...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1905
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL259
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (2430, 31)
#
# The shape of  is (1957, 31)
# #assay_desc:
# count                                                  1957
# unique                                                   68
# top       Displacement of [125I]NDP-MSH from human MC4R ...
# freq                                                    258
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  1957
# unique                                                 1700
# top       NC1CCC(CC2CCC(N(C/C(Cl)=C/c3ccccc3)C(=O)COc3cc...
# freq                                                      9
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (1065, 31)
#
# The shape of  is (813, 31)
# #assay_desc:
# count                                                   813
# unique                                                   75
# top       Displacement of [125I]Nle4-D-Phe7-alpha-MSH fr...
# freq                                                     64
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   813
# unique                                                  698
# top       CCCC[C@H](NC(C)=O)C(=O)N[C@H]1CC(=O)NCCCC[C@@H...
# freq                                                     11
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4877
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (351, 31)
#
# The shape of  is (351, 31)
# #assay_desc:
# count                                                   351
# unique                                                   24
# top       Displacement of [125I]-PP from human Y4R expre...
# freq                                                     86
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   351
# unique                                                  230
# top       CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O...
# freq                                                      7
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (47, 31)
#
# The shape of  is (28, 31)
# #assay_desc:
# count                                                    28
# unique                                                    8
# top       Displacement of [Lys2(sCy5),Arg4]-BVD-15 from ...
# freq                                                     11
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    28
# unique                                                   25
# top       CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523360
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1833
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (1793, 31)
#
# The shape of  is (1547, 31)
# #assay_desc:
# count                                         1547
# unique                                         177
# top       Binding affinity to human 5HT2B receptor
# freq                                            65
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                    1547
# unique                                   1417
# top       Cn1ccc2cc3c(cc21)CCN3C(=O)Nc1cccnc1
# freq                                        8
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (307, 31)
#
# The shape of  is (46, 31)
# #assay_desc:
# count                                                    46
# unique                                                   23
# top       Displacement of [3H]rauwolsine from human 5HT2...
# freq                                                     10
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                          46
# unique                         41
# top       COc1cc(CC(C)N)c(OC)cc1I
# freq                            5
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1850
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (786, 31)
#
# The shape of  is (589, 31)
# #assay_desc:
# count                                                   589
# unique                                                   81
# top       Displacement of [3H]-SCH23390 from recombinant...
# freq                                                     54
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                              589
# unique                             534
# top       CN1CCc2ccccc2Cc2ccc(O)cc2CC1
# freq                                 5
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (8, 31)
# #assay_desc:
# count                                                     8
# unique                                                    7
# top       Binding affinity to human dopamine D5 receptor...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     8
# unique                                                    6
# top       CN1CCc2cc(Cl)c(O)cc2[C@@H](c2ccccc2)C1.O=C(O)/...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3426
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (562, 31)
#
# The shape of  is (501, 31)
# #assay_desc:
# count                                                   501
# unique                                                   78
# top       Displacement of [3H]LSD from human recombinant...
# freq                                                     40
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                        501
# unique                       459
# top       NCCc1c[nH]c2ccc(O)cc12
# freq                           6
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (50, 31)
# #assay_desc:
# count                                                    50
# unique                                                   19
# top       Displacement of [3H]8-OH-DPAT binding to 5-hyd...
# freq                                                     16
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                         50
# unique                        45
# top       NCCc1c[nH]c2ccc(O)cc12
# freq                           6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3724
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (13, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                                     2
# unique                                                    1
# top       Binding affinity for Lysophosphatidic acid rec...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                           2
# unique                          2
# top       CCCCCCCCCCCCCCP(=O)(O)O
# freq                            1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (163, 31)
#
# The shape of  is (27, 31)
# #assay_desc:
# count                                                    27
# unique                                                    1
# top       Binding affinity to human sphingosine 1-phosph...
# freq                                                     27
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                          27
# unique                                         27
# top       CCCCCCCCOc1c(Cl)cc(CNCCCP(=O)(O)O)cc1Cl
# freq                                            1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2203
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (104, 31)
#
# The shape of  is (102, 31)
# #assay_desc:
# count                                               102
# unique                                                4
# top       Displacement of [125I]motilin from human MOTR
# freq                                                 53
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   102
# unique                                                   95
# top       NC(=O)[C@H](CCc1ccccc1)NC(=O)C1C=CC2(CCNCC2)n2...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (33, 31)
#
# The shape of  is (15, 31)
# #assay_desc:
# count                                                    15
# unique                                                    3
# top       Compound was tested for in vitro motilin recep...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    15
# unique                                                    8
# top       CCC1OC(=O)C(C)C(OC2C[C@@](C)(OC)[C@@H](O)C(C)O...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3636
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (107, 31)
#
# The shape of  is (83, 31)
# #assay_desc:
# count                                                    83
# unique                                                    4
# top       Binding affinity for human neuromedin B(hNMB) ...
# freq                                                     61
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    83
# unique                                                   82
# top       CC(C)c1cccc(C(C)C)c1NC(=O)N[C@@](C)(Cc1c[nH]c2...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (77, 31)
#
# The shape of  is (68, 31)
# #assay_desc:
# count                                                    68
# unique                                                    4
# top       Displacement of [125I]-(D-Tyr0)NMB from human ...
# freq                                                     36
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    68
# unique                                                   64
# top       Cc1ccc2c(c1)NC(c1ccccc1C(F)(F)F)C1=C(CC3(CCCC3...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1963
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (58, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5852
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (13, 31)
#
# The shape of  is (13, 31)
# #assay_desc:
# count                                                    13
# unique                                                    2
# top       Displacement of [125I]-43RFa from human QRFP r...
# freq                                                     11
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                  13
# unique                                 13
# top       Cl.NC(N)=N/N=C/c1ccc(Cl)c(Cl)c1
# freq                                    1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (123, 31)
#
# The shape of  is (29, 31)
# #assay_desc:
# count                                                    29
# unique                                                    3
# top       Displacement of [125I]-QRFP43 from human GPR10...
# freq                                                     22
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    29
# unique                                                   29
# top       N=C(N)NCCC[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (530, 31)
#
# The shape of  is (481, 31)
# #assay_desc:
# count                                 481
# unique                                 40
# top       Binding affinity to TP receptor
# freq                                   46
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   481
# unique                                                  437
# top       O=C(O)c1ccc2c(c1)C(SCCNS(=O)(=O)/C=C/c1ccccc1)...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (766, 31)
#
# The shape of  is (244, 31)
# #assay_desc:
# count                                                   244
# unique                                                   28
# top       Displacement of the high affinity radiolabeled...
# freq                                                     52
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                              244
# unique                                             220
# top       O=C(O)CCCCO/N=C(/c1cccnc1)c1cccc(C(F)(F)F)c1
# freq                                                 3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1790
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (554, 31)
#
# The shape of  is (429, 31)
# #assay_desc:
# count                                                   429
# unique                                                   55
# top       Displacement [3H]Arg human recombinant Vasopre...
# freq                                                     57
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   429
# unique                                                  387
# top       N=C(N)NCCC[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H]1...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (396, 31)
#
# The shape of  is (231, 31)
# #assay_desc:
# count                                                   231
# unique                                                   29
# top       Inhibitory activity against human recombinant ...
# freq                                                     29
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   231
# unique                                                  219
# top       Cc1ccc(F)cc1C(=O)Nc1ccc(C(=O)N2Cc3cccn3Cc3cccc...
# freq                                                      8
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5968
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (10, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1628461
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (89, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2056
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (1836, 31)
#
# The shape of  is (1502, 31)
# #assay_desc:
# count                                                  1502
# unique                                                  146
# top       Displacement of [3H]SCH 23390 from dopamine D1...
# freq                                                     63
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                      1502
# unique                                     1276
# top       CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1
# freq                                         13
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (208, 31)
#
# The shape of  is (79, 31)
# #assay_desc:
# count                                                    79
# unique                                                   25
# top       Reception Binding Assay: Different concentrati...
# freq                                                     25
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                    79
# unique                                   65
# top       CN1CCc2cc(Cl)c(O)cc2C(c2ccccc2)C1
# freq                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293293
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (217, 31)
#
# The shape of  is (12, 31)
# #assay_desc:
# count                                                    12
# unique                                                    1
# top       Displacement of [125]-hNPW23 from human NPBWR1...
# freq                                                     12
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    12
# unique                                                   12
# top       COc1ccc(C2(N[C@@H]3CC[C@H](C(=O)N4CCN(c5nc6cc(...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3228
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (20, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                              2
# unique                             2
# top       Binding affinity at mGluR8
# freq                               1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                  2
# unique                                 2
# top       N#Cc1cc(F)cc(C#Cc2csc(CF)n2)c1
# freq                                   1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (56, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                                     2
# unique                                                    1
# top       Inhibitory concentration against [3H]1 binding...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                           2
# unique                          2
# top       N[C@@H](CCC(=O)O)C(=O)O
# freq                            1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL218
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (5414, 31)
#
# The shape of  is (5182, 31)
# #assay_desc:
# count                                                  5182
# unique                                                  278
# top       Displacement of [3H]CP-55940 from human recomb...
# freq                                                    241
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  5182
# unique                                                 4293
# top       Cc1c(C(=O)c2cccc3ccccc23)c2cccc3c2n1[C@H](CN1C...
# freq                                                     65
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (2108, 31)
#
# The shape of  is (875, 31)
# #assay_desc:
# count                                                   875
# unique                                                   73
# top       Displacement of [3H]CP-55940 from human recomb...
# freq                                                     80
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   875
# unique                                                  803
# top       CCCCCCC(C)(C)c1ccc([C@@H]2C[C@H](O)CC[C@H]2CCC...
# freq                                                     10
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL264
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (5019, 31)
#
# The shape of  is (4333, 31)
# #assay_desc:
# count                                                4333
# unique                                                261
# top       Binding affinity to human histamine H3 receptor
# freq                                                  271
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                   4333
# unique                                  3639
# top       S=C(NC1CCCCC1)N1CCC(c2cnc[nH]2)CC1
# freq                                      29
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (797, 31)
#
# The shape of  is (185, 31)
# #assay_desc:
# count                                                   185
# unique                                                   10
# top       Displacement of [125H]iodoproxyphan from human...
# freq                                                     55
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                              185
# unique                                             176
# top       N#Cc1ccc(C2C[C@@H]2C(=O)N2CCN(C3CCC3)CC2)cc1
# freq                                                 3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1854
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (1, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                              1
# unique                                             1
# top       Displacement of [125I]hCG from LH receptor
# freq                                               1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       CC(C)(C)c1ccc(-n2nc(-c3cccnc3)cc2CCCCC(=O)N[C@...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (50, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Displacement of [3H]Org43553 from human lutein...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                1
# unique                                               1
# top       O=C(NC1CCCC1)Oc1cc(-c2ccccc2)cc(-c2ccccc2)c1
# freq                                                 1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3399910
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (5, 31)
#
# The shape of  is (5, 31)
# #assay_desc:
# count                                                     5
# unique                                                    1
# top       Displacement of [3H]RTI-33 from GPR88 (unknown...
# freq                                                      5
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     5
# unique                                                    5
# top       COCc1ccc(-c2ccc(N(C[C@@H](N)[C@@H](C)OC)C(=O)[...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4296246
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5201
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2731
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (27, 31)
#
# The shape of  is (27, 31)
# #assay_desc:
# count                                                    27
# unique                                                    2
# top       Displacement of [125I]galanin from human galan...
# freq                                                     19
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  27
# unique                                                 26
# top       O=C1/C(=N/c2cccc(C(F)(F)F)c2)c2ccccc2N1c1ccccc1
# freq                                                    2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4616
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (752, 31)
#
# The shape of  is (700, 31)
# #assay_desc:
# count                                                   700
# unique                                                   25
# top       Displacement of [125I]-Ghrelin from human GSHR...
# freq                                                    363
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   700
# unique                                                  657
# top       COc1ccc(CC(=O)N2CCC3(CC2)CN([C@@H]2CCc4cc(-c5n...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (1395, 31)
#
# The shape of  is (803, 31)
# #assay_desc:
# count                                                   803
# unique                                                   41
# top       Displacement of [125I-His9]ghrelin from human ...
# freq                                                     66
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   803
# unique                                                  650
# top       CCCCCCCC(=O)OC[C@H](NC(=O)CNC(=O)[C@@H](N)CCCN...
# freq                                                      7
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2384898
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (142, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075144
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (4, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                             4
# unique                            1
# top       Binding affinity to NMUR2
# freq                              4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# ...
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1832
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (15, 31)
#
# The shape of  is (15, 31)
# #assay_desc:
# count                                                    15
# unique                                                    3
# top       Inhibition of [125I]-salmon calcitonin (sCT) b...
# freq                                                     13
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    15
# unique                                                   15
# top       CC(C)C[C@H](NC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (169, 31)
#
# The shape of  is (169, 31)
# #assay_desc:
# count                                                   169
# unique                                                    3
# top       Displacement of [125I]-labeled human calcitoni...
# freq                                                     91
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   169
# unique                                                  116
# top       CC(C)C[C@H](NC(=O)[C@H](CCCNC(=N)N)NC(=O)CNC(=...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4596
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (76, 31)
#
# The shape of  is (76, 31)
# #assay_desc:
# count                                                    76
# unique                                                    2
# top       Binding affinity to human CCR8 expressed in L1...
# freq                                                     61
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    76
# unique                                                   75
# top       Cc1ccccc1C(=O)Nc1ccc(S(=O)(=O)NC2CCN(C(=O)[C@@...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                            1
# unique                           1
# top       Binding affinity to CCR8
# freq                             1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       O=C(NCc1cc(C(F)(F)F)cc(C(F)(F)F)c1)[C@@H](NCCN...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5071
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (1164, 31)
#
# The shape of  is (1013, 31)
# #assay_desc:
# count                                                  1013
# unique                                                   32
# top       Radioligand Binding Assay: The CRTH2 receptor ...
# freq                                                    215
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  1013
# unique                                                  978
# top       CN([C@@H]1CCc2c(CC(=O)O)c3ccccc3n2C1)S(=O)(=O)...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (2960, 31)
#
# The shape of  is (1672, 31)
# #assay_desc:
# count                                                  1672
# unique                                                   52
# top       Radioligand Displacement Assay: Binding assay ...
# freq                                                    449
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  1672
# unique                                                 1465
# top       CCCCNC(=O)c1ccc(Oc2ccc(CC(=O)O)cc2OC)c(NS(=O)(...
# freq                                                      7
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2024
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (69, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4295740
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (15, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5844
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (9, 31)
# #assay_desc:
# count                                                     9
# unique                                                    1
# top       Binding affinity towards GLP-2 receptor in hum...
# freq                                                      9
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     9
# unique                                                    9
# top       CC[C@H](C)[C@H](NC(=O)[C@H](CO)NC(=O)[C@H](CCS...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL234
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (6650, 31)
#
# The shape of  is (5618, 31)
# #assay_desc:
# count                                                  5618
# unique                                                  419
# top       Displacement of [3H]spiperone from human D3 re...
# freq                                                    131
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             5618
# unique                                            4565
# top       O=C(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1
# freq                                                50
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (383, 31)
#
# The shape of  is (102, 31)
# #assay_desc:
# count                                                   102
# unique                                                   24
# top       Binding affinity to cloned human Dopamine rece...
# freq                                                     17
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   102
# unique                                                   96
# top       CC(C)(C)[C@@]1(O)CCN2C[C@@H]3c4ccccc4CCc4cccc(...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL219
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (3763, 31)
#
# The shape of  is (3556, 31)
# #assay_desc:
# count                                                  3556
# unique                                                  325
# top       Displacement of [3H]N-methylspiperone from D4 ...
# freq                                                    102
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                      3556
# unique                                     2824
# top       CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1
# freq                                         53
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (407, 31)
#
# The shape of  is (253, 31)
# #assay_desc:
# count                                                   253
# unique                                                   27
# top       Displacement of [3H]-Spiperone from human reco...
# freq                                                     51
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                       253
# unique                                      232
# top       CN1CCN(C2=Nc3cc(Cl)ccc3Nc3ccccc32)CC1
# freq                                          7
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1805
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (151, 31)
#
# The shape of  is (150, 31)
# #assay_desc:
# count                                                   150
# unique                                                   29
# top       In vitro binding affinity was determined by ra...
# freq                                                     58
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                150
# unique                                               139
# top       CN1CCC(c2c[nH]c3ccc(NC(=O)c4ccc(F)cc4)cc23)CC1
# freq                                                   5
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (17, 31)
#
# The shape of  is (5, 31)
# #assay_desc:
# count                                                     5
# unique                                                    4
# top       Compound was evaluated for the affinity at 5-h...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                         5
# unique                                        5
# top       CNS(=O)(=O)Cc1ccc2[nH]cc(CCN(C)C)c2c1
# freq                                          1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4235
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (308, 31)
#
# The shape of  is (132, 31)
# #assay_desc:
# count                                                   132
# unique                                                    9
# top       Inhibition of human recombinant 11beta-HSD1 ex...
# freq                                                     33
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                 132
# unique                                                130
# top       C[C@H](NC1=NC(=O)[C@@](C)(C(F)(F)F)S1)c1ccccc1F
# freq                                                    2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (4732, 31)
#
# The shape of  is (1253, 31)
# #assay_desc:
# count                                                  1253
# unique                                                   64
# top       Inhibition of human 11 beta-HSD1 expressed in ...
# freq                                                     52
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  1253
# unique                                                  883
# top       CC1(C)[C@@H](O)CC[C@]2(C)[C@H]3C(=O)C=C4[C@@H]...
# freq                                                      8
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1798
#
# Effect: bind
#
# Assay: RBA
#
# Pattern: (?i)affinity|displacement|3H|125I
#
# Pattern_ex: (?i)camp|gtp|calcium|ca2+|IP1|IP3|arrest|agonis
#
# Standard type: Ki
#
# The shape of type_df is (4, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                                                     4
# unique                                                    4
# top       Binding affinity against Cysteinyl leukotriene...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     4
# unique                                                    3
# top       CCCCC/C=C\C/C=C\C=C\C=C\[C@@H](SC[C@H](N)C(=O)...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: IC50
#
# The shape of type_df is (268, 31)
#
# The shape of  is (15, 31)
# #assay_desc:
# count                                                    15
# unique                                                    4
# top       In vitro inhibition of [3H]-LTD4 binding to LT...
# freq                                                     12
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    15
# unique                                                   15
# top       CCCc1c(OCC(O)COc2ccc3c(=O)cc(C(=O)O)oc3c2CCC)c...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================

# %% [markdown]
# ## G_GTP

# %% [markdown]
# ### Agonism: EC50

# %%
# G-protein dependent functional assays
# GTPgamma binding assay
p_agon_G_GTP = r"(?i)gtp"
p_agon_G_GTP_ex = r"(?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric" 

# cat_datasets: ORs
or_type_dfs, or_agon_G_GTP_dfs, or_agon_G_GTP_plus_dfs, or_agon_G_GTP_exclude_dfs, or_agon_G_GTP_final_dfs, or_agon_G_GTP_len_dfs = categorize_ORs(targets='ORs', effect='agon', assay='G_GTP', std_types=['EC50'], 
                                                                                    pattern=p_agon_G_GTP, pattern_ex=p_agon_G_GTP_ex)
# Out:
# target_chembl_id: CHEMBL233
#
# Target: CHEMBL233
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2296, 31)
#
# The shape of  is (1067, 31)
# #assay_desc:
# count                                                  1067
# unique                                                  123
# top       [35S]GTPγS Functional Assay: [35S]GTPγS functi...
# freq                                                     64
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  1067
# unique                                                  955
# top       C[C@@H](NC(=O)[C@@H](N)Cc1ccc(O)cc1)C(=O)NCC(=...
# freq                                                     33
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (80, 31)
#
# The shape of exclude_df is (23, 31)
#
# The shape of final_df is (1124, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL237
#
# Target: CHEMBL237
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2062, 31)
#
# The shape of  is (1365, 31)
# #assay_desc:
# count                                                  1365
# unique                                                  142
# top       Functional Assay: Functional [35S]GTPgammaS bi...
# freq                                                     88
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  1365
# unique                                                 1202
# top       CN(C(=O)Cc1ccc(Cl)c(Cl)c1)[C@@H]1CCCC[C@H]1N1C...
# freq                                                     30
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (103, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (1468, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL236
#
# Target: CHEMBL236
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1324, 31)
#
# The shape of  is (837, 31)
# #assay_desc:
# count                                                   837
# unique                                                   87
# top       Agonist activity at human delta opioid recepto...
# freq                                                     67
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   837
# unique                                                  678
# top       CC1(C)SSC(C)(C)[C@@H](NC(=O)[C@@H](N)Cc2ccc(O)...
# freq                                                     18
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (85, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (922, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL2014
#
# Target: CHEMBL2014
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (524, 31)
#
# The shape of  is (286, 31)
# #assay_desc:
# count                                                   286
# unique                                                   47
# top       Agonist activity at human NOP assessed as stim...
# freq                                                     25
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   286
# unique                                                  264
# top       CC(C)C[C@H](NC(=O)[C@H](CCCCN)NC(=O)[C@H](CCCN...
# freq                                                     14
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (28, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (314, 31)
#
# ##########################
# ================================================================

# %%
# cat_datasets: GPCRs
gpcr_type_dfs, gpcr_agon_G_GTP_dfs, gpcr_agon_G_GTP_len_dfs = categorize_GPCRs(targets='GPCRs', effect='agon', assay='G_GTP', std_types=['EC50'], 
                                                                                    pattern=p_agon_G_GTP, pattern_ex=p_agon_G_GTP_ex)
# Out:
# Target: CHEMBL2327
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (5, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3713916
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5144
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (38, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL223
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (247, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2049
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (492, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075178
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (125, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4714
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (356, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4308
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1905
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL259
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1564, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4877
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (379, 31)
#
# The shape of  is (18, 31)
# #assay_desc:
# count                                                    18
# unique                                                    2
# top       Agonist activity at human Y4 receptor expresse...
# freq                                                     16
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    18
# unique                                                   18
# top       CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523360
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1833
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (935, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1850
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (35, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3426
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3724
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (108, 31)
#
# The shape of  is (11, 31)
# #assay_desc:
# count                                                    11
# unique                                                    3
# top       Agonistic activity against lysophosphatidic ac...
# freq                                                      9
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             11
# unique                                            10
# top       CCCCCCCC/C=C\CCCCCCCC(=O)NCCC(=O)P(=O)(O)O
# freq                                               2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2203
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (164, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3636
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (10, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1963
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (40, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5852
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (96, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1790
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (366, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5968
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (24, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1628461
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2056
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (538, 31)
#
# The shape of  is (17, 31)
# #assay_desc:
# count                                                    17
# unique                                                    5
# top       Agonist activity at dopamine D1 receptor (unkn...
# freq                                                      6
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                17
# unique                               13
# top       Oc1cc2c(cc1O)C(c1ccccc1)CNCC2
# freq                                  5
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293293
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3228
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (157, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Agonist activity at human mGlu8 receptor expre...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       N[C@]1(C(=O)O)[C@H]2[C@@H](C[C@@H]1F)[C@@H]2C(...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL218
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (3668, 31)
#
# The shape of  is (375, 31)
# #assay_desc:
# count                                                   375
# unique                                                   36
# top       Agonist activity at human CB1 receptor express...
# freq                                                     40
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   375
# unique                                                  345
# top       CCCCCCC(C)(C)c1ccc([C@@H]2C[C@H](O)CC[C@H]2CCC...
# freq                                                     15
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL264
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (484, 31)
#
# The shape of  is (127, 31)
# #assay_desc:
# count                                                   127
# unique                                                   19
# top       Agonist activity at human histamine H3 recepto...
# freq                                                     17
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count               127
# unique              102
# top       NCCc1c[nH]cn1
# freq                  9
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1854
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (45, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3399910
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (583, 31)
#
# The shape of  is (78, 31)
# #assay_desc:
# count                                                    78
# unique                                                    4
# top       Modulator activity at G-protein-coupled recept...
# freq                                                     40
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    78
# unique                                                   77
# top       Cc1ccc(-c2ccc([C@H](CO)NC(=O)[C@H]3C[C@@H]3c3c...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4296246
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5201
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (120, 31)
#
# The shape of  is (25, 31)
# #assay_desc:
# count                                                    25
# unique                                                    2
# top       Agonist activity at human FFA3 receptor stably...
# freq                                                     22
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count           25
# unique          24
# top       CCC(=O)O
# freq             2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2731
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4616
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1079, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Agonist activity at human recombinant GHSR1a e...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       Cc1ccccc1-c1nc2ccc(Oc3ccc(F)cc3)cc2c(=O)n1CC1C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2384898
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (58, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075144
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (159, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL226
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (556, 31)
#
# The shape of  is (61, 31)
# #assay_desc:
# count                                                    61
# unique                                                    8
# top       Agonist activity at human adenosine A1 recepto...
# freq                                                     28
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    61
# unique                                                   57
# top       COc1ccc(Nc2ncnc3c2ncn3[C@@H]2O[C@H](CO)[C@@H](...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714046
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075166
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4427
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (185, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL298
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (136, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3710
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (229, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2150840
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4691
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (310, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4441
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (56, 31)
#
# The shape of  is (15, 31)
# #assay_desc:
# count                                                    15
# unique                                                    1
# top       Agonist activity at CXCR3 expressed in HEK293 ...
# freq                                                     15
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    15
# unique                                                   15
# top       CC1(C)[C@@H]2CC=C(C[N+](C)(C)Cc3ccc(-c4ccccc4I...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1889
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (434, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5137
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1124, 31)
#
# The shape of  is (169, 31)
# #assay_desc:
# count                                                   169
# unique                                                   16
# top       Agonist activity at human mGluR2 expressed in ...
# freq                                                     28
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                         169
# unique                        161
# top       N[C@@H](CCC(=O)O)C(=O)O
# freq                            3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075162
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (97, 31)
#
# The shape of  is (6, 31)
# #assay_desc:
# count                                                     6
# unique                                                    1
# top       Agonist activity at human GPR17 expressed in h...
# freq                                                      6
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     6
# unique                                                    6
# top       O=c1ccn([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-]...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523454
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (23, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3798
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (14, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5409
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (961, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3250
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (127, 31)
#
# The shape of  is (13, 31)
# #assay_desc:
# count                                                    13
# unique                                                    2
# top       Agonistic activity against lysophosphatidic ac...
# freq                                                      9
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             13
# unique                                            13
# top       CCCCCCCC/C=C\CCCCCCCC(=O)NCCC(=S)P(=O)(O)O
# freq                                               1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2035
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (311, 31)
#
# The shape of  is (24, 31)
# #assay_desc:
# count                                                    24
# unique                                                    1
# top       Agonist activity at human muscarinic M5 recept...
# freq                                                     24
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    24
# unique                                                   24
# top       C/C(=N\c1ccc2c(c1)[C@@H](NC(=O)c1ccc(Br)cc1)[C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3176
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL344
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (83, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5413
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (228, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5678
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4761
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (238, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4029
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5892
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2274
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (386, 31)
#
# The shape of  is (228, 31)
# #assay_desc:
# count                                                   228
# unique                                                   30
# top       Agonist activity at recombinant human S1PR5 ex...
# freq                                                     61
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                         228
# unique                                        207
# top       CCCCCCCCc1ccc(CCC(N)(CO)COP(=O)(O)O)cc1
# freq                                            6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714079
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (311, 31)
#
# The shape of  is (34, 31)
# #assay_desc:
# count                                                    34
# unique                                                   13
# top       Agonist activity at N-terminal FLAG-tagged/C-t...
# freq                                                     12
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                      34
# unique                                     21
# top       c1ccc2c(Cc3c[nH]c4ccccc34)c[nH]c2c1
# freq                                        5
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1946
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (227, 31)
#
# The shape of  is (150, 31)
# #assay_desc:
# count                                                   150
# unique                                                   10
# top       Agonist activity at human MT2 receptor express...
# freq                                                     33
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                             150
# unique                            137
# top       COc1ccc2cccc(CCNC(C)=O)c2c1
# freq                                8
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2955
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (188, 31)
#
# The shape of  is (122, 31)
# #assay_desc:
# count                                                   122
# unique                                                   16
# top       Agonist activity at recombinant human S1PR2 ex...
# freq                                                     50
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                 122
# unique                                                116
# top       CCCCCCCCCCCCC/C=C/[C@@H](O)[C@@H](N)COP(=O)(O)O
# freq                                                    6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1867
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (171, 31)
#
# The shape of  is (24, 31)
# #assay_desc:
# count                                                    24
# unique                                                    4
# top       Agonist activity at human recombinant alpha2A ...
# freq                                                     11
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                           24
# unique                          18
# top       NC[C@H](O)c1ccc(O)c(O)c1
# freq                             3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL288
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (7, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069161
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (220, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4015
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2321628
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3632455
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (487, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3309110
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (3, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL245
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (233, 31)
#
# The shape of  is (23, 31)
# #assay_desc:
# count                                                    23
# unique                                                    1
# top       Agonist activity at human muscarinic M3 recept...
# freq                                                     23
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    23
# unique                                                   23
# top       C/C(=N\c1ccc2c(c1)[C@@H](NC(=O)c1ccc(Br)cc1)[C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4867
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (51, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1810
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (18, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1983
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (196, 31)
#
# The shape of  is (174, 31)
# #assay_desc:
# count                                                   174
# unique                                                   12
# top       Agonist-induced [35S]- GTPgammaS binding in CH...
# freq                                                     45
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                       174
# unique                                      128
# ...
# Target: CHEMBL4080
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (376, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5339
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (701, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5994
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL225
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1456, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1945
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (238, 31)
#
# The shape of  is (165, 31)
# #assay_desc:
# count                                                   165
# unique                                                   12
# top       Agonist activity at human MT1 receptor express...
# freq                                                     33
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                             165
# unique                            153
# top       COc1ccc2cccc(CCNC(C)=O)c2c1
# freq                                7
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2331058
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (22, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1995
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (325, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4518
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (84, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1941
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (247, 31)
#
# The shape of  is (116, 31)
# #assay_desc:
# count                                                   116
# unique                                                   12
# top       Agonist activity at human H2R-Gsalphas express...
# freq                                                     19
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count               116
# unique              103
# top       NCCc1c[nH]cn1
# freq                  8
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1925
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293316
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (131, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523248
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (14, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4532
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4608
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (438, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2414
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3559686
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1832
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (239, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4596
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (45, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5071
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (17, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2024
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (89, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4295740
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5844
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (105, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL234
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (744, 31)
#
# The shape of  is (158, 31)
# #assay_desc:
# count                                                   158
# unique                                                   22
# top       Agonist activity at human Dopamine D3 receptor...
# freq                                                     40
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                   158
# unique                  101
# top       NCCc1ccc(O)c(O)c1
# freq                     15
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL219
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (398, 31)
#
# The shape of  is (18, 31)
# #assay_desc:
# count                                                    18
# unique                                                    6
# top       Activity at human D4.4 receptor expressed in C...
# freq                                                     11
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                     18
# unique                                    16
# top       CCCN1CCC[C@@H]2Cc3[nH]ncc3C[C@H]21
# freq                                       3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1805
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (27, 31)
#
# The shape of  is (24, 31)
# #assay_desc:
# count                                                    24
# unique                                                    6
# top       In vitro effective concentration for stimulati...
# freq                                                     10
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                              24
# unique                                             24
# top       CN1CCC(c2coc3ccc(NC(=O)c4ccc(F)cc4)nc23)CC1
# freq                                                1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4235
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (46, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1798
#
# Effect: agon
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (8, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================

# %% [markdown]
# ### Antagonism: IC50, Ki, Ke, Kb

# %%
# GTPgammaS binding assay
p_antag_G_GTP = r"(?i)gtp"
p_antag_G_GTP_ex = r"(?i)arrestin|camp|calcium|IP1|IP3|allosteric"

or_type_dfs, or_antag_G_GTP_dfs, or_antag_G_GTP_plus_dfs, or_antag_G_GTP_exclude_dfs, or_antag_G_GTP_final_dfs, or_antag_G_GTP_len_dfs = categorize_ORs(targets='ORs', effect='antag', assay='G_GTP', std_types=['IC50', 'Ki'], 
                                                                                       pattern=p_antag_G_GTP, pattern_ex=p_antag_G_GTP_ex)
# Out:
# target_chembl_id: CHEMBL233
#
# Target: CHEMBL233
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1366, 31)
#
# The shape of  is (440, 31)
# #assay_desc:
# count                                                   440
# unique                                                   43
# top       Antagonist activity assessed as inhibition of ...
# freq                                                     56
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   440
# unique                                                  396
# top       C[C@@H](NC(=O)[C@@H](N)Cc1ccc(O)cc1)C(=O)NCC(=...
# freq                                                      7
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (63, 31)
#
# The shape of final_df is (377, 31)
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (5682, 31)
#
# The shape of  is (66, 31)
# #assay_desc:
# count                                                    66
# unique                                                   11
# top       Antagonist activity at human mu opioid recepto...
# freq                                                     27
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    66
# unique                                                   64
# top       O=C1CC[C@@]2(O)[C@H]3Cc4ccc(O)c5c4[C@@]2(CCN3C...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (3, 31)
#
# The shape of final_df is (63, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL237
#
# Target: CHEMBL237
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1049, 31)
#
# The shape of  is (244, 31)
# #assay_desc:
# count                                                   244
# unique                                                   32
# top       Antagonist activity at human kappa opioid rece...
# freq                                                     40
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   244
# unique                                                  228
# top       Oc1ccc2c3c1O[C@H]1c4[nH]c5c(c4C[C@@]4(O)[C@@H]...
# freq                                                      5
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (32, 31)
#
# The shape of final_df is (212, 31)
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (4857, 31)
#
# The shape of  is (76, 31)
# #assay_desc:
# count                                                    76
# unique                                                   13
# top       Antagonist activity at human kappa opioid rece...
# freq                                                     27
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    76
# unique                                                   72
# top       O=C1CC[C@@]2(O)[C@H]3Cc4ccc(O)c5c4[C@@]2(CCN3C...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (19, 31)
#
# The shape of final_df is (57, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL236
#
# Target: CHEMBL236
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1316, 31)
#
# The shape of  is (224, 31)
# #assay_desc:
# count                                                   224
# unique                                                   29
# top       Antagonist activity at human delta opioid rece...
# freq                                                     47
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   224
# unique                                                  214
# top       C=CCN1CC[C@]23c4c5ccc(O)c4O[C@H]2C(=O)CC[C@@]3...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (1, 31)
#
# The shape of exclude_df is (28, 31)
#
# The shape of final_df is (197, 31)
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (5152, 31)
#
# The shape of  is (91, 31)
# #assay_desc:
# count                                                    91
# unique                                                   20
# top       Antagonist activity at human delta opioid rece...
# freq                                                     27
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    91
# unique                                                   74
# top       O=C1CC[C@@]2(O)[C@H]3Cc4ccc(O)c5c4[C@@]2(CCN3C...
# freq                                                      7
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (91, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL2014
#
# Target: CHEMBL2014
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (747, 31)
#
# The shape of  is (159, 31)
# #assay_desc:
# count                                                   159
# unique                                                   16
# top       Antagonist activity at human recombinant ORL1 ...
# freq                                                     32
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   159
# unique                                                  150
# top       Cc1ncc(-c2c(C)c(CN[C@H]3CC[C@@H](F)C3)nn2-c2nc...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (2, 31)
#
# The shape of final_df is (157, 31)
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (1381, 31)
#
# The shape of  is (6, 31)
# #assay_desc:
# count                                                     6
# unique                                                    1
# top       Antagonist activity at NOP expressed in HEK293...
# freq                                                      6
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     6
# unique                                                    6
# top       O=C1CC[C@@]2(O)[C@H]3Cc4ccc(O)c5c4[C@@]2(CCN3C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (6, 31)
#
# ##########################
# ================================================================

# %%
# cat_datasets: GPCRs
gpcr_type_dfs, gpcr_antag_G_GTP_dfs, gpcr_antag_G_GTP_len_dfs = categorize_GPCRs(targets='GPCRs', effect='antag', assay='G_GTP', std_types=['IC50', 'Ki'], 
                                                                                       pattern=p_antag_G_GTP, pattern_ex=p_antag_G_GTP_ex)
# Out:
# Target: CHEMBL2327
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (290, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (873, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3713916
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5144
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (18, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL223
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (188, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (1437, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2049
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (137, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (821, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075178
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (55, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (4, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4714
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (82, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (5, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4308
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (495, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (824, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1905
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL259
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1065, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (2430, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4877
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (47, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Antagonist activity at human neuropeptide Y4 r...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       COc1ccc([C@H](N[C@@H]2CC[C@@H](C(=O)N3CCC(C(=O...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (351, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523360
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1833
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (307, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (1793, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1850
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (786, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3426
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (562, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3724
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (163, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (13, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2203
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (33, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (104, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3636
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (77, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (107, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1963
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (58, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5852
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (123, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (13, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (766, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (530, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1790
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (396, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (554, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5968
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (10, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1628461
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (89, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                                                     4
# unique                                                    1
# top       Antagonist activity at human OXE receptor fuse...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                      4
# unique                                     4
# top       CC/C=C\C/C=C\C/C=C\CCCCCCCCCC(=O)O
# freq                                       1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2056
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (208, 31)
#
# The shape of  is (20, 31)
# #assay_desc:
# count                                                    20
# unique                                                    5
# top       Antagonist activity at dopamine D1 receptor as...
# freq                                                      6
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                    20
# unique                                   17
# top       CN1CCc2cc(Cl)c(O)cc2C(c2ccccc2)C1
# freq                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (1836, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293293
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (217, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3228
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (56, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Antagonist activity at human mGlu8 receptor ex...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       N[C@]1(C(=O)O)[C@H]2[C@@H](C[C@@H]1F)[C@@H]2C(...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (20, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL218
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2108, 31)
#
# The shape of  is (247, 31)
# #assay_desc:
# count                                                   247
# unique                                                   15
# top       Antagonist activity at human recombinant CB1 r...
# freq                                                     54
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   247
# unique                                                  184
# top       Cc1c(C(=O)NN2CCCCC2)nn(-c2ccc(Cl)cc2Cl)c1-c1cc...
# freq                                                      9
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (5414, 31)
#
# The shape of  is (108, 31)
# #assay_desc:
# count                                                   108
# unique                                                   10
# top       Functional activity at human CB1 receptor tran...
# freq                                                     21
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   108
# unique                                                   99
# top       Cc1c(C(=O)NN2CCCCC2)nn(-c2ccc(Cl)cc2Cl)c1-c1cc...
# freq                                                      8
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL264
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (797, 31)
#
# The shape of  is (215, 31)
# #assay_desc:
# count                                                   215
# unique                                                   11
# top       Antagonist activity at human histamine H3 rece...
# freq                                                     43
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                            215
# unique                                           207
# top       NC(=O)c1ccc(C2CC2C(=O)N2CCN(C3CCC3)CC2)cc1
# freq                                               3
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (5019, 31)
#
# The shape of  is (314, 31)
# #assay_desc:
# count                                                   314
# unique                                                   16
# top       Antagonist activity at human histamine H3 rece...
# freq                                                     52
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                    314
# unique                                   303
# top       O=C(c1ccc(OCCCc2c[nH]cn2)cc1)C1CC1
# freq                                       3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1854
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (50, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3399910
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (5, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4296246
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5201
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2731
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (27, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4616
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1395, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (752, 31)
#
# The shape of  is (25, 31)
# #assay_desc:
# count                                                    25
# unique                                                    2
# top       Antagonist activity at human GHS-R1a expressed...
# freq                                                     17
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    25
# unique                                                   24
# top       COc1ccc(OCC(=O)N2CCC3(CC2)CN(Cc2ccc4c(c2)CCC(C...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2384898
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (142, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075144
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (55, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (4, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL226
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (368, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Displacement of [3H]DPCPX from human adenosine...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       Nc1c(S(=O)(=O)[O-])cc(Nc2ccc(Nc3ncccn3)c(S(=O)...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (6092, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Displacement [3H]DPCPX from of human adenosine...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       COc1cc([C@H]2OC[C@](O)(Cc3ccc(O[C@@H]4O[C@H](C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714046
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075166
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (24, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4427
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (646, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (343, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL298
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1552, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (632, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3710
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (791, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (580, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2150840
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (8, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4691
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1014, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4441
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1996, 31)
#
# The shape of  is (61, 31)
# #assay_desc:
# count                                                    61
# unique                                                    2
# top       Antagonist activity at human CXCR3 expressed i...
# freq                                                     60
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    61
# unique                                                   49
# top       O=C1CCC(c2ccccc2)(C2CCN(Cc3ccc(Br)cc3)CC2)C(=O)N1
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (321, 31)
#
# The shape of  is (101, 31)
# #assay_desc:
# count                                                   101
# unique                                                    4
# top       Antagonist activity at human CXCR3 expressed i...
# freq                                                     38
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                               101
# unique                                               96
# top       O=C(Nc1ccc2ccccc2c1)NC1CCN(C/C2=C/CCCCCC2)CC1
# freq                                                  2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1889
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (538, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (948, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5137
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (816, 31)
#
# The shape of  is (259, 31)
# #assay_desc:
# count                                                   259
# unique                                                    7
# top       [35S]GTPgammaS Binding Assay: The frozen cell ...
# freq                                                    245
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   259
# unique                                                  258
# top       Cc1cc(-c2nc(-c3ccc(OC(F)F)c(F)c3)n3c2CCO[C@H](...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (234, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                                     2
# unique                                                    1
# top       Antagonistic activity against stimulation of G...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     2
# unique                                                    2
# top       NC(C(=O)O)[C@H]1[C@@H](CC2c3ccccc3Oc3ccccc32)[...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075162
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (48, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                                                     4
# unique                                                    1
# top       Antagonist activity at human GPR17 expressed i...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     4
# unique                                                    4
# top       N.N.Nc1nc(Cl)nc2c1ncn2[C@H]1C[C@H](OP(=O)(O)O)...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (8, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523454
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3798
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (801, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (546, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# ...
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4532
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (72, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4608
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (948, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (500, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2414
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (650, 31)
#
# The shape of  is (150, 31)
# #assay_desc:
# count                                                   150
# unique                                                    7
# top       Antagonist activity at human recombinant CCR4 ...
# freq                                                     71
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   150
# unique                                                  136
# top       COc1ccc(COc2nc(Br)cnc2NS(=O)(=O)c2ccc(C)cc2)cc...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (102, 31)
#
# The shape of  is (19, 31)
# #assay_desc:
# count                                                    19
# unique                                                    1
# top       Binding affinity to CCR4 by 35S-gamma-GTP memb...
# freq                                                     19
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    19
# unique                                                   19
# top       O=S(=O)(Nc1cc(Cl)c(Cl)cc1Cn1ccnn1)c1ccc(Cl)c(C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3559686
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1832
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (169, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (15, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4596
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Antagonist activity at CCR8 receptor (unknown ...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       COc1cccc2c1c(NS(=O)(=O)c1ccc(Cl)s1)nn2Cc1cccc(...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (76, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5071
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2960, 31)
#
# The shape of  is (304, 31)
# #assay_desc:
# count                                                   304
# unique                                                   17
# top       Antagonist activity at CRTh2 (unknown origin) ...
# freq                                                     95
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   304
# unique                                                  271
# top       Cc1c(Cc2ccccc2S(=O)(=O)c2ccccc2)c2c(n1CC(=O)O)...
# freq                                                      9
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (1164, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2024
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (69, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4295740
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (15, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5844
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL234
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (383, 31)
#
# The shape of  is (7, 31)
# #assay_desc:
# count                                                     7
# unique                                                    4
# top       Antagonist activity against human D3R expresse...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                7
# unique                                               7
# top       Cc1cccc(N2CCN(CCCCNC(=O)c3cc4ccccc4o3)CC2)c1
# freq                                                 1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (6650, 31)
#
# The shape of  is (553, 31)
# #assay_desc:
# count                                                   553
# unique                                                   16
# top       Antagonist activity at human Dopamine D3 recep...
# freq                                                    105
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   553
# unique                                                  425
# top       N#Cc1ccc2c(c1)CCN(CC[C@H]1CC[C@H](NC(=O)c3ccnc...
# freq                                                      8
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL219
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (407, 31)
#
# The shape of  is (3, 31)
# #assay_desc:
# count                                                     3
# unique                                                    1
# top       Inhibition of 333 nM dopamine stimulated GTP b...
# freq                                                      3
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     3
# unique                                                    3
# top       O=C(O)/C=C/C(=O)O.c1cnc(N2CCN(CCCCCNC3=Nc4cccc...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (3763, 31)
#
# The shape of  is (6, 31)
# #assay_desc:
# count                                                     6
# unique                                                    4
# top       Antagonism of dopamine-stimulated [35S]GTP-gam...
# freq                                                      3
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  6
# unique                                                 6
# top       O=C1C(N2CCN(Cc3ccc(Cl)cc3)CC2)CCc2cccc3c2N1CC3
# freq                                                   1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1805
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (17, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (151, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4235
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (4732, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (308, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1798
#
# Effect: antag
#
# Assay: G_GTP
#
# Pattern: (?i)gtp
#
# Pattern_ex: (?i)arrestin|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (268, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: Ki
#
# The shape of type_df is (4, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================

# %% [markdown]
# ## G_cAMP

# %% [markdown]
# ### Agonism: IC50, EC50

# %%
# cAMP accumulation assay
p_ago_G_cAMP = r"(?i)camp"
p_ago_G_cAMP_ex = r"(?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric"

or_type_dfs, or_agon_G_cAMP_dfs, or_agon_G_cAMP_plus_dfs, or_agon_G_cAMP_exclude_dfs,or_agon_G_cAMP_final_dfs, or_agon_G_cAMP_len_dfs = categorize_ORs(targets='ORs', effect='agon', assay='G_cAMP', std_types=['IC50', 'EC50'], 
                                                                                       pattern=p_ago_G_cAMP, pattern_ex=p_ago_G_cAMP_ex)
# Out:
# target_chembl_id: CHEMBL233
#
# Target: CHEMBL233
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1366, 31)
#
# The shape of  is (79, 31)
# #assay_desc:
# count                                                    79
# unique                                                   15
# top       Agonist activity at human MOR expressed in HEK...
# freq                                                     16
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    79
# unique                                                   56
# top       C[C@@H](NC(=O)[C@@H](N)Cc1ccc(O)cc1)C(=O)NCC(=...
# freq                                                      7
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (6, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (85, 31)
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (2296, 31)
#
# The shape of  is (587, 31)
# #assay_desc:
# count                                                   587
# unique                                                   52
# top       Agonist activity at human MOR expressed in CHO...
# freq                                                     84
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   587
# unique                                                  476
# top       C[C@@H](NC(=O)[C@@H](N)Cc1ccc(O)cc1)C(=O)NCC(=...
# freq                                                     12
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (3, 31)
#
# The shape of exclude_df is (3, 31)
#
# The shape of final_df is (587, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL237
#
# Target: CHEMBL237
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1049, 31)
#
# The shape of  is (36, 31)
# #assay_desc:
# count                                                    36
# unique                                                    4
# top       Agonist activity at human KOR expressed in HEK...
# freq                                                     16
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    36
# unique                                                   27
# top       CN(C(=O)Cc1ccc(Cl)c(Cl)c1)[C@@H]1CCCC[C@H]1N1C...
# freq                                                      5
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (36, 31)
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (2062, 31)
#
# The shape of  is (345, 31)
# #assay_desc:
# count                                                   345
# unique                                                   31
# top       Agonist activity at human KOR expressed in CHO...
# freq                                                     48
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   345
# unique                                                  294
# top       COC(=O)[C@@H]1C[C@H](OC(C)=O)C(=O)[C@H]2[C@@]1...
# freq                                                      9
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (1, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (346, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL236
#
# Target: CHEMBL236
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1316, 31)
#
# The shape of  is (33, 31)
# #assay_desc:
# count                                                    33
# unique                                                    7
# top       Agonist activity at human DOR expressed in HEK...
# freq                                                     16
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    33
# unique                                                   31
# top       CC1(C)SSC(C)(C)[C@@H](NC(=O)[C@@H](N)Cc2ccc(O)...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (33, 31)
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (1324, 31)
#
# The shape of  is (202, 31)
# #assay_desc:
# count                                                   202
# unique                                                   22
# top       Agonist activity at delta opioid receptor expr...
# freq                                                     23
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   202
# unique                                                  157
# top       CN1CC[C@]23c4c5ccc(O)c4O[C@H]2[C@@H](O)C=C[C@H...
# freq                                                      5
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (202, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL2014
#
# Target: CHEMBL2014
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (747, 31)
#
# The shape of  is (80, 31)
# #assay_desc:
# count                                                    80
# unique                                                    2
# top       Agonist activity at human NOP receptor express...
# freq                                                     63
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    80
# unique                                                   70
# top       COc1ccc(C)c(OC(CCN2CCC(n3c(=O)[nH]c4ccccc43)CC...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (80, 31)
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (524, 31)
#
# The shape of  is (37, 31)
# #assay_desc:
# count                                                    37
# unique                                                    6
# top       Inhibition of forskolin stimulated cAMP accumu...
# freq                                                     15
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    37
# unique                                                   36
# top       CC(C)C[C@H](NC(=O)[C@H](CCCCN)NC(=O)[C@H](CCCN...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (37, 31)
#
# ##########################
# ================================================================

# %%
# cat_datasets: GPCRs
gpcr_type_dfs, gpcr_agon_G_cAMP_dfs, gpcr_agon_G_cAMP_len_dfs = categorize_GPCRs(targets='GPCRs', effect='agon', assay='G_cAMP', std_types=['IC50', 'EC50'], 
                                                                                       pattern=p_ago_G_cAMP, pattern_ex=p_ago_G_cAMP_ex)
# Out:
# Target: CHEMBL2327
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (290, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (5, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3713916
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Inhibition of OGR1 (unknown origin) expressed ...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       CCc1nn2c(C)cc(C)nc2c1Cc1ccc(-c2nnc(C3CCNCC3)o2...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5144
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (18, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (38, 31)
#
# The shape of  is (37, 31)
# #assay_desc:
# count                                                    37
# unique                                                    3
# top       Agonist activity at human VIPR1 expressed in C...
# freq                                                     33
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    37
# unique                                                   37
# top       CC[C@H](C)[C@H](NC(=O)[C@H](CO)NC(=O)[C@H](CCC...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL223
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (188, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (247, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2049
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (137, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (492, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075178
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (55, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (125, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4714
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (82, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (356, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4308
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (495, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1905
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL259
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1065, 31)
#
# The shape of  is (6, 31)
# #assay_desc:
# count                                                     6
# unique                                                    3
# top       Activity at MC4R assessed as inhibition of alp...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     6
# unique                                                    6
# top       CC(C)C[C@H](NC(=O)CN)c1cc(C(F)(F)F)ccc1N1CCN(C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (1564, 31)
#
# The shape of  is (980, 31)
# #assay_desc:
# count                                                   980
# unique                                                   81
# top       Agonist activity at human recombinant MC4 rece...
# freq                                                     60
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   980
# unique                                                  824
# top       CCCC[C@H](NC(C)=O)C(=O)N[C@H]1CC(=O)NCCCC[C@@H...
# freq                                                     20
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4877
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (47, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (379, 31)
#
# The shape of  is (26, 31)
# #assay_desc:
# count                                                    26
# unique                                                    7
# top       Agonist activity at human NPY4 receptor in HEK...
# freq                                                      9
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    26
# unique                                                   21
# top       CCC[C@H](NC(=O)[C@H](CCCN=C(N)N)NC(=O)[C@H](Cc...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523360
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1833
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (307, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (935, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1850
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (35, 31)
#
# The shape of  is (5, 31)
# #assay_desc:
# count                                                     5
# unique                                                    1
# top       Agonist activity at D5R (unknown origin) expre...
# freq                                                      5
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                     5
# unique                    5
# top       NCCc1ccc(O)c(O)c1
# freq                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3426
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3724
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (163, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (108, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2203
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (33, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (164, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3636
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (77, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (10, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1963
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (58, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (40, 31)
#
# The shape of  is (39, 31)
# #assay_desc:
# count                                                    39
# unique                                                    2
# top       Agonist activity at TSHR (unknown origin) tran...
# freq                                                     24
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   39
# unique                                                  39
# top       CSc1nc(-c2cccc(O)c2)c2c(N)c(C(=O)NC(C)(C)C)sc2n1
# freq                                                     1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5852
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (123, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (96, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (766, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1790
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (396, 31)
#
# The shape of  is (33, 31)
# #assay_desc:
# count                                                    33
# unique                                                    6
# top       Evaluated for accumulation of cAMP in transfec...
# freq                                                     15
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    33
# unique                                                   31
# top       Cc1ccc(F)cc1C(=O)Nc1ccc(C(=O)N2CCC3(C=C(C(=O)N...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (366, 31)
#
# The shape of  is (121, 31)
# #assay_desc:
# count                                                   121
# unique                                                    9
# top       Agonist activity at human vasopressin V2 recep...
# freq                                                     46
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   121
# unique                                                  118
# top       Cc1ccn(-c2ccc(C(=O)N3Cc4cccn4Cc4ccccc43)c(Cl)c...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5968
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (10, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (24, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1628461
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (89, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2056
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (208, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (538, 31)
#
# The shape of  is (251, 31)
# #assay_desc:
# count                                                   251
# unique                                                   18
# top       Agonist activity at recombinant human D1 recep...
# freq                                                     88
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                            251
# unique                                           159
# top       Cc1cc(Oc2nccc3occc23)ccc1-c1c(C)ncc2nccn12
# freq                                               7
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293293
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (217, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (5, 31)
# #assay_desc:
# count                                                     5
# unique                                                    2
# top       Agonist activity at human NPBWR1 expressed in ...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     5
# unique                                                    5
# top       CSCC[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC(C)...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3228
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (56, 31)
#
# The shape of  is (3, 31)
# #assay_desc:
# count                                                     3
# unique                                                    2
# top       Tested for agonist activity in non-neuronal ce...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     3
# unique                                                    3
# top       N[C@@H](C[C@H](CCCC(c1ccccc1)c1ccccc1)C(=O)O)C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (157, 31)
#
# The shape of  is (18, 31)
# #assay_desc:
# count                                                    18
# unique                                                    5
# top       Agonist activity at mGlu8 receptor (unknown or...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                              18
# unique                                             14
# top       N[C@@]1(C(=O)O)CO[C@H]2[C@H](C(=O)O)[C@H]21
# freq                                                2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL218
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2108, 31)
#
# The shape of  is (96, 31)
# #assay_desc:
# count                                                    96
# unique                                                   10
# top       Agonist activity at human CB1 receptor express...
# freq                                                     51
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    96
# unique                                                   88
# top       O=C(c1csc(-c2ccncc2)n1)N1CCC(O)(c2ccccc2)[C@@H...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (3668, 31)
#
# The shape of  is (1734, 31)
# #assay_desc:
# count                                                  1734
# unique                                                   51
# top       cAMP Assay: CHO cells expressing human CB1 or ...
# freq                                                    376
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  1734
# unique                                                 1592
# top       CCCCCCC(C)(C)c1ccc([C@@H]2C[C@H](O)CC[C@H]2CCC...
# freq                                                     11
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL264
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (797, 31)
#
# The shape of  is (47, 31)
# #assay_desc:
# count                                                    47
# unique                                                    2
# top       HTRF cAMP Assay: Compounds of the present inve...
# freq                                                     26
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                47
# unique                                               34
# top       C[C@@H]1CCCN1CCc1ccc(-c2ccc(CCCC(=O)O)cc2)cc1
# freq                                                  2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (484, 31)
#
# The shape of  is (134, 31)
# #assay_desc:
# count                                                   134
# unique                                                   10
# top       Agonist activity at human H3R expressed in HEK...
# freq                                                     44
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count               134
# unique              103
# top       NCCc1c[nH]cn1
# freq                  5
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1854
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (50, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (45, 31)
#
# The shape of  is (28, 31)
# #assay_desc:
# count                                                    28
# unique                                                    2
# top       Agonist activity at LHCGR expressed in HEK293 ...
# freq                                                     17
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   28
# unique                                                  28
# top       CSc1nc(-c2cccc(O)c2)c2c(N)c(C(=O)NC(C)(C)C)sc2n1
# freq                                                     1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3399910
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (583, 31)
#
# The shape of  is (505, 31)
# #assay_desc:
# count                                                   505
# unique                                                   12
# top       Agonist activity at GPR88 (unknown origin) exp...
# freq                                                    146
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   505
# unique                                                  338
# top       CCCc1ccc(-c2ccc(N(C[C@@H](N)[C@@H](C)CC)C(=O)[...
# freq                                                      8
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4296246
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5201
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (120, 31)
#
# The shape of  is (61, 31)
# #assay_desc:
# count                                                    61
# unique                                                    3
# top       Agonist activity at human FFA3 receptor stably...
# freq                                                     53
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    61
# unique                                                   61
# top       Cc1cc(OCCCS(C)(=O)=O)cc(C)c1-c1cccc(COc2ccc3c(...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2731
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4616
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1395, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (1079, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2384898
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (142, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (58, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Agonist activity at recombinant full length hu...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                1
# unique                                               1
# top       CCCCC/C=C\C/C=C\C/C=C\C/C=C\CCCC(=O)NCC(=O)O
# freq                                                 1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075144
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (55, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (159, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL226
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (368, 31)
#
# The shape of  is (67, 31)
# #assay_desc:
# count                                                    67
# unique                                                   10
# top       Agonist activity at adenosine A1 receptor asse...
# freq                                                     21
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    67
# unique                                                   66
# top       OC[C@H]1O[C@@H](n2cnc3c(NC4CCCC4)nc(Cl)nc32)[C...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (556, 31)
#
# The shape of  is (134, 31)
# #assay_desc:
# count                                                   134
# unique                                                   16
# top       Agonist activity at human adenosine A1 recepto...
# freq                                                     31
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   134
# unique                                                  121
# top       CCNC(=O)[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O...
# freq                                                      8
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714046
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075166
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4427
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (646, 31)
#
# The shape of  is (144, 31)
# #assay_desc:
# count                                                   144
# unique                                                    9
# top       In vitro inhibition of cAMP formation evoked b...
# freq                                                     47
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   144
# unique                                                  123
# top       CC(O)c1cc(S(C)(=O)=O)cc2c3c(n(Cc4ccc(Cl)cc4)c1...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (185, 31)
#
# The shape of  is (27, 31)
# #assay_desc:
# count                                                    27
# unique                                                    3
# top       Agonist activity at recombinant human DP1 rece...
# freq                                                     23
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    27
# unique                                                   26
# top       CC#CCC(C)[C@H](O)/C=C/[C@@H]1[C@H]2C/C(=C/CCCC...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL298
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1552, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (136, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3710
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (791, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (229, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2150840
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (8, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4691
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1014, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (310, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4441
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1996, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# ...
# top       Agonist activity at human MC5R expressed in HE...
# freq                                                     31
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    31
# unique                                                   31
# top       CC[C@H](C)[C@@H]1NC(=O)[C@@H]2CCCN2C(=O)[C@H](...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (438, 31)
#
# The shape of  is (353, 31)
# #assay_desc:
# count                                                   353
# unique                                                   42
# top       Agonist activity at human MC5 receptor express...
# freq                                                     32
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   353
# unique                                                  312
# top       CCCC[C@H](NC(C)=O)C(=O)N[C@H]1CC(=O)NCCCC[C@@H...
# freq                                                     12
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2414
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (650, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3559686
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1832
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (169, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (239, 31)
#
# The shape of  is (239, 31)
# #assay_desc:
# count                                                   239
# unique                                                    2
# top       Agonist activity at human calcitonin receptor ...
# freq                                                    143
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   239
# unique                                                  143
# top       CC(C)C[C@H](NC(=O)[C@H](C)NC(=O)[C@H](C)NC(=O)...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4596
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (45, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5071
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2960, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                         4
# unique                        3
# top       cAMP Functional Assay
# freq                          2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     4
# unique                                                    2
# top       CN([C@@H]1CCc2c(CC(=O)O)c3ccccc3n2C1)S(=O)(=O)...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (17, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Agonist activity at human CRTh2 expressed in H...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       CCN(c1nc(C(=O)O)cs1)[C@H]1c2ccccc2N(C(=O)OCc2c...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2024
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (69, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       In vitro inhibition of maximum response evoked...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       CC(=O)N1c2ccc(NC(=O)c3ccc(-c4ccccc4)cc3)cc2C(C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (89, 31)
#
# The shape of  is (9, 31)
# #assay_desc:
# count                                                     9
# unique                                                    3
# top       Agonistic activity in CHO-hFSHR cell-based cAM...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     9
# unique                                                    8
# top       CCCCCCN1C(=O)[C@H](Cc2ccc(-c3cccc(CN(CCCC)C(=O...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4295740
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (15, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5844
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (105, 31)
#
# The shape of  is (17, 31)
# #assay_desc:
# count                                                    17
# unique                                                    2
# top       Agonist activity at human GLP2 receptor expres...
# freq                                                     15
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    17
# unique                                                   17
# top       CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL234
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (383, 31)
#
# The shape of  is (23, 31)
# #assay_desc:
# count                                                    23
# unique                                                    1
# top       Partial agonist activity at human D3 receptor ...
# freq                                                     23
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    23
# unique                                                   23
# top       CN(CC(=O)NCc1ccccc1)C(=O)CCCN1CCN(c2cccc(Cl)c2...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (744, 31)
#
# The shape of  is (169, 31)
# #assay_desc:
# count                                                   169
# unique                                                   10
# top       Agonist activity at human recombinant dopamine...
# freq                                                     47
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   169
# unique                                                  122
# top       NC(=O)c1cccc(-c2ccc(OC(=O)NCCCCN3CCN(c4cccc(Cl...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL219
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (407, 31)
#
# The shape of  is (23, 31)
# #assay_desc:
# count                                                    23
# unique                                                    1
# top       Partial agonist activity at human D4 receptor ...
# freq                                                     23
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    23
# unique                                                   23
# top       CN(CC(=O)NCc1ccccc1)C(=O)CCCN1CCN(c2cccc(Cl)c2...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (398, 31)
#
# The shape of  is (47, 31)
# #assay_desc:
# count                                                    47
# unique                                                    6
# top       Agonist activity at human D4 receptor expresse...
# freq                                                     19
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                     47
# unique                                    43
# top       Cc1ccc2nc(CNCCCOc3ccccc3)cc(O)c2c1
# freq                                       3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1805
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (17, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (27, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4235
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (4732, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (46, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1798
#
# Effect: agon
#
# Assay: G_cAMP
#
# Pattern: (?i)camp
#
# Pattern_ex: (?i)arrestin|gtp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (268, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# Standard type: EC50
#
# The shape of type_df is (8, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================

# %% [markdown]
# ### Antagonism

# %% [markdown]
# neither IC50 data not EC50 data within G_cAMP assay is related to antagonism

# %% [markdown]
# ## G_Ca

# %% [markdown]
# ### Agonism: EC50

# %%
# IP3/IP1 and Ca2+ assay
p_agon_G_Ca = r"(?i)calcium|ca2+|IP1|IP3"
p_agon_G_Ca_ex = r"(?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric"

# cat_datasets: ORs
or_type_dfs, or_agon_G_Ca_dfs, or_agon_G_Ca_plus_dfs, or_agon_G_Ca_exclude_dfs, or_agon_G_Ca_final_dfs, or_agon_G_Ca_len_dfs = categorize_ORs(targets='ORs', effect='agon', assay='G_Ca', std_types=['EC50'], 
                                                                                 pattern=p_agon_G_Ca, pattern_ex=p_agon_G_Ca_ex)
# Out:
# target_chembl_id: CHEMBL233
#
# Target: CHEMBL233
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2296, 31)
#
# The shape of  is (151, 31)
# #assay_desc:
# count                                                   151
# unique                                                   14
# top       Agonist activity at human MOR expressed in CHO...
# freq                                                     35
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   151
# unique                                                  140
# top       NC(=O)[C@H](Cc1ccccc1)NC(=O)[C@H](Cc1ccccc1)NC...
# freq                                                      5
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (25, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (176, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL237
#
# Target: CHEMBL237
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2062, 31)
#
# The shape of  is (86, 31)
# #assay_desc:
# count                                                    86
# unique                                                   11
# top       Agonist activity at human kappa opioid recepto...
# freq                                                     43
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    86
# unique                                                   77
# top       COC(=O)[C@@H]1C[C@H](OC(C)=O)C(=O)[C@H]2[C@@]1...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (86, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL236
#
# Target: CHEMBL236
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1324, 31)
#
# The shape of  is (45, 31)
# #assay_desc:
# count                                                    45
# unique                                                    6
# top       Agonist activity at human delta opioid recepto...
# freq                                                     16
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    45
# unique                                                   42
# top       CC1(C)SSC(C)(C)[C@@H](NC(=O)[C@@H](N)Cc2ccc(O)...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (45, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL2014
#
# Target: CHEMBL2014
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (524, 31)
#
# The shape of  is (40, 31)
# #assay_desc:
# count                                                    40
# unique                                                    2
# top       Agonist activity at human NOP receptor express...
# freq                                                     34
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    40
# unique                                                   40
# top       O=C(O)C(=O)O.O=C1NCN(c2ccccc2)C12CCN(CC1COc3cc...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (26, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (66, 31)
#
# ##########################
# ================================================================

# %%
# cat_datasets: GPCRs
gpcr_type_dfs, gpcr_agon_G_Ca_dfs, gpcr_agon_G_Ca_len_dfs = categorize_GPCRs(targets='GPCRs', effect='agon', assay='G_Ca', std_types=['EC50'], 
                                                                                 pattern=p_agon_G_Ca, pattern_ex=p_agon_G_Ca_ex)
# Out:
# Target: CHEMBL2327
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (5, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3713916
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Affinity Phenotypic Cellular interaction (FLIP...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                      1
# unique                                     1
# top       Nc1nc(NCc2ccccc2)nc(-c2ccccc2CO)n1
# freq                                       1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5144
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (38, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL223
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (247, 31)
#
# The shape of  is (142, 31)
# #assay_desc:
# count                                                   142
# unique                                                    5
# top       Agonist activity at human cloned adrenergic Al...
# freq                                                     57
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                        142
# unique                       132
# top       c1ccc(C2Cc3nccn3C2)cc1
# freq                           4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2049
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (492, 31)
#
# The shape of  is (181, 31)
# #assay_desc:
# count                                                   181
# unique                                                   18
# top       Agonist activity at human OTR expressed in CHO...
# freq                                                     68
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   181
# unique                                                  156
# top       CC[C@H](C)[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=...
# freq                                                     10
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075178
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (125, 31)
#
# The shape of  is (125, 31)
# #assay_desc:
# count                                                   125
# unique                                                    9
# top       Agonist activity at human NMUR1 expressed in H...
# freq                                                     38
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   125
# unique                                                  118
# top       CC(C)C[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C@@H]...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4714
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (356, 31)
#
# The shape of  is (91, 31)
# #assay_desc:
# count                                                    91
# unique                                                   10
# top       Agonist activity at human P2Y6R expressed in 1...
# freq                                                     23
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    91
# unique                                                   75
# top       O=c1ccn([C@@H]2O[C@H](COP(=O)(O)OP(=O)(O)OP(=O...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4308
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1905
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL259
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1564, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4877
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (379, 31)
#
# The shape of  is (75, 31)
# #assay_desc:
# count                                                    75
# unique                                                    3
# top       Agonist activity at human Y4 receptor expresse...
# freq                                                     43
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    75
# unique                                                   54
# top       CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523360
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Agonist activity at human TAS2R55 expressed in...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                             1
# unique                            1
# top       CC(C)NCC(O)c1ccc(O)c(O)c1
# freq                              1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1833
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (935, 31)
#
# The shape of  is (684, 31)
# #assay_desc:
# count                                                   684
# unique                                                   36
# top       Agonist activity at human 5-HT2B receptor expr...
# freq                                                     71
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                        684
# unique                       532
# top       NCCc1c[nH]c2ccc(O)cc12
# freq                          15
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1850
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (35, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3426
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3724
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (108, 31)
#
# The shape of  is (48, 31)
# #assay_desc:
# count                                                    48
# unique                                                    7
# top       Inhibition of LPA-induced calcium transients i...
# freq                                                     16
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                       48
# unique                      48
# top       CCCCCCCCCCOP(=O)(O)O
# freq                         1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2203
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (164, 31)
#
# The shape of  is (34, 31)
# #assay_desc:
# count                                                    34
# unique                                                    3
# top       Agonist activity at human recombinant motilin ...
# freq                                                     13
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    34
# unique                                                   33
# top       COc1cccc(CCN(Cc2ccccc2-c2ccc(CN3CCNCC3)cc2)C(=...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3636
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (10, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Agonist activity at recombinant neuromedin B r...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       CCCC[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C@H](Cc...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1963
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (40, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5852
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (96, 31)
#
# The shape of  is (96, 31)
# #assay_desc:
# count                                                    96
# unique                                                    3
# top       Agonist activity at DYKDDDDK-flagged human GPR...
# freq                                                     42
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    96
# unique                                                   93
# top       N=C(N)NCCC[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (129, 31)
# #assay_desc:
# count                                                   129
# unique                                                    5
# top       Agonist activity at human recombinant TP recep...
# freq                                                    114
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   129
# unique                                                  127
# top       CC(C)(C)c1ccc(N2C(=O)CC[C@@H]2COCc2ccc(C(=O)O)...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1790
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (366, 31)
#
# The shape of  is (16, 31)
# #assay_desc:
# count                                                    16
# unique                                                    3
# top       Agonist activity at human V2 receptor expresse...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    16
# unique                                                   13
# top       CC[C@H](C)[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5968
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (24, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Agonist activity at LPA4 receptor (unknown ori...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                              1
# unique                                             1
# top       CCCCCCCC/C=C\CCCCCCCC(=O)OCC(O)COP(=O)(O)O
# freq                                               1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1628461
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (3, 31)
# #assay_desc:
# count                                                     3
# unique                                                    2
# top       Agonist activity at 5-oxo-ETE receptor in huma...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                            3
# unique                                           2
# top       CCCCC/C=C\C/C=C\C/C=C\C=C\C(=O)CCCC(=O)O
# freq                                             2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2056
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (538, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293293
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (48, 31)
# #assay_desc:
# count                                                    48
# unique                                                    1
# top       Agonist activity at human NPBWR1 expressed in ...
# freq                                                     48
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    48
# unique                                                   48
# top       CSCC[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC(C)...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3228
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (157, 31)
#
# The shape of  is (51, 31)
# #assay_desc:
# count                                                    51
# unique                                                    3
# top       Agonist activity at mGlu8 (unknown origin) exp...
# freq                                                     49
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    51
# unique                                                   51
# top       N[C@@]1(C(=O)O)C[C@@H](Sc2nnc[nH]2)[C@H]2[C@H]...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL218
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (3668, 31)
#
# The shape of  is (237, 31)
# #assay_desc:
# count                                                   237
# unique                                                   10
# top       Agonist activity at human CB1 receptor express...
# freq                                                     52
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   237
# unique                                                  229
# top       CCCCCCC(C)(C)c1ccc([C@@H]2C[C@H](O)CC[C@H]2CCC...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL264
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (484, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1854
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (45, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3399910
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (583, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4296246
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5201
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (120, 31)
#
# The shape of  is (14, 31)
# #assay_desc:
# count                                                    14
# unique                                                    6
# top       Agonist activity at human GPR41 (unknown origi...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                        14
# unique                                       14
# top       COc1ccc(S(=O)(=O)Nc2c(C)cc(C)cc2C)cc1
# freq                                          1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2731
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4616
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1079, 31)
#
# The shape of  is (497, 31)
# #assay_desc:
# count                                                   497
# unique                                                   15
# top       Agonist activity at human GHSR expressed in HE...
# freq                                                    104
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   497
# unique                                                  375
# top       CN1CCCCC(C(=O)N[C@H]2c3ccccc3C[C@@H]2NC(=O)c2c...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2384898
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (58, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075144
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (159, 31)
#
# The shape of  is (126, 31)
# #assay_desc:
# count                                                   126
# unique                                                    9
# top       Agonist activity at human NMUR2 expressed in H...
# freq                                                     41
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   126
# unique                                                  118
# top       CC(C)C[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C@@H]...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL226
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (556, 31)
#
# The shape of  is (93, 31)
# #assay_desc:
# count                                                    93
# unique                                                    6
# top       Luciferase Assay: The stock cultures are grown...
# freq                                                     50
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  93
# unique                                                 89
# top       Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO)[C@@H](O)[C@H]1O
# freq                                                    2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714046
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075166
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4427
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (185, 31)
#
# The shape of  is (126, 31)
# #assay_desc:
# count                                                   126
# unique                                                    3
# top       Agonist activity at human recombinant DP recep...
# freq                                                    112
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   126
# unique                                                  117
# top       CC(C)(C)c1ccc(N2C(=O)CC[C@@H]2COCc2ccc(C(=O)O)...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL298
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (136, 31)
#
# The shape of  is (72, 31)
# #assay_desc:
# count                                                    72
# unique                                                    7
# top       Agonist activity at human CCK2R expressed in h...
# freq                                                     56
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    72
# unique                                                   70
# top       CSCC[C@H](NC(=O)[C@H](Cc1ccc(OS(=O)(=O)O)cc1)N...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3710
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (229, 31)
#
# The shape of  is (196, 31)
# #assay_desc:
# count                                                   196
# unique                                                    9
# top       Agonist activity at human recombinant EP3A rec...
# freq                                                    114
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   196
# unique                                                  183
# top       CCCCCC(O)/C=C/c1c(Cl)cc(Cl)c(=O)n1CCc1ccc(C(=O...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2150840
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4691
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (310, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4441
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (56, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1889
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (434, 31)
#
# The shape of  is (191, 31)
# #assay_desc:
# count                                                   191
# unique                                                   10
# top       Agonist activity at human V1a receptor express...
# freq                                                     68
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   191
# unique                                                  113
# top       CC[C@H](C)[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5137
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1124, 31)
#
# The shape of  is (118, 31)
# #assay_desc:
# count                                                   118
# unique                                                    9
# top       Agonist activity at human mGlu2 receptor expre...
# freq                                                     34
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   118
# unique                                                   65
# top       COc1c(OCCOCCOCCOCCOCCOCCOCCOCCOc2ccc(C3CCN(c4c...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075162
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (97, 31)
#
# The shape of  is (87, 31)
# #assay_desc:
# count                                                    87
# unique                                                    6
# top       Agonist activity at human GPR17 expressed in h...
# freq                                                     51
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                      87
# unique                                     63
# top       O=C(O)CCc1c(C(=O)O)[nH]c2cc(I)ccc12
# freq                                        3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523454
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (23, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3798
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (14, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5409
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (961, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3250
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (127, 31)
#
# The shape of  is (77, 31)
# #assay_desc:
# count                                                    77
# unique                                                   10
# top       Inhibition of LPA-induced calcium transients i...
# freq                                                     24
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  77
# unique                                                 75
# top       CCCCCCCC/C=C\CCCCCCCC(=O)OC[C@@H](O)COP(=O)(O)O
# freq                                                    2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2035
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (311, 31)
#
# The shape of  is (67, 31)
# #assay_desc:
# count                                                    67
# unique                                                    9
# top       Activation of human muscarinic M5 receptor exp...
# freq                                                     19
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                       67
# unique                      62
# top       CC(=O)OCC[N+](C)(C)C
# freq                         2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3176
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL344
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (83, 31)
#
# The shape of  is (49, 31)
# #assay_desc:
# count                                                    49
# unique                                                    3
# top       Stimulation of IP3-coupled mobilization of cal...
# freq                                                     45
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    49
# unique                                                   45
# top       CCCc1cc(N)c2cc(NC(=O)/C=C/c3ccc(C(F)(F)F)cc3)c...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5413
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (228, 31)
#
# The shape of  is (215, 31)
# #assay_desc:
# count                                                   215
# unique                                                    8
# top       Activity at metastin receptor expressed in HEK...
# freq                                                     41
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   215
# unique                                                  206
# top       CC(C)C[C@H](NC(=O)CNC(=O)[C@H](Cc1ccccc1)NC(=O...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5678
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4761
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (238, 31)
#
# The shape of  is (188, 31)
# #assay_desc:
# count                                                   188
# unique                                                    7
# top       Agonist activity at human C3a receptor in huma...
# freq                                                     81
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   188
# unique                                                   99
# top       CC(C)C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4029
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5892
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2274
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (386, 31)
#
# The shape of  is (49, 31)
# #assay_desc:
# count                                                    49
# unique                                                    8
# top       Agonist activity at human S1P5 receptor expres...
# freq                                                     31
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             49
# unique                                            45
# top       CCCCCCCCc1ccc(CC[C@](N)(CO)COP(=O)(O)O)cc1
# freq                                               3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714079
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (311, 31)
#
# The shape of  is (46, 31)
# #assay_desc:
# count                                                    46
# unique                                                    3
# top       Agonist activity at GPR84 (unknown origin) exp...
# freq                                                     43
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                  46
# unique                                 44
# top       CCCCCCCCNc1cc(=O)[nH]c(=O)[nH]1
# freq                                    2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1946
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (227, 31)
#
# The shape of  is (18, 31)
# #assay_desc:
# count                                                    18
# unique                                                    4
# top       Agonist activity at human MT2 receptor express...
# freq                                                     10
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                       18
# unique                                      18
# top       CCC(=O)NCCCc1cc(OC)ccc1-c1cccc(OC)c1
# freq                                         1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2955
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (188, 31)
#
# The shape of  is (11, 31)
# #assay_desc:
# count                                                    11
# unique                                                    5
# top       Agonist activity at human S1P2 receptor assess...
# freq                                                      5
# Name: assay_desc, dtype: object
#
# ...
#
# The shape of type_df is (701, 31)
#
# The shape of  is (283, 31)
# #assay_desc:
# count                                                   283
# unique                                                   25
# top       Agonist activity at human FFA4 receptor expres...
# freq                                                     61
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                     283
# unique                                    246
# top       Cc1cc(C)cc(COc2ccc(CCC(=O)O)cc2C)c1
# freq                                        2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5994
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL225
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1456, 31)
#
# The shape of  is (1155, 31)
# #assay_desc:
# count                                                  1155
# unique                                                   44
# top       Agonist activity at human 5HT2C receptor stabl...
# freq                                                    198
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                       1155
# unique                       811
# top       NCCc1c[nH]c2ccc(O)cc12
# freq                          23
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1945
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (238, 31)
#
# The shape of  is (18, 31)
# #assay_desc:
# count                                                    18
# unique                                                    4
# top       Agonist activity at human MT1 receptor express...
# freq                                                     10
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                       18
# unique                                      18
# top       CCC(=O)NCCCc1cc(OC)ccc1-c1cccc(OC)c1
# freq                                         1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2331058
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (22, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1995
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (325, 31)
#
# The shape of  is (120, 31)
# #assay_desc:
# count                                                   120
# unique                                                    3
# top       Agonist activity at human recombinant IP recep...
# freq                                                    114
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   120
# unique                                                  119
# top       CCCCCCC(O)c1ccc(N2C(=O)CC[C@@H]2CCCc2ccc(C(=O)...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4518
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (84, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1941
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (247, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1925
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293316
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (131, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523248
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (14, 31)
#
# The shape of  is (14, 31)
# #assay_desc:
# count                                                    14
# unique                                                    2
# top       Activity at human TAS2R38 expressed in HEK-293...
# freq                                                     13
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                14
# unique               14
# top       CC(=O)NC(N)=S
# freq                  1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4532
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4608
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (438, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2414
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3559686
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1832
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (239, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4596
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (45, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5071
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (17, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2024
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (89, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4295740
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5844
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (105, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL234
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (744, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Agonist activity at dopamine D3 receptor (unkn...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                     1
# unique                    1
# top       NCCc1ccc(O)c(O)c1
# freq                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL219
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (398, 31)
#
# The shape of  is (22, 31)
# #assay_desc:
# count                                                    22
# unique                                                    4
# top       Agonist activity was calculated in calcium flu...
# freq                                                     13
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                          22
# unique                                         21
# top       Cc1cccc(NC(=O)CN2CCN(c3ccccc3C#N)CC2)c1
# freq                                            2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1805
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (27, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4235
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (46, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1798
#
# Effect: agon
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (8, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================

# %% [markdown]
# ### Antagonism: IC50

# %%
# IP3/IP1 and Ca2+ assay
p_antag_G_Ca = r"(?i)calcium|ca2+|IP1|IP3"
p_antag_G_Ca_ex = r"(?i)arrestin|gtp|camp|allosteric"

# %%
# cat_datasets: ORs
# nearly no data points

# %%
# cat_datasets: GPCRs
gpcr_type_dfs, gpcr_antag_G_Ca_dfs, gpcr_antag_G_Ca_len_dfs = categorize_GPCRs(targets='GPCRs', effect='antag', assay='G_Ca', std_types=['IC50'], 
                                                                                 pattern=p_antag_G_Ca, pattern_ex=p_antag_G_Ca_ex)
# Out:
# Target: CHEMBL2327
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (290, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3713916
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5144
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (18, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                     2
# unique                                    2
# top       Inhibition of human VIP1 receptor
# freq                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     2
# unique                                                    2
# top       CC[C@@H](C)[C@H](NC(=O)[C@H](CO)NC(=O)[C@H](CC...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL223
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (188, 31)
#
# The shape of  is (82, 31)
# #assay_desc:
# count                                                    82
# unique                                                    4
# top       Antagonist activity at alpha-1D adrenergic rec...
# freq                                                     38
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    82
# unique                                                   80
# top       C[C@H](Cc1cc2c(c(C(N)=O)c1)N(CCCO)CC2)NCCOc1cc...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2049
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (137, 31)
#
# The shape of  is (82, 31)
# #assay_desc:
# count                                                    82
# unique                                                   10
# top       Antagonist activity at human OTR expressed in ...
# freq                                                     26
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                 82
# unique                                73
# top       Cn1nccc1NS(=O)(=O)c1ccc(Cl)cc1
# freq                                   2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075178
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (55, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4714
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (82, 31)
#
# The shape of  is (75, 31)
# #assay_desc:
# count                                                    75
# unique                                                    9
# top       Antagonist activity at human P2Y6 receptor exp...
# freq                                                     26
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                      75
# unique                                     68
# top       O=[N+]([O-])C1=Cc2ccccc2OC1C(F)(F)F
# freq                                        3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4308
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (495, 31)
#
# The shape of  is (358, 31)
# #assay_desc:
# count                                                   358
# unique                                                   16
# top       Calcium Mobilization Assay: Calcium mobilizati...
# freq                                                     62
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   358
# unique                                                  350
# top       O=C(C[C@@H](NS(=O)(=O)c1ccc2ccccc2c1)c1ccccc1)...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1905
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL259
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1065, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4877
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (47, 31)
#
# The shape of  is (6, 31)
# #assay_desc:
# count                                                     6
# unique                                                    1
# top       Antagonist activity at human NPY4 receptor ass...
# freq                                                      6
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     6
# unique                                                    6
# top       COc1ccc(C)cc1S(=O)(=O)NC[C@H]1CC[C@H](Nc2nc3c(...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523360
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1833
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (307, 31)
#
# The shape of  is (176, 31)
# #assay_desc:
# count                                                   176
# unique                                                   17
# top       Activity at 5HT2B receptor expressed in CHO ce...
# freq                                                     44
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   176
# unique                                                  138
# top       O=C(c1ccc(-c2ccc(OC(F)(F)F)cc2)cc1)N1CCC(c2nc3...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1850
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3426
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3724
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (163, 31)
#
# The shape of  is (94, 31)
# #assay_desc:
# count                                                    94
# unique                                                   14
# top       Inhibition of LPA-induced calcium transients i...
# freq                                                     24
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    94
# unique                                                   90
# top       Cc1noc(-c2ccc(CSCCC(=O)O)cc2)c1NC(=O)OC(C)c1cc...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2203
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (33, 31)
#
# The shape of  is (16, 31)
# #assay_desc:
# count                                                    16
# unique                                                    3
# top       Antagonist activity against human motilin rece...
# freq                                                      8
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    16
# unique                                                   15
# top       CCC[C@@H]1NC(=O)[C@@H](C(C)C)NC(=O)[C@@H](Cc2c...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3636
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (77, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1963
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (58, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5852
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (123, 31)
#
# The shape of  is (49, 31)
# #assay_desc:
# count                                                    49
# unique                                                    2
# top       Antagonist activity at human QRFPR expressed i...
# freq                                                     35
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    49
# unique                                                   48
# top       N=C(N)NCCC[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)[C...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (766, 31)
#
# The shape of  is (207, 31)
# #assay_desc:
# count                                                   207
# unique                                                   12
# top       Antagonist activity at human thromboxane A2 re...
# freq                                                     38
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   207
# unique                                                  115
# top       Cc1ccc(Nc2ccc([N+](=O)[O-])cc2S(=O)(=O)NC(=O)N...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1790
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (396, 31)
#
# The shape of  is (12, 31)
# #assay_desc:
# count                                                    12
# unique                                                    3
# top       Antagonist activity at human V2 receptor expre...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    12
# unique                                                   12
# top       CC[C@H](C)[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5968
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (10, 31)
#
# The shape of  is (10, 31)
# #assay_desc:
# count                                                    10
# unique                                                    3
# top       Antagonist activity at LPA4 receptor expressed...
# freq                                                      8
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    10
# unique                                                   10
# top       NCC(=O)N[C@@H](CSc1ccc([N+](=O)[O-])cc1[N+](=O...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1628461
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (89, 31)
#
# The shape of  is (81, 31)
# #assay_desc:
# count                                                    81
# unique                                                    8
# top       Antagonist activity at OXE receptor (unknown o...
# freq                                                     31
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                           81
# unique                                          67
# top       CCCCCCc1cc2ccc(Cl)cc2n1C(=O)CC(C)CC(=O)O
# freq                                             6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2056
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (208, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293293
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (217, 31)
#
# The shape of  is (73, 31)
# #assay_desc:
# count                                                    73
# unique                                                    2
# top       Antagonist activity at human NPBWR1 expressed ...
# freq                                                     66
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    73
# unique                                                   73
# top       COC(=O)c1nn(-c2ccc(C(C)C)cc2)c(=O)c(Oc2ccc(OC)...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3228
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (56, 31)
#
# The shape of  is (5, 31)
# #assay_desc:
# count                                                     5
# unique                                                    5
# top       Antagonist activity at human mGluR8 receptor e...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    5
# unique                                                   5
# top       Cc1c(-c2ccc3c(c2)CN(C(C)C)C3=O)nnn1-c1ccc(F)cc1F
# freq                                                     1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL218
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2108, 31)
#
# The shape of  is (186, 31)
# #assay_desc:
# count                                                   186
# unique                                                   10
# top       Antagonist activity at human CB1 receptor stab...
# freq                                                     37
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   186
# unique                                                  182
# top       Cc1c(C(=O)NN2CCCCC2)nn(-c2ccc(Cl)cc2Cl)c1-c1cc...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL264
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (797, 31)
#
# The shape of  is (52, 31)
# #assay_desc:
# count                                                    52
# unique                                                    2
# top       Antagonist activity at human histamine H3 rece...
# freq                                                     38
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                    52
# unique                                   52
# top       N=C(NCc1ccc(Cl)cc1)SCCCc1c[nH]cn1
# freq                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1854
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (50, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3399910
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4296246
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5201
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2731
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4616
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1395, 31)
#
# The shape of  is (289, 31)
# #assay_desc:
# count                                                   289
# unique                                                   17
# top       Antagonist activity at recombinant human GHSR1...
# freq                                                     39
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                           289
# unique                                          282
# top       CCc1nc(N)nc(N)c1-c1ccc(NCc2ccc(Cl)cc2)cc1
# freq                                              2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2384898
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (142, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075144
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (55, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL226
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (368, 31)
#
# The shape of  is (8, 31)
# #assay_desc:
# count                                                     8
# unique                                                    2
# top       Fluorometric Imaging Plate Reader (FLIPR) Asss...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             8
# unique                                            8
# top       CNc1cc2nc(NCc3cccnc3)nc(C(=O)c3cccs3)c2s1
# freq                                              1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714046
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075166
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4427
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (646, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Inhibition of human DP receptor assessed as LT...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       O=c1cc(CN2CCOc3c(Cl)cc(-n4ccc5cc(F)ccc54)cc3C2...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL298
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1552, 31)
#
# The shape of  is (76, 31)
# #assay_desc:
# count                                                    76
# unique                                                    1
# top       In vitro inhibition of gastrin-induced [Ca2+] ...
# freq                                                     76
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    76
# unique                                                   76
# top       O=C(O)CCCNC(=O)CCC(NC(=O)c1cc(Cl)cc(Cl)c1)C(=O...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3710
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (791, 31)
#
# The shape of  is (45, 31)
# #assay_desc:
# count                                                    45
# unique                                                    4
# top       Antagonist activity at human prostanoid EP3 re...
# freq                                                     20
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    45
# unique                                                   43
# top       C[C@H](NC(=O)c1c(C(F)F)nn(C)c1Oc1cccc(C(F)(F)F...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2150840
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (8, 31)
#
# The shape of  is (8, 31)
# #assay_desc:
# count                                                     8
# unique                                                    1
# top       Antagonist activity at human GPR99 receptor ex...
# freq                                                      8
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  8
# unique                                                 8
# top       Cc1cccc(-c2ccc(CNC(=O)CCCc3ccc4cccnc4n3)cc2)c1
# freq                                                   1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4691
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1014, 31)
#
# The shape of  is (616, 31)
# #assay_desc:
# count                                                   616
# unique                                                    5
# top       Antagonist activity against human PAR4 express...
# freq                                                    507
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   616
# unique                                                  584
# top       COc1cc(OCc2cccc(OCc3ccccc3)c2)c2cc(-c3cn4nc(OC...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4441
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1996, 31)
#
# The shape of  is (437, 31)
# #assay_desc:
# count                                                   437
# unique                                                   31
# top       Antagonist activity at human recombinant CXCR3...
# freq                                                     58
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   437
# unique                                                  360
# top       CCNC(=O)N1CCCN(c2ccc(C(=O)NCCc3ccc(Cl)cc3Cl)cc...
# freq                                                      5
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1889
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (538, 31)
#
# The shape of  is (216, 31)
# #assay_desc:
# count                                                   216
# unique                                                   20
# top       Antagonist activity at human V1a receptor expr...
# freq                                                     39
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   216
# unique                                                  198
# top       CN1Cc2cc(Cl)ccc2-n2c(nnc2[C@H]2CC[C@H](Oc3cccc...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5137
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (816, 31)
#
# The shape of  is (321, 31)
# #assay_desc:
# count                                                   321
# unique                                                    5
# top       Biological Assay: The utility of the compounds...
# freq                                                    315
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   321
# unique                                                  296
# top       CC1CN(Cc2ccc3c(-c4ccc(F)cc4)cc(C(N)=O)nc3c2)CC...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075162
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (48, 31)
#
# The shape of  is (44, 31)
# #assay_desc:
# count                                                    44
# unique                                                    2
# top       Antagonist activity at human GPR17 expressed i...
# freq                                                     39
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                 44
# unique                                                43
# top       COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1
# freq                                                   2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523454
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3798
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (801, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5409
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (34, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3250
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (91, 31)
# #assay_desc:
# count                                                    91
# unique                                                   14
# top       Antagonist activity at human recombinant LPA3 ...
# freq                                                     23
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    91
# unique                                                   79
# top       C[C@@H](OC(=O)Nc1c(-c2ccc(-c3ccc(C4(C(=O)O)CC4...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2035
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (450, 31)
#
# The shape of  is (150, 31)
# #assay_desc:
# count                                                   150
# unique                                                   11
# top       Antagonist activity at human muscarinic M5 rec...
# freq                                                     69
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   150
# unique                                                  116
# top       Cn1ccnc1SC[C@H]1CCN(S(=O)(=O)c2ccc3c(c2)CCO3)C...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3176
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (50, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL344
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (3063, 31)
#
# The shape of  is (598, 31)
# #assay_desc:
# count                                                   598
# unique                                                   36
# top       Concentration required to inhibit 50% of melan...
# freq                                                     79
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                 598
# unique                                580
# top       CC(CC(C)(C)C)Oc1cccc2ccc(N)nc12
# freq                                    5
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5413
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (138, 31)
#
# The shape of  is (23, 31)
# #assay_desc:
# count                                                    23
# unique                                                    2
# top       Antagonist activity at human GPR54 receptor ex...
# freq                                                     22
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    23
# unique                                                   23
# top       N#Cc1c(-c2cccc(C(=O)O)c2)cc(-c2ccccc2O)nc1NC(=...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5678
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (234, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4761
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (301, 31)
#
# The shape of  is (83, 31)
# #assay_desc:
# count                                                    83
# unique                                                    7
# top       Antagonist activity at C3a receptor in human M...
# freq                                                     56
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    83
# unique                                                   42
# top       N=C(N)NCCC[C@H](NC(=O)COCC(c1ccccc1)c1ccccc1)C...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4029
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (334, 31)
#
# The shape of  is (50, 31)
# #assay_desc:
# count                                                    50
# unique                                                    4
# top       Antagonist activity in CXCR1 (unknown origin) ...
# freq                                                     25
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             50
# unique                                            50
# top       O=C(Nc1ccc(F)cc1)c1ccc(SCc2ccccc2B(O)O)nc1
# freq                                               1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5892
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2274
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (207, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714079
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (626, 31)
#
# The shape of  is (48, 31)
# #assay_desc:
# count                                                    48
# unique                                                    2
# top       Antagonist activity at human GPR84 expressed i...
# freq                                                     47
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                            48
# unique                           46
# top       N#CC1=Cc2ccccc2Sc2ccccc21
# freq                              2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1946
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (106, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2955
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (680, 31)
#
# The shape of  is (187, 31)
# #assay_desc:
# count                                                   187
# unique                                                    9
# top       Agonist activity at human S1P2 receptor expres...
# freq                                                     40
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   187
# unique                                                  134
# top       O=C(O)c1ccc(Oc2cc(NC(=O)N3CCC(O)(c4ccc(F)cc4)C...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1867
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (167, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Antagonist activity at alpha-2A adrenergic rec...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       CCCCCCCCCCCCCCCC(=O)N[C@H](C(=O)N[C@H](C(=O)N[...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL288
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1657, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# ...
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5994
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (126, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL225
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1069, 31)
#
# The shape of  is (56, 31)
# #assay_desc:
# count                                                    56
# unique                                                    7
# top       Inhibition of human 5HT2c receptor expressed i...
# freq                                                     29
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    56
# unique                                                   55
# top       Cc1nc2n(c(=O)c1CCN1CCC(c3noc4cc(F)ccc34)CC1)CCCC2
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1945
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (247, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2331058
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1995
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (246, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                                     2
# unique                                                    2
# top       Inhibition of human recombinant IP receptor ex...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     2
# unique                                                    2
# top       Cc1ccc(-n2c(C)ccc2-c2cc(Cl)ccc2OCc2ccc(F)cc2)c...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4518
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (321, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1941
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (98, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1925
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293316
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523248
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4532
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (72, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4608
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (948, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2414
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (650, 31)
#
# The shape of  is (123, 31)
# #assay_desc:
# count                                                   123
# unique                                                   10
# top       Antagonist activity at recombinant human CCR4 ...
# freq                                                     50
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                    123
# unique                                   121
# top       COc1nccnc1NS(=O)(=O)c1cccc(Cl)c1Cl
# freq                                       2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3559686
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1832
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (169, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4596
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (77, 31)
# #assay_desc:
# count                                                    77
# unique                                                    2
# top       Antagonist activity against human CCR8 express...
# freq                                                     41
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    77
# unique                                                   77
# top       CCCC(=O)N1CCC(NCc2ccc(NC(=O)c3ccccc3C)c3ccccc2...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5071
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2960, 31)
#
# The shape of  is (214, 31)
# #assay_desc:
# count                                                   214
# unique                                                   14
# top       Fluorometric Imaging Plate Reader (FLIPR) Assa...
# freq                                                     55
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   214
# unique                                                  207
# top       O=C(O)Cc1cnc(C(=O)c2ccc(NC(=O)c3ncccn3)cc2)c2c...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2024
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (69, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4295740
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (15, 31)
#
# The shape of  is (15, 31)
# #assay_desc:
# count                                                    15
# unique                                                    1
# top       Inhibition of recombinant human Gq/11 coupled ...
# freq                                                     15
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    15
# unique                                                    9
# top       C=C1C(=O)N[C@@H](C)C(=O)N(C)[C@@H](C)C(=O)N[C@...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5844
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL234
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (383, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                                     2
# unique                                                    1
# top       Antagonist activity at dopamine D3 receptor (u...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     2
# unique                                                    2
# top       O=C(CCCCN1CCC(c2noc3cc(F)ccc23)CC1)c1cc2c3c(c1...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL219
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (407, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1805
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (17, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4235
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (4732, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1798
#
# Effect: antag
#
# Assay: G_Ca
#
# Pattern: (?i)calcium|ca2+|IP1|IP3
#
# Pattern_ex: (?i)arrestin|gtp|camp|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (268, 31)
#
# The shape of  is (213, 31)
# #assay_desc:
# count                                                   213
# unique                                                    6
# top       Antagonist activity at CysLT1 receptor in huma...
# freq                                                     76
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   213
# unique                                                  207
# top       O=C(O)c1ccc(OCCCc2ccc(OCCCCOC3CCCCC3)cc2)c(C(=...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================

# %% [markdown]
# ## B_arrest

# %% [markdown]
# ### Agonism: EC50

# %%
# G-protein independent functional assays
# Beta-arrestin recruitment assay
p_agon_B_arrest = r"(?i)arrest"
p_agon_B_arrest_ex = r"(?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric"

or_type_dfs, or_agon_B_arrest_dfs, or_agon_B_arrest_plus_dfs, or_agon_B_arrest_exclude_dfs, or_agon_B_arrest_final_dfs, or_agon_B_arrest_len_dfs = categorize_ORs(targets='ORs', effect='agon', assay='B_arrest', std_types=['EC50'], 
                                                                                             pattern=p_agon_B_arrest, pattern_ex=p_agon_B_arrest_ex)
# Out:
# target_chembl_id: CHEMBL233
#
# Target: CHEMBL233
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2296, 31)
#
# The shape of  is (267, 31)
# #assay_desc:
# count                                                   267
# unique                                                   24
# top       Agonist activity at human mu opioid receptor e...
# freq                                                     45
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   267
# unique                                                  214
# top       C[C@@H](NC(=O)[C@@H](N)Cc1ccc(O)cc1)C(=O)NCC(=...
# freq                                                     10
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
# The shape of final_df is (267, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL237
#
# Target: CHEMBL237
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2062, 31)
#
# The shape of  is (66, 31)
# #assay_desc:
# count                                                    66
# unique                                                   17
# top       Agonist activity at GFP-fused kappa opioid rec...
# freq                                                     13
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             66
# unique                                            54
# top       Clc1ccc(CSc2nnc(-c3ccccn3)n2Cc2ccco2)cc1Cl
# freq                                               4
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (66, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL236
#
# Target: CHEMBL236
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1324, 31)
#
# The shape of  is (53, 31)
# #assay_desc:
# count                                                    53
# unique                                                    9
# top       Agonist activity at human delta opioid recepto...
# freq                                                     16
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    53
# unique                                                   40
# top       CC(C)C[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)CNC(=O...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (53, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL2014
#
# Target: CHEMBL2014
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (524, 31)
#
# The shape of  is (47, 31)
# #assay_desc:
# count                                                    47
# unique                                                    3
# top       Agonist activity at NOP (unknown origin) expre...
# freq                                                     45
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    47
# unique                                                   46
# top       CC1(N2CCC(n3c([C@H]4CCCNC4)nc4ccccc43)CC2)CCCC...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (47, 31)
#
# ##########################
# ================================================================

# %%
# cat_datasets: GPCRs
gpcr_type_dfs, gpcr_agon_B_arrest_dfs, gpcr_agon_B_arrest_len_dfs = categorize_GPCRs(targets='GPCRs', effect='agon', assay='B_arrest', std_types=['EC50'], 
                                                                                             pattern=p_agon_B_arrest, pattern_ex=p_agon_B_arrest_ex)
# Out:
# Target: CHEMBL2327
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (5, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3713916
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5144
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (38, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL223
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (247, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2049
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (492, 31)
#
# The shape of  is (25, 31)
# #assay_desc:
# count                                                    25
# unique                                                    3
# top       Agonist activity at recombinant human Gi/Go-co...
# freq                                                     14
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    25
# unique                                                   16
# top       CC[C@H](C)[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=...
# freq                                                      3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075178
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (125, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4714
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (356, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4308
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1905
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL259
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1564, 31)
#
# The shape of  is (10, 31)
# #assay_desc:
# count                                                    10
# unique                                                    1
# top       Agonist activity at human FLAG-tagged MC4R exp...
# freq                                                     10
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    10
# unique                                                   10
# top       CCCCC(NC(=O)[C@H](CO)NC(=O)[C@H](Cc1ccc(O)cc1)...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4877
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (379, 31)
#
# The shape of  is (184, 31)
# #assay_desc:
# count                                                   184
# unique                                                    6
# top       Agonist activity at human Y4R expressed in HEK...
# freq                                                     50
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   184
# unique                                                   63
# top       CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O...
# freq                                                      8
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523360
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1833
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (935, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1850
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (35, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3426
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                                     2
# unique                                                    1
# top       Agonist activity at human 5-HT5A receptor tran...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                      2
# unique                                     2
# top       CS(=O)(=O)C1(CNCc2cccc3cccnc23)CC1
# freq                                       1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3724
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (108, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2203
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (164, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3636
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (10, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1963
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (40, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5852
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (96, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1790
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (366, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                                                     4
# unique                                                    1
# top       Agonist activity at human V2 receptor expresse...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     4
# unique                                                    4
# top       Cc1cc(C(=O)N2Cc3cnn(C)c3Nc3ccccc32)ccc1CNC(=O)...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5968
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (24, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1628461
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (6, 31)
# #assay_desc:
# count                                                     6
# unique                                                    1
# top       Agonist activity at human PK-tagged OXER1 expr...
# freq                                                      6
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             6
# unique                                            6
# top       CCCCC/C=C\C/C=C\C/C=C\C=C\C(=O)CCCC(=O)OC
# freq                                              1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2056
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (538, 31)
#
# The shape of  is (101, 31)
# #assay_desc:
# count                                                   101
# unique                                                    5
# top       Agonist activity at recombinant C-terminal RLu...
# freq                                                     42
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                            101
# unique                                            58
# top       Cc1cc(Oc2nccc3occc23)ccc1-c1c(C)ncc2nccn12
# freq                                               3
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293293
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3228
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (157, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL218
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (3668, 31)
#
# The shape of  is (110, 31)
# #assay_desc:
# count                                                   110
# unique                                                   13
# top       Agonist activity at N-terminal Flag epitope ta...
# freq                                                     32
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   110
# unique                                                   89
# top       CCCCCCC(C)(C)c1ccc([C@@H]2C[C@H](O)CC[C@H]2CCC...
# freq                                                      7
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL264
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (484, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1854
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (45, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3399910
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (583, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4296246
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5201
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (120, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2731
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4616
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1079, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2384898
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (58, 31)
#
# The shape of  is (55, 31)
# #assay_desc:
# count                                                    55
# unique                                                    4
# top       Agonist activity at recombinant human GPR18 ex...
# freq                                                     33
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    55
# unique                                                   54
# top       CCCCCc1cc(O)c2c(c1)OC(C)(C)[C@@H]1CCC(C)=C[C@@...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075144
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (159, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL226
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (556, 31)
#
# The shape of  is (3, 31)
# #assay_desc:
# count                                                     3
# unique                                                    1
# top       Agonist activity at human A1A adenosine recept...
# freq                                                      3
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     3
# unique                                                    3
# top       OC[C@H]1O[C@@H](n2cnc3c(NC(C4CCC4)C4CCC4)ncnc3...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714046
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075166
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4427
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (185, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL298
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (136, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3710
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (229, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2150840
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4691
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (310, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4441
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (56, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1889
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (434, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5137
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1124, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075162
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (97, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523454
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (23, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3798
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (14, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5409
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (961, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3250
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (127, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2035
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (311, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3176
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL344
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (83, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5413
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (228, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5678
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4761
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (238, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4029
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5892
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2274
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (386, 31)
#
# The shape of  is (20, 31)
# #assay_desc:
# count                                                    20
# unique                                                    4
# top       Agonist activity at human S1P5 receptor by bet...
# freq                                                     10
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    20
# unique                                                   15
# top       N#Cc1cc(OC(F)(F)F)cc(-c2nc(-c3ccc4[nH]c5c(c4c3...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714079
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (311, 31)
#
# The shape of  is (92, 31)
# #assay_desc:
# count                                                    92
# unique                                                   10
# top       Agonist activity at human GPR84 expressed in C...
# freq                                                     63
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                    92
# unique                                   82
# top       CCCCCCCCCCCC1=C(O)C(=O)C=C(O)C1=O
# freq                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1946
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (227, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                                                     4
# unique                                                    2
# top       Agonist activity at human MT2 receptor transfe...
# freq                                                      3
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    4
# unique                                                   4
# top       Nc1nc(NCc2ccc(Oc3ccccc3)cc2)nc(-c2c(F)cccc2CO)n1
# freq                                                     1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2955
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (188, 31)
#
# The shape of  is (16, 31)
# #assay_desc:
# count                                                    16
# unique                                                    3
# top       Agonist activity at human S1P2 receptor by bet...
# freq                                                     10
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    16
# unique                                                   11
# top       N#Cc1cc(OC(F)(F)F)cc(-c2nc(-c3ccc4[nH]c5c(c4c3...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1867
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (171, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL288
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (7, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069161
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (220, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4015
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2321628
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3632455
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (487, 31)
#
# The shape of  is (133, 31)
# #assay_desc:
# count                                                   133
# unique                                                    1
# top       Agonist activity at human GPR139 expressed in ...
# freq                                                    133
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   133
# unique                                                  129
# top       CC(C(=O)N[C@@H](C)c1ccc(Cl)c(F)c1)n1nc2cccnn2c1=O
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3309110
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (3, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL245
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (233, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                                     2
# unique                                                    2
# top       Agonist activity at muscarinic M3 receptor (un...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                              2
# unique                             1
# top       C[N+](C)(C)CCOC(N)=O.[Cl-]
# freq                               2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4867
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (51, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1810
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (18, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1983
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (196, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5548
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1875
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (405, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2695
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (12, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# ...
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5339
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (701, 31)
#
# The shape of  is (182, 31)
# #assay_desc:
# count                                                   182
# unique                                                   12
# top       Agonist activity at GPR120 expressed in HEK 29...
# freq                                                     39
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                           182
# unique                                          179
# top       O=S1(=O)c2ccccc2CN1c1cc(F)cc(Oc2ccccn2)c1
# freq                                              2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5994
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL225
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (1456, 31)
#
# The shape of  is (29, 31)
# #assay_desc:
# count                                                    29
# unique                                                    2
# top       Agonist activity at human 5-HT2C INI receptor ...
# freq                                                     18
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                         29
# unique                        13
# top       NCCc1c[nH]c2ccc(O)cc12
# freq                           4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1945
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (238, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                                                     4
# unique                                                    2
# top       Agonist activity at human MT1 receptor transfe...
# freq                                                      3
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    4
# unique                                                   4
# top       Nc1nc(NCc2ccc(Oc3ccccc3)cc2)nc(-c2c(F)cccc2CO)n1
# freq                                                     1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2331058
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (22, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1995
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (325, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4518
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (84, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1941
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (247, 31)
#
# The shape of  is (49, 31)
# #assay_desc:
# count                                                    49
# unique                                                    4
# top       Agonist activity at human histamine H2 recepto...
# freq                                                     23
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                49
# unique               42
# top       NCCc1c[nH]cn1
# freq                  4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1925
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293316
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (131, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523248
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (14, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4532
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4608
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (438, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2414
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3559686
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1832
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (239, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4596
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (45, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5071
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (17, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2024
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (89, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4295740
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5844
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (105, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL234
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (744, 31)
#
# The shape of  is (185, 31)
# #assay_desc:
# count                                                   185
# unique                                                    9
# top       Agonist activity at human D3R expressed in CHO...
# freq                                                    112
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                    185
# unique                                   172
# top       CCCN1CCC[C@@H]2Cc3[nH]ncc3C[C@H]21
# freq                                       6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL219
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (398, 31)
#
# The shape of  is (30, 31)
# #assay_desc:
# count                                                    30
# unique                                                    6
# top       Agonist activity at human D4 receptor expresse...
# freq                                                     19
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                    30
# unique                   29
# top       NCCc1ccc(O)c(O)c1
# freq                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1805
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (27, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4235
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (46, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1798
#
# Effect: agon
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|antagonis|inverse agonist|allosteric
#
# Standard type: EC50
#
# The shape of type_df is (8, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================

# %% [markdown]
# ### Antagonism: IC50

# %%
# G-protein independent functional assays
# Beta-arrestin recruitment assay
p_antag_B_arrest = r"(?i)arrest"
p_antag_B_arrest_ex = r"(?i)gtp|camp|calcium|IP1|IP3|allosteric"

or_type_dfs, or_antag_B_arrest_dfs, or_antag_B_arrest_plus_dfs, or_antag_B_arrest_exclude_dfs, or_antag_B_arrest_final_dfs, or_antag_B_arrest_len_dfs  = categorize_ORs(targets='ORs', effect='antag', assay='B_arrest', std_types=['IC50'], 
                                                                                             pattern=p_antag_B_arrest, pattern_ex=p_antag_B_arrest_ex)
# Out:
# target_chembl_id: CHEMBL233
#
# Target: CHEMBL233
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1366, 31)
#
# The shape of  is (40, 31)
# #assay_desc:
# count                                                    40
# unique                                                    3
# top       Antagonist activity at GAL4-VP16-fused MOR (un...
# freq                                                     26
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    40
# unique                                                   40
# top       Cc1ccc(S(=O)(=O)NCc2ccc(C(=O)NCCN(Cc3ccccc3)C(...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (40, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL237
#
# Target: CHEMBL237
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1049, 31)
#
# The shape of  is (73, 31)
# #assay_desc:
# count                                                    73
# unique                                                    7
# top       Antagonist activity at GAL4-VP16-fused KOR (un...
# freq                                                     26
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    73
# unique                                                   54
# top       Cc1ccc(S(=O)(=O)NCc2ccc(C(=O)NCCN(Cc3ccccc3)C(...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (73, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL236
#
# Target: CHEMBL236
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1316, 31)
#
# The shape of  is (38, 31)
# #assay_desc:
# count                                                    38
# unique                                                    2
# top       Antagonist activity at GAL4-VP16-fused DOR (un...
# freq                                                     26
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    38
# unique                                                   38
# top       Cc1ccc(S(=O)(=O)NCc2ccc(C(=O)NCCN(Cc3ccccc3)C(...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (38, 31)
#
# ##########################
# ================================================================
# target_chembl_id: CHEMBL2014
#
# Target: CHEMBL2014
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (747, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# The shape of plus_df is (0, 31)
#
# The shape of exclude_df is (0, 31)
#
# The shape of final_df is (0, 31)
#
# ##########################
# ================================================================

# %%
# cat_datasets: GPCRs
gpcr_type_dfs, gpcr_antag_B_arrest_dfs, gpcr_antag_B_arrest_len_dfs = categorize_GPCRs(targets='GPCRs',  effect='antag', assay='B_arrest', std_types=['IC50'], 
                                                                                             pattern=p_antag_B_arrest, pattern_ex=p_antag_B_arrest_ex)
# Out:
# Target: CHEMBL2327
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (290, 31)
#
# The shape of  is (7, 31)
# #assay_desc:
# count                                                     7
# unique                                                    1
# top       Antagonist activity at human TACR2 expressed i...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     7
# unique                                                    7
# top       CC[C@H](C)[C@@H](OC(=O)C#Cc1ccccc1)C(=O)N1CCC[...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3713916
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5144
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (18, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL223
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (188, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2049
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (137, 31)
#
# The shape of  is (10, 31)
# #assay_desc:
# count                                                    10
# unique                                                    3
# top       Antagonist activity at human OXTR expressed in...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    10
# unique                                                   10
# top       CC[C@H](C)[C@@H](OC(=O)C#Cc1ccccc1)C(=O)N1CCC[...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075178
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (55, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4714
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (82, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4308
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (495, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1905
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL259
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1065, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4877
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (47, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523360
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1833
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (307, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                                                     4
# unique                                                    1
# top       Antagonist activity at 5-HT2B receptor (unknow...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                 4
# unique                                                4
# top       CCc1cc(=O)[nH]c(-n2nc(C)cc2NC(=O)c2ccccc2F)n1
# freq                                                  1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1850
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Antagonist activity at Gs-coupled human D5R ex...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  1
# unique                                                 1
# top       COc1ccc(OCCN2CCN(C(=O)c3cc4ccccc4[nH]3)CC2)cc1
# freq                                                   1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3426
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (53, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3724
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (163, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2203
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (33, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3636
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (77, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1963
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (58, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5852
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (123, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (766, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                                                     4
# unique                                                    3
# top       Inhibition of beta-arrestin translocation at h...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     4
# unique                                                    4
# top       CN([C@@H]1CCc2c(c3ccccc3n2CC(=O)O)C1)S(=O)(=O)...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1790
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (396, 31)
#
# The shape of  is (24, 31)
# #assay_desc:
# count                                                    24
# unique                                                    5
# top       Inhibition of vasopressin-stimulated vasopress...
# freq                                                      8
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             24
# unique                                             7
# top       O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12
# freq                                               6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5968
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (10, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1628461
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (89, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2056
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (208, 31)
#
# The shape of  is (17, 31)
# #assay_desc:
# count                                                    17
# unique                                                    2
# top       Antagonist activity at C-terminal RLuc8-fused ...
# freq                                                     16
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                 17
# unique                                                 9
# top       COc1ccc2c(c1OC)-c1c(Br)ccc3c1[C@@H](C2)N(C)CC3
# freq                                                   2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293293
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (217, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3228
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (56, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL218
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2108, 31)
#
# The shape of  is (9, 31)
# #assay_desc:
# count                                                     9
# unique                                                    2
# top       Antagonist activity at CP-55940-activated CB1 ...
# freq                                                      8
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     9
# unique                                                    9
# top       CC[C@]12CCCN(C(=O)c3cccc(Br)c3)CCc3c(n(c4ccccc...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL264
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (797, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1854
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (50, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3399910
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4296246
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5201
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2731
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4616
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1395, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2384898
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (142, 31)
#
# The shape of  is (142, 31)
# #assay_desc:
# count                                                   142
# unique                                                    7
# top       Antagonist activity against human GPR18 expres...
# freq                                                     51
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                   142
# unique                                                  140
# top       Cn1c(=O)c2c(nc3n2CCCN3CCc2c[nH]c3ccccc23)n(C)c1=O
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075144
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (55, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL226
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (368, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714046
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075166
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (19, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4427
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (646, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL298
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1552, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3710
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (791, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2150840
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (8, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4691
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1014, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4441
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1996, 31)
#
# The shape of  is (47, 31)
# #assay_desc:
# count                                                    47
# unique                                                    1
# top       Antagonist activity at recombinant human CXCR3...
# freq                                                     47
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    47
# unique                                                   47
# top       C[C@@H]1CN(c2scnc2-c2nc3ccccc3[nH]2)CCN1C(=O)C...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1889
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (538, 31)
#
# The shape of  is (5, 31)
# #assay_desc:
# count                                                     5
# unique                                                    2
# top       Agonist activity at human V1a receptor express...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     5
# unique                                                    4
# top       Cc1cc(C(=O)N2Cc3cnn(C)c3Nc3ccccc32)ccc1CNC(=O)...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5137
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (816, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1075162
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (48, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523454
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3798
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (801, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5409
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (34, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3250
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2035
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (450, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3176
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (50, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL344
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (3063, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5413
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (138, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5678
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (234, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4761
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (301, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4029
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (334, 31)
#
# The shape of  is (94, 31)
# #assay_desc:
# count                                                    94
# unique                                                    6
# top       In Vitro Assay: The in vitro affinity of the c...
# freq                                                     37
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    94
# unique                                                   65
# top       Cc1ccc(C(Nc2c(Nc3cccc(C(=O)N(C)C)c3O)c(=O)c2=O...
# freq                                                      6
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5892
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2274
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (207, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3714079
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (626, 31)
#
# The shape of  is (4, 31)
# #assay_desc:
# count                                                     4
# unique                                                    1
# top       Displacement of [3H]PSB-1584 from recombinant ...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                             4
# unique                                            4
# top       Clc1ccc2c(Cc3c[nH]c4cc(Cl)ccc34)c[nH]c2c1
# freq                                              1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1946
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (106, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2955
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (680, 31)
#
# The shape of  is (10, 31)
# #assay_desc:
# count                                                    10
# unique                                                    3
# top       Antagonist activity at S1P2 receptor expressed...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    10
# unique                                                   10
# top       CN(CC(=O)NC(COCc1ccccc1)C(=O)Nc1ccc(Oc2ccccc2)...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1867
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (167, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL288
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1657, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2069161
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (47, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4015
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2756, 31)
#
# The shape of  is (11, 31)
# #assay_desc:
# count                                                    11
# unique                                                    3
# top       Antagonist activity at human CCR2 expressed in...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    11
# unique                                                    5
# top       O=C(O)c1ccc(Oc2ccc(Cl)cc2NS(=O)(=O)c2ccc(Cl)c(...
# freq                                                      4
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2321628
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (82, 31)
#
# The shape of  is (7, 31)
# #assay_desc:
# count                                                     7
# unique                                                    1
# top       Antagonist activity at human CCR10 expressed i...
# freq                                                      7
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     7
# unique                                                    7
# top       CC[C@H](C)[C@@H](OC(=O)C#Cc1ccccc1)C(=O)N1CCC[...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3632455
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3309110
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL245
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (934, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                                     2
# unique                                                    1
# top       Binding affinity to human muscarinic M3 recept...
# freq                                                      2
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     2
# unique                                                    2
# top       CC1(C)C(/C=C/C=C/C=C2/N(CCCCS(=O)(=O)O)c3ccccc...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4867
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (3, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1810
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1983
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (435, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5548
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1875
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (91, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2695
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2114, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4561
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (883, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4421
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (5, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5861
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# ...
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    62
# unique                                                   61
# top       COc1cc(C(=O)N[C@@H]2C[C@H]3CCC[C@@H](C2)N3Cc2n...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL225
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (1069, 31)
#
# The shape of  is (5, 31)
# #assay_desc:
# count                                                     5
# unique                                                    2
# top       Antagonist activity at recombinant human 5-HT2...
# freq                                                      4
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                  5
# unique                                                 5
# top       Cc1cc2c(cc1Cl)N(C(=O)Nc1ccc(Oc3cccnc3C)nc1)CC2
# freq                                                   1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1945
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (247, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2331058
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1995
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (246, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Antagonist activity at human Gs-coupled PTGIR ...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       CC[C@]12CCCN(C(=O)c3cccc(Br)c3)CCc3c(n(c4ccccc...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4518
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (321, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1941
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (98, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1925
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1293316
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4523248
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (0, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4532
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (72, 31)
#
# The shape of  is (58, 31)
# #assay_desc:
# count                                                    58
# unique                                                    2
# top       Antagonist activity at recombinant human N-ter...
# freq                                                     57
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    58
# unique                                                   57
# top       O=C(N[C@H]1c2ccccc2C[C@H]1O)[C@H](Cc1ccccc1)C[...
# freq                                                      2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4608
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (948, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2414
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (650, 31)
#
# The shape of  is (19, 31)
# #assay_desc:
# count                                                    19
# unique                                                    4
# top       Inhibition of CCL22-stimulated CCR4 in human H...
# freq                                                      6
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                    19
# unique                                                    4
# top       CCC(C)n1ncn(-c2ccc(N3CCN(c4ccc(OCC5COC(Cn6cncn...
# freq                                                      7
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL3559686
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1832
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (169, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4596
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (141, 31)
#
# The shape of  is (2, 31)
# #assay_desc:
# count                                                     2
# unique                                                    2
# top       Antagonist activity at human CCR8 expressed in...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     2
# unique                                                    2
# top       CC[C@]12C=C(C(=O)OC)n3c(c(CCNC(=O)c4ccc(Br)cc4...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5071
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (2960, 31)
#
# The shape of  is (195, 31)
# #assay_desc:
# count                                                   195
# unique                                                    5
# top       Antagonist activity at human CRTH2 receptor ex...
# freq                                                    132
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                        195
# unique                                       190
# top       O=C(O)Cc1sc(-c2ccccc2)nc1-c1ccc(Cl)cc1
# freq                                           2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL2024
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (69, 31)
#
# The shape of  is (1, 31)
# #assay_desc:
# count                                                     1
# unique                                                    1
# top       Antagonist activity at human FSHR expressed in...
# freq                                                      1
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                                     1
# unique                                                    1
# top       COC(=O)[C@@H]1[C@H]2C[C@@H](OCc3ccc(Br)cc3)c3[...
# freq                                                      1
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4295740
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (15, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL5844
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (9, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL234
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (383, 31)
#
# The shape of  is (51, 31)
# #assay_desc:
# count                                                    51
# unique                                                    5
# top       Antagonist activity at human D3 receptor expre...
# freq                                                     19
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                               51
# unique                                              50
# top       O=C(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1
# freq                                                 2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL219
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (407, 31)
#
# The shape of  is (34, 31)
# #assay_desc:
# count                                                    34
# unique                                                    6
# top       Antagonist activity at human D4 receptor expre...
# freq                                                     19
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count                                          34
# unique                                         33
# top       Clc1ccc(N2CCN(Cc3c[nH]c4ncccc34)CC2)cc1
# freq                                            2
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1805
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (17, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL4235
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (4732, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================
# Target: CHEMBL1798
#
# Effect: antag
#
# Assay: B_arrest
#
# Pattern: (?i)arrest
#
# Pattern_ex: (?i)gtp|camp|calcium|IP1|IP3|allosteric
#
# Standard type: IC50
#
# The shape of type_df is (268, 31)
#
# The shape of  is (0, 31)
# #assay_desc:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: assay_desc, dtype: object
#
# #canonical_smiles:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: canonical_smiles, dtype: object
#
# ##########################
# ================================================================

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Create the dfs to store the stats

# %%
or_combine_len_dfs = [or_bind_len_dfs, 
                    or_agon_G_GTP_len_dfs, 
                    or_agon_G_cAMP_len_dfs, 
                    or_agon_G_Ca_len_dfs, 
                    or_agon_B_arrest_len_dfs, 
                    or_antag_G_GTP_len_dfs,  
                    or_antag_B_arrest_len_dfs]

# %%
final_len_df = pd.DataFrame()
for len_dfs in or_combine_len_dfs:
    for key, len_df in len_dfs.items():
        #print(key)
        # use method 'concat' to append len_df to final_len_df
        final_len_df = pd.concat([final_len_df, len_df], axis=0, sort=False)

# remove the rows where 'std_type' is 'Ke' or 'Kb'
final_len_df = final_len_df[~final_len_df['std_type'].isin(['Ke', 'Kb'])]
        
final_len_df
# type_df = final_df + final_out_df
# final_df = effect_type_df + plus_df - exclude_df
# Out:
#        target effect     assay std_type  type_df  effect_type_df  plus_df  \
# 0   CHEMBL233   bind       RBA       Ki     5682            5418      139
# 0   CHEMBL233   bind       RBA     IC50     1366             668       19
# 0   CHEMBL237   bind       RBA       Ki     4857            4535      140
# 0   CHEMBL237   bind       RBA     IC50     1049             478        7
# 0   CHEMBL236   bind       RBA       Ki     5152            4933       65
# 0   CHEMBL236   bind       RBA     IC50     1316             930       34
# 0  CHEMBL2014   bind       RBA       Ki     1381            1320       12
# 0  CHEMBL2014   bind       RBA     IC50      747             496       11
# 0   CHEMBL233   agon     G_GTP     EC50     2296            1067       80
# 0   CHEMBL237   agon     G_GTP     EC50     2062            1365      103
# 0   CHEMBL236   agon     G_GTP     EC50     1324             837       85
# 0  CHEMBL2014   agon     G_GTP     EC50      524             286       28
# 0   CHEMBL233   agon    G_cAMP     IC50     1366              79        6
# 0   CHEMBL233   agon    G_cAMP     EC50     2296             587        3
# 0   CHEMBL237   agon    G_cAMP     IC50     1049              36        0
# 0   CHEMBL237   agon    G_cAMP     EC50     2062             345        1
# 0   CHEMBL236   agon    G_cAMP     IC50     1316              33        0
# 0   CHEMBL236   agon    G_cAMP     EC50     1324             202        0
# 0  CHEMBL2014   agon    G_cAMP     IC50      747              80        0
# 0  CHEMBL2014   agon    G_cAMP     EC50      524              37        0
# 0   CHEMBL233   agon      G_Ca     EC50     2296             151       25
# 0   CHEMBL237   agon      G_Ca     EC50     2062              86        0
# 0   CHEMBL236   agon      G_Ca     EC50     1324              45        0
# 0  CHEMBL2014   agon      G_Ca     EC50      524              40       26
# 0   CHEMBL233   agon  B_arrest     EC50     2296             267        0
# 0   CHEMBL237   agon  B_arrest     EC50     2062              66        0
# 0   CHEMBL236   agon  B_arrest     EC50     1324              53        0
# 0  CHEMBL2014   agon  B_arrest     EC50      524              47        0
# 0   CHEMBL233  antag     G_GTP     IC50     1366             440        0
# 0   CHEMBL233  antag     G_GTP       Ki     5682              66        0
# 0   CHEMBL237  antag     G_GTP     IC50     1049             244        0
# 0   CHEMBL237  antag     G_GTP       Ki     4857              76        0
# 0   CHEMBL236  antag     G_GTP     IC50     1316             224        1
# 0   CHEMBL236  antag     G_GTP       Ki     5152              91        0
# 0  CHEMBL2014  antag     G_GTP     IC50      747             159        0
# 0  CHEMBL2014  antag     G_GTP       Ki     1381               6        0
# 0   CHEMBL233  antag  B_arrest     IC50     1366              40        0
# 0   CHEMBL237  antag  B_arrest     IC50     1049              73        0
# 0   CHEMBL236  antag  B_arrest     IC50     1316              38        0
# 0  CHEMBL2014  antag  B_arrest     IC50      747               0        0
#
#    exclude_df  final_df  final_out_df
# 0           0      5557           125
# 0           0       687           679
# 0          29      4646           211
# 0           0       485           564
# 0           1      4997           155
# 0           0       964           352
# 0           0      1332            49
# 0           0       507           240
# 0          23      1124          1172
# 0           0      1468           594
# 0           0       922           402
# 0           0       314           210
# 0           0        85          1281
# 0           3       587          1709
# 0           0        36          1013
# 0           0       346          1716
# 0           0        33          1283
# 0           0       202          1122
# 0           0        80           667
# 0           0        37           487
# 0           0       176          2120
# 0           0        86          1976
# 0           0        45          1279
# 0           0        66           458
# 0           0       267          2029
# 0           0        66          1996
# 0           0        53          1271
# 0           0        47           477
# 0          63       377           989
# 0           3        63          5619
# 0          32       212           837
# 0          19        57          4800
# 0          28       197          1119
# 0           0        91          5061
# 0           2       157           590
# 0           0         6          1375
# 0           0        40          1326
# 0           0        73           976
# 0           0        38          1278
# 0           0         0           747

# %% [markdown]
# ## Effectwise

# %% [markdown]
# ### donut plot for effect-wise activity space

# %%
def effect_activity_space(target='CHEMBL233', startangle=-90, fig_format='pdf'):
    
    target_len_df = final_len_df[final_len_df['target'] == target]
    # extract coloums needed for plotting
    target_len_df = target_len_df[['effect', 'assay', 'std_type', 'final_df']]
    # create the pivot table
    target_len_df = pd.pivot_table(target_len_df, index=['effect','assay', 'std_type'], values=['final_df'])
    # make a new column for labeling the minor data
    target_len_df['assay-type'] = target_len_df.index.get_level_values('std_type') + ': ' + target_len_df.index.get_level_values('assay')


    ##########Plot the nested pie chart#####################
    # create a figure and subplots
    fig, ax = plt.subplots(figsize=(10, 6))
    
    width = 0.3

    # data for pie charts
    # Major category values = sum of minor category values
    major_data = target_len_df.groupby('effect')['final_df'].sum()
    major_labels = target_len_df.index.get_level_values('effect').unique()
    # Minor category values
    minor_data = target_len_df['final_df']
    minor_labels = target_len_df['assay-type'] + '(' + target_len_df['final_df'].astype(str) + ')'

    # create custom colormaps based on a given color
    # color for major category
    bind_color = '#b0e3e6'
    agon_color = '#f5426c'
    antag_color = '#4278f5'
    major_colors = [agon_color, antag_color, bind_color]
    # color for minor category
    bind_palette = sns.light_palette(bind_color, n_colors=2)[::-1]
    agon_palette = sns.light_palette(agon_color, n_colors=4)[::-1]
    antag_palette = sns.light_palette(antag_color, n_colors=6)[::-1]
    minor_colors = [agon_palette[3], agon_palette[2],agon_palette[1], agon_palette[0],
                    antag_palette[5], antag_palette[4], antag_palette[3], antag_palette[2], antag_palette[1], antag_palette[0],
                    bind_palette[1], bind_palette[0]
                    ]

    # Draw pies
    hfont = {'fontname':'Times New Roman'}
    # pie for major category - 'effect', put in the inner circle
    ax.pie(major_data, 
        radius=1-width, 
        colors=major_colors,
        labels=major_labels,
        startangle=startangle,
        textprops={'fontsize': 13, 'fontname':'Times New Roman', 'fontweight':'bold'},
        wedgeprops=dict(width=width, edgecolor='w'),
        labeldistance=0.6)
    
    # pie for minor category - 'assay', put in the outer circle
    ax.pie(minor_data,
        radius=1,
        colors=minor_colors,
        labels=minor_labels,
        startangle=startangle,
        textprops={'fontsize': 11, 'fontname':'Times New Roman'},
        wedgeprops=dict(width=width, edgecolor='w'),
        labeldistance=1)

    # Set a title
    ax.set_title(f'{target}: effect-wise activity space', fontsize=16, fontweight='bold', **hfont)

    # save the figure
    file_path = os.path.join(CAT_FIG_DIR, target)
    mkdirs(file_path)

    fig.savefig(os.path.join(file_path, f"{target}_effect-wise_activity_space_pie.{fig_format}"), dpi=300, bbox_inches='tight')

    return target_len_df

# %%
mor_effect_len_df = effect_activity_space(target='CHEMBL233', startangle=-90, fig_format='pdf')
kor_effect_len_df = effect_activity_space(target='CHEMBL237', startangle=-73, fig_format='pdf')
dor_effect_len_df = effect_activity_space(target='CHEMBL236', startangle=-70, fig_format='pdf')
nor_effect_len_df = effect_activity_space(target='CHEMBL2014', startangle=-50, fig_format='pdf')
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.

# %%
mor_effect_len_df
# Out:
#                           final_df      assay-type
# effect assay    std_type
# agon   B_arrest EC50           267  EC50: B_arrest
#        G_Ca     EC50           176      EC50: G_Ca
#        G_GTP    EC50          1124     EC50: G_GTP
#        G_cAMP   EC50           587    EC50: G_cAMP
#                 IC50            85    IC50: G_cAMP
# antag  B_arrest IC50            40  IC50: B_arrest
#        G_GTP    IC50           377     IC50: G_GTP
#                 Ki              63       Ki: G_GTP
# bind   RBA      IC50           687       IC50: RBA
#                 Ki            5557         Ki: RBA

# %%
kor_effect_len_df
# Out:
#                           final_df      assay-type
# effect assay    std_type
# agon   B_arrest EC50            66  EC50: B_arrest
#        G_Ca     EC50            86      EC50: G_Ca
#        G_GTP    EC50          1468     EC50: G_GTP
#        G_cAMP   EC50           346    EC50: G_cAMP
#                 IC50            36    IC50: G_cAMP
# antag  B_arrest IC50            73  IC50: B_arrest
#        G_GTP    IC50           212     IC50: G_GTP
#                 Ki              57       Ki: G_GTP
# bind   RBA      IC50           485       IC50: RBA
#                 Ki            4646         Ki: RBA

# %%
dor_effect_len_df
# Out:
#                           final_df      assay-type
# effect assay    std_type
# agon   B_arrest EC50            53  EC50: B_arrest
#        G_Ca     EC50            45      EC50: G_Ca
#        G_GTP    EC50           922     EC50: G_GTP
#        G_cAMP   EC50           202    EC50: G_cAMP
#                 IC50            33    IC50: G_cAMP
# antag  B_arrest IC50            38  IC50: B_arrest
#        G_GTP    IC50           197     IC50: G_GTP
#                 Ki              91       Ki: G_GTP
# bind   RBA      IC50           964       IC50: RBA
#                 Ki            4997         Ki: RBA

# %%
nor_effect_len_df
# Out:
#                           final_df      assay-type
# effect assay    std_type
# agon   B_arrest EC50            47  EC50: B_arrest
#        G_Ca     EC50            66      EC50: G_Ca
#        G_GTP    EC50           314     EC50: G_GTP
#        G_cAMP   EC50            37    EC50: G_cAMP
#                 IC50            80    IC50: G_cAMP
# antag  B_arrest IC50             0  IC50: B_arrest
#        G_GTP    IC50           157     IC50: G_GTP
#                 Ki               6       Ki: G_GTP
# bind   RBA      IC50           507       IC50: RBA
#                 Ki            1332         Ki: RBA

# %% [markdown]
# ## Typewise

# %% [markdown]
# ### donut plot for type-wise activity space

# %%
def type_activity_space(target='CHEMBL233', startangle=-90, fig_format='pdf'):
    
    target_len_df = final_len_df[final_len_df['target'] == target]
    # extract columns needed for plotting
    target_len_df = target_len_df[['effect', 'assay', 'std_type', 'final_df']]
    # create the pivot table
    target_len_df = pd.pivot_table(target_len_df, index=['std_type', 'effect','assay'], values=['final_df'])
    # make a new column for labeling the minor data
    target_len_df['effect-assay'] = target_len_df.index.get_level_values('effect') + ': ' + target_len_df.index.get_level_values('assay')


    ##########Plot the nested pie chart#####################
    # create a figure and subplots
    fig, ax = plt.subplots(figsize=(10, 6))

    width = 0.3

    # data for pie charts
    # Major category values = sum of minor category values
    major_data = target_len_df.groupby('std_type')['final_df'].sum()
    major_labels = target_len_df.index.get_level_values('std_type').unique()
    # Minor category values
    minor_data = target_len_df['final_df']
    minor_labels = target_len_df['effect-assay'] + '(' + target_len_df['final_df'].astype(str) + ')'

    # create custom colormaps based on a given color
    # color for major category
    ec50_color = '#b0daff'
    ic50_color = '#19a7ce'
    kb_color = '#146c94'
    ke_color = '#164b60' 
    ki_color = '#c4b0ff' #'#e5beec', #f9f54b

    major_colors = [ec50_color, ic50_color, kb_color, ke_color, ki_color]
    # color for minor category
    ki_palette = sns.light_palette(ki_color, n_colors=2)[::-1]
    ic50_palette = sns.light_palette(ic50_color, n_colors=4)[::-1]
    ec50_palette = sns.light_palette(ec50_color, n_colors=4)[::-1]
    ke_palette = sns.light_palette(ke_color, n_colors=1)[::-1]
    kb_palette = sns.light_palette(kb_color, n_colors=1)[::-1]
    minor_colors = [ec50_palette[3], ec50_palette[2], ec50_palette[1], ec50_palette[0],
                    ic50_palette[3], ic50_palette[2], ic50_palette[1], ic50_palette[0],
                    kb_palette[0],
                    ke_palette[0],
                    ki_palette[1], ki_palette[0]]
    # Draw pies
    hfont = {'fontname':'Times New Roman'}
    # pie for major category - 'effect', put in the inner circle
    ax.pie(major_data, 
        radius=1-width, 
        colors=major_colors,
        labels=major_labels,
        startangle=startangle,
        textprops={'fontsize': 11, 'fontweight':'bold'},
        wedgeprops=dict(width=width, edgecolor='w'),
        labeldistance=0.65)
    # pie for minor category - 'assay', put in the outer circle
    ax.pie(minor_data,
        radius=1,
        colors=minor_colors,
        labels=minor_labels,
        startangle=startangle,
        textprops={'fontsize': 11, 'fontname':'Times New Roman'},
        wedgeprops=dict(width=width, edgecolor='w'),
        labeldistance=1)
    
    # Set a title
    ax.set_title(f'{target}: type-wise activity space', fontsize=16, fontweight='bold', **hfont)

    # save the figure
    file_path = os.path.join(CAT_FIG_DIR, target)
    mkdirs(file_path)

    fig.savefig(os.path.join(file_path, f"{target}_type-wise_activity_space_pie.{fig_format}"), dpi=300, bbox_inches='tight')
    print(f"Figure saved in {file_path}")
    
    return target_len_df

# %%
mor_type_len_df = type_activity_space(target='CHEMBL233', startangle=-90, fig_format='pdf')
kor_type_len_df = type_activity_space(target='CHEMBL237', startangle=-103, fig_format='pdf')
dor_type_len_df = type_activity_space(target='CHEMBL236', startangle=-101, fig_format='pdf')
nor_type_len_df = type_activity_space(target='CHEMBL2014', startangle=-100, fig_format='pdf')
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# Figure saved in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Figures/data_prep/data_categorize/CHEMBL233
# Figure saved in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Figures/data_prep/data_categorize/CHEMBL237
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# Figure saved in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Figures/data_prep/data_categorize/CHEMBL236
# Figure saved in /storage/homefs/yc24j783/datacat4ml/datacat4ml/Figures/data_prep/data_categorize/CHEMBL2014

# %%
mor_type_len_df
# Out:
#                           final_df     effect-assay
# std_type effect assay
# EC50     agon   B_arrest       267   agon: B_arrest
#                 G_Ca           176       agon: G_Ca
#                 G_GTP         1124      agon: G_GTP
#                 G_cAMP         587     agon: G_cAMP
# IC50     agon   G_cAMP          85     agon: G_cAMP
#          antag  B_arrest        40  antag: B_arrest
#                 G_GTP          377     antag: G_GTP
#          bind   RBA            687        bind: RBA
# Ki       antag  G_GTP           63     antag: G_GTP
#          bind   RBA           5557        bind: RBA

# %%
kor_type_len_df
# Out:
#                           final_df     effect-assay
# std_type effect assay
# EC50     agon   B_arrest        66   agon: B_arrest
#                 G_Ca            86       agon: G_Ca
#                 G_GTP         1468      agon: G_GTP
#                 G_cAMP         346     agon: G_cAMP
# IC50     agon   G_cAMP          36     agon: G_cAMP
#          antag  B_arrest        73  antag: B_arrest
#                 G_GTP          212     antag: G_GTP
#          bind   RBA            485        bind: RBA
# Ki       antag  G_GTP           57     antag: G_GTP
#          bind   RBA           4646        bind: RBA

# %%
dor_type_len_df
# Out:
#                           final_df     effect-assay
# std_type effect assay
# EC50     agon   B_arrest        53   agon: B_arrest
#                 G_Ca            45       agon: G_Ca
#                 G_GTP          922      agon: G_GTP
#                 G_cAMP         202     agon: G_cAMP
# IC50     agon   G_cAMP          33     agon: G_cAMP
#          antag  B_arrest        38  antag: B_arrest
#                 G_GTP          197     antag: G_GTP
#          bind   RBA            964        bind: RBA
# Ki       antag  G_GTP           91     antag: G_GTP
#          bind   RBA           4997        bind: RBA

# %%
nor_type_len_df
# Out:
#                           final_df     effect-assay
# std_type effect assay
# EC50     agon   B_arrest        47   agon: B_arrest
#                 G_Ca            66       agon: G_Ca
#                 G_GTP          314      agon: G_GTP
#                 G_cAMP          37     agon: G_cAMP
# IC50     agon   G_cAMP          80     agon: G_cAMP
#          antag  B_arrest         0  antag: B_arrest
#                 G_GTP          157     antag: G_GTP
#          bind   RBA            507        bind: RBA
# Ki       antag  G_GTP            6     antag: G_GTP
#          bind   RBA           1332        bind: RBA
